# %% [markdown]
# <a href="https://colab.research.google.com/github/AFracassi/inf1340-programmingfordatascience-fa22/blob/main/Antoniette_FracassiTable6Midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Table 6

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.ExcelFile('/content/drive/MyDrive/UN_MigrantStockTotal_2015.xlsx')

# %%
df.sheet_names
# Out:
# ['CONTENTS',
#  'Table 1',
#  'Table 2',
#  'Table 3',
#  'Table 4',
#  'Table 5',
#  'Table 6',
#  'ANNEX',
#  'NOTES']

# %%
table6=pd.read_excel(df, sheet_name="Table 6")
table6
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0          NaN                        NaN        NaN        NaN
# 1          NaN                        NaN        NaN        NaN
# 2          NaN                        NaN        NaN        NaN
# 3          NaN                        NaN        NaN        NaN
# 4          NaN                        NaN        NaN        NaN
# ..         ...                        ...        ...        ...
# 275        261                      Samoa        NaN        882
# 276        262                    Tokelau        NaN        772
# 277        263                      Tonga        NaN        776
# 278        264                     Tuvalu        NaN        798
# 279        265  Wallis and Futuna Islands        NaN        876
#
#               Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                    NaN        NaN        NaN        NaN        NaN
# ...

# %%
#Removing the Header
table6=table6[13:]
table6
# Out:
#       Unnamed: 0                                         Unnamed: 1  \
# 13   Sort\norder  Major area, region, country or area of destina...
# 14           NaN                                                NaN
# 15             1                                              WORLD
# 16             2                                  Developed regions
# 17             3                                 Developing regions
# ..           ...                                                ...
# 275          261                                              Samoa
# 276          262                                            Tokelau
# 277          263                                              Tonga
# 278          264                                             Tuvalu
# 279          265                          Wallis and Futuna Islands
#
#     Unnamed: 2    Unnamed: 3        Unnamed: 4  \
# 13       Notes  Country code  Type of data (a)
# 14         NaN           NaN               NaN
# ...

# %%
#New Column Name
my_columns=["sort\norder", "Major area, region, country or area of destination", "Notes", "Country code", "Type of data (a)", "Est. Refugee stock at mid-year, Both sexes, 1990", "Est. Refugee stock at mid-year, Both sexes, 1995",
            "Est. Refugee stock at mid-year, Both sexes, 2000", "Est. Refugee stock at mid-year, Both sexes, 2005", "Est. Refugee stock at mid-year, Both sexes, 2010", 
            "Est. Refugee stock at mid-year, Both sexes, 2015", "Refugees as a % of Int'l migrant stock, 1990", "Refugees as a % of Int'l migrant stock, 1995", "Refugees as a % of Int'l migrant stock, 2000", "Refugees as a % of Int'l migrant stock, 2005", 
            "Refugees as a % of Int'l migrant stock, 2010", "Refugees as a % of Int'l migrant stock, 2015", "Annual rate of change of the refugee stock, 1990-1995",
            "Annual rate of change of the refugee stock, 1995-2000", "Annual rate of change of the refugee stock, 2000-2005", "Annual rate of change of the refugee stock, 2005-2010", "Annual rate of change of the refugee stock, 2010-2015"]
my_columns
# Out:
# ['sort\norder',
#  'Major area, region, country or area of destination',
#  'Notes',
#  'Country code',
#  'Type of data (a)',
#  'Est. Refugee stock at mid-year, Both sexes, 1990',
#  'Est. Refugee stock at mid-year, Both sexes, 1995',
#  'Est. Refugee stock at mid-year, Both sexes, 2000',
#  'Est. Refugee stock at mid-year, Both sexes, 2005',
#  'Est. Refugee stock at mid-year, Both sexes, 2010',
#  'Est. Refugee stock at mid-year, Both sexes, 2015',
#  "Refugees as a % of Int'l migrant stock, 1990",
#  "Refugees as a % of Int'l migrant stock, 1995",
#  "Refugees as a % of Int'l migrant stock, 2000",
#  "Refugees as a % of Int'l migrant stock, 2005",
#  "Refugees as a % of Int'l migrant stock, 2010",
#  "Refugees as a % of Int'l migrant stock, 2015",
#  'Annual rate of change of the refugee stock, 1990-1995',
#  'Annual rate of change of the refugee stock, 1995-2000',
#  'Annual rate of change of the refugee stock, 2000-2005',
# ...

# %%
table6.columns=my_columns
table6
# Out:
#      sort\norder Major area, region, country or area of destination  Notes  \
# 13   Sort\norder  Major area, region, country or area of destina...  Notes
# 14           NaN                                                NaN    NaN
# 15             1                                              WORLD    NaN
# 16             2                                  Developed regions    (b)
# 17             3                                 Developing regions    (c)
# ..           ...                                                ...    ...
# 275          261                                              Samoa    NaN
# 276          262                                            Tokelau    NaN
# 277          263                                              Tonga    NaN
# 278          264                                             Tuvalu    NaN
# 279          265                          Wallis and Futuna Islands    NaN
#
#      Country code  Type of data (a)  \
# ...

# %%
#Removing Colmns and rows
table6=table6.iloc[2:, 1:]
table6=table6.drop(["Notes", "Type of data (a)"], axis=1)
table6
# Out:
#     Major area, region, country or area of destination Country code  \
# 15                                               WORLD          900
# 16                                   Developed regions          901
# 17                                  Developing regions          902
# 18                           Least developed countries          941
# 19   Less developed regions excluding least develop...          934
# ..                                                 ...          ...
# 275                                              Samoa          882
# 276                                            Tokelau          772
# 277                                              Tonga          776
# 278                                             Tuvalu          798
# 279                          Wallis and Futuna Islands          876
#
#     Est. Refugee stock at mid-year, Both sexes, 1990  \
# 15                                          18836571
# ...

# %%
table6_tidy=table6.melt(id_vars=['Major area, region, country or area of destination', 'Country code'], value_vars=["Est. Refugee stock at mid-year, Both sexes, 1990", 
                        "Est. Refugee stock at mid-year, Both sexes, 1995", "Est. Refugee stock at mid-year, Both sexes, 2000", 
                                "Est. Refugee stock at mid-year, Both sexes, 2005","Est. Refugee stock at mid-year, Both sexes, 2010", 
                                "Est. Refugee stock at mid-year, Both sexes, 2015", "Refugees as a % of Int'l migrant stock, 1990", 
                                "Refugees as a % of Int'l migrant stock, 1995", "Refugees as a % of Int'l migrant stock, 2000", 
                                "Refugees as a % of Int'l migrant stock, 2005", "Refugees as a % of Int'l migrant stock, 2010", 
                                "Refugees as a % of Int'l migrant stock, 2015",
                                "Annual rate of change of the refugee stock, 1990-1995",
                                "Annual rate of change of the refugee stock, 1995-2000",
                                "Annual rate of change of the refugee stock, 2000-2005",
                                "Annual rate of change of the refugee stock, 2005-2010",
                                "Annual rate of change of the refugee stock, 2010-2015"],
value_name="Values, in $, %",
var_name="Trends in International Migrant Stock, Year")
table6_tidy
# Out:
#      Major area, region, country or area of destination Country code  \
# 0                                                 WORLD          900
# 1                                     Developed regions          901
# 2                                    Developing regions          902
# 3                             Least developed countries          941
# 4     Less developed regions excluding least develop...          934
# ...                                                 ...          ...
# 4500                                              Samoa          882
# 4501                                            Tokelau          772
# 4502                                              Tonga          776
# 4503                                             Tuvalu          798
# 4504                          Wallis and Futuna Islands          876
#
#             Trends in International Migrant Stock, Year Values, in $, %
# ...
