# %% [markdown]
# <a href="https://colab.research.google.com/github/AFracassi/inf1340-programmingfordatascience-fa22/blob/main/Antonietta_Fracassi_Table5Midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Table 5

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.ExcelFile('/content/drive/MyDrive/UN_MigrantStockTotal_2015.xlsx')

# %%
df.sheet_names
# Out:
# ['CONTENTS',
#  'Table 1',
#  'Table 2',
#  'Table 3',
#  'Table 4',
#  'Table 5',
#  'Table 6',
#  'ANNEX',
#  'NOTES']

# %%
table5=pd.read_excel(df, sheet_name="Table 5")

# %%
table5
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0          NaN                        NaN        NaN        NaN
# 1          NaN                        NaN        NaN        NaN
# 2          NaN                        NaN        NaN        NaN
# 3          NaN                        NaN        NaN        NaN
# 4          NaN                        NaN        NaN        NaN
# ..         ...                        ...        ...        ...
# 275        261                      Samoa        NaN        882
# 276        262                    Tokelau        NaN        772
# 277        263                      Tonga        NaN        776
# 278        264                     Tuvalu        NaN        798
# 279        265  Wallis and Futuna Islands        NaN        876
#
#               Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                    NaN        NaN        NaN        NaN        NaN
# 1                    NaN        NaN        NaN        NaN        NaN
# 2                    NaN        NaN        NaN        NaN        NaN
# 3         United Nations        NaN        NaN        NaN        NaN
# 4    Population Division        NaN        NaN        NaN        NaN
# ..                   ...        ...        ...        ...        ...
# 275                    B   6.704748    4.90282  -0.858442  -2.299179
# 276                    B  -0.298513  -0.303036  -0.307698  10.169947
# 277                    B   2.350316   2.359733   3.096969   3.099614
# 278                    C  -3.797947  -3.845134  -3.408224  -3.450671
# 279                    B    3.61788   3.636508   3.203177    3.20466
#
#     Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
# ..         ...         ...         ...         ...         ...         ...
# 275  -0.768177    6.499035    4.704571   -1.066301    -2.50417   -0.987758
# 276   2.536144   -0.404054   -0.412386   -1.589283    8.750541    2.463246
# 277   2.641235    2.874558    2.848819    3.228155    3.163851    2.737439
# 278  -1.763854   -3.914892   -4.028435   -3.613401   -3.449385   -1.718849
# 279    0.51914    3.364378    3.396526    3.189382    3.197545     0.52134
#
#     Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19
# 0           NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...
# 275    6.931983    5.117229   -0.638315    -2.08663   -0.545343
# 276   -0.167365   -0.168777    1.152582   11.577161     2.60325
# 277    1.787022     1.80546    2.943277    3.023552    2.526318
# 278   -3.646431   -3.611679   -3.152579   -3.452255   -1.819436
# 279    3.886601    3.884553    3.217252    3.211913    0.516899
#
# [280 rows x 20 columns]

# %%
#Removing the header
table5=table5[8:]
table5
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 8          NaN                        NaN        NaN        NaN
# 9          NaN                        NaN        NaN        NaN
# 10         NaN                        NaN        NaN        NaN
# 11         NaN                        NaN        NaN        NaN
# 12         NaN                        NaN        NaN        NaN
# ..         ...                        ...        ...        ...
# 275        261                      Samoa        NaN        882
# 276        262                    Tokelau        NaN        772
# 277        263                      Tonga        NaN        776
# 278        264                     Tuvalu        NaN        798
# 279        265  Wallis and Futuna Islands        NaN        876
#
#                                             Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 8    Table 5 - Annual rate of change of the migrant...        NaN        NaN
# 9                            POP/DB/MIG/Stock/Rev.2015        NaN        NaN
# 10   December 2015 - Copyright © 2015 by United Nat...        NaN        NaN
# 11   Suggested citation: United Nations, Department...        NaN        NaN
# 12                                                 NaN        NaN        NaN
# ..                                                 ...        ...        ...
# 275                                                  B   6.704748    4.90282
# 276                                                  B  -0.298513  -0.303036
# 277                                                  B   2.350316   2.359733
# 278                                                  C  -3.797947  -3.845134
# 279                                                  B    3.61788   3.636508
#
#     Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 8          NaN        NaN        NaN         NaN         NaN         NaN
# 9          NaN        NaN        NaN         NaN         NaN         NaN
# 10         NaN        NaN        NaN         NaN         NaN         NaN
# 11         NaN        NaN        NaN         NaN         NaN         NaN
# 12         NaN        NaN        NaN         NaN         NaN         NaN
# ..         ...        ...        ...         ...         ...         ...
# 275  -0.858442  -2.299179  -0.768177    6.499035    4.704571   -1.066301
# 276  -0.307698  10.169947   2.536144   -0.404054   -0.412386   -1.589283
# 277   3.096969   3.099614   2.641235    2.874558    2.848819    3.228155
# 278  -3.408224  -3.450671  -1.763854   -3.914892   -4.028435   -3.613401
# 279   3.203177    3.20466    0.51914    3.364378    3.396526    3.189382
#
#     Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 8           NaN         NaN         NaN         NaN         NaN         NaN
# 9           NaN         NaN         NaN         NaN         NaN         NaN
# 10          NaN         NaN         NaN         NaN         NaN         NaN
# 11          NaN         NaN         NaN         NaN         NaN         NaN
# 12          NaN         NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...         ...
# 275    -2.50417   -0.987758    6.931983    5.117229   -0.638315    -2.08663
# 276    8.750541    2.463246   -0.167365   -0.168777    1.152582   11.577161
# 277    3.163851    2.737439    1.787022     1.80546    2.943277    3.023552
# 278   -3.449385   -1.718849   -3.646431   -3.611679   -3.152579   -3.452255
# 279    3.197545     0.52134    3.886601    3.884553    3.217252    3.211913
#
#     Unnamed: 19
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# ..          ...
# 275   -0.545343
# 276     2.60325
# 277    2.526318
# 278   -1.819436
# 279    0.516899
#
# [272 rows x 20 columns]

# %%
#New Column Names

# %%
my_columns=["sort\norder", "Major area, region, country or area of destination", "Notes", "Country Code", "Type of data (a)", "Both sexes, 1990-1995", "Both sexes, 1995-2000", 
            "Both sexes, 2000-2005", "Both sexes, 2005-2010", "Both sexes, 2010-2015", "Male, 1990-1995", 
            "Male, 1995-2000", "Male, 2000-2005", "Male, 2005-2010", "Male, 2010-2015", "Female, 1990-1995", "Female, 1995-2000", "Female, 2000-2005",
            "Female, 2005-2010", "Female, 2010-2015"]
my_columns
# Out:
# ['sort\norder',
#  'Major area, region, country or area of destination',
#  'Notes',
#  'Country Code',
#  'Type of data (a)',
#  'Both sexes, 1990-1995',
#  'Both sexes, 1995-2000',
#  'Both sexes, 2000-2005',
#  'Both sexes, 2005-2010',
#  'Both sexes, 2010-2015',
#  'Male, 1990-1995',
#  'Male, 1995-2000',
#  'Male, 2000-2005',
#  'Male, 2005-2010',
#  'Male, 2010-2015',
#  'Female, 1990-1995',
#  'Female, 1995-2000',
#  'Female, 2000-2005',
#  'Female, 2005-2010',
#  'Female, 2010-2015']

# %%
table5.columns=my_columns
table5
# Out:
#     sort\norder Major area, region, country or area of destination Notes  \
# 8           NaN                                                NaN   NaN
# 9           NaN                                                NaN   NaN
# 10          NaN                                                NaN   NaN
# 11          NaN                                                NaN   NaN
# 12          NaN                                                NaN   NaN
# ..          ...                                                ...   ...
# 275         261                                              Samoa   NaN
# 276         262                                            Tokelau   NaN
# 277         263                                              Tonga   NaN
# 278         264                                             Tuvalu   NaN
# 279         265                          Wallis and Futuna Islands   NaN
#
#     Country Code                                   Type of data (a)  \
# 8            NaN  Table 5 - Annual rate of change of the migrant...
# 9            NaN                          POP/DB/MIG/Stock/Rev.2015
# 10           NaN  December 2015 - Copyright © 2015 by United Nat...
# 11           NaN  Suggested citation: United Nations, Department...
# 12           NaN                                                NaN
# ..           ...                                                ...
# 275          882                                                  B
# 276          772                                                  B
# 277          776                                                  B
# 278          798                                                  C
# 279          876                                                  B
#
#     Both sexes, 1990-1995 Both sexes, 1995-2000 Both sexes, 2000-2005  \
# 8                     NaN                   NaN                   NaN
# 9                     NaN                   NaN                   NaN
# 10                    NaN                   NaN                   NaN
# 11                    NaN                   NaN                   NaN
# 12                    NaN                   NaN                   NaN
# ..                    ...                   ...                   ...
# 275              6.704748               4.90282             -0.858442
# 276             -0.298513             -0.303036             -0.307698
# 277              2.350316              2.359733              3.096969
# 278             -3.797947             -3.845134             -3.408224
# 279               3.61788              3.636508              3.203177
#
#     Both sexes, 2005-2010 Both sexes, 2010-2015 Male, 1990-1995  \
# 8                     NaN                   NaN             NaN
# 9                     NaN                   NaN             NaN
# 10                    NaN                   NaN             NaN
# 11                    NaN                   NaN             NaN
# 12                    NaN                   NaN             NaN
# ..                    ...                   ...             ...
# 275             -2.299179             -0.768177        6.499035
# 276             10.169947              2.536144       -0.404054
# 277              3.099614              2.641235        2.874558
# 278             -3.450671             -1.763854       -3.914892
# 279               3.20466               0.51914        3.364378
#
#     Male, 1995-2000 Male, 2000-2005 Male, 2005-2010 Male, 2010-2015  \
# 8               NaN             NaN             NaN             NaN
# 9               NaN             NaN             NaN             NaN
# 10              NaN             NaN             NaN             NaN
# 11              NaN             NaN             NaN             NaN
# 12              NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 275        4.704571       -1.066301        -2.50417       -0.987758
# 276       -0.412386       -1.589283        8.750541        2.463246
# 277        2.848819        3.228155        3.163851        2.737439
# 278       -4.028435       -3.613401       -3.449385       -1.718849
# 279        3.396526        3.189382        3.197545         0.52134
#
#     Female, 1990-1995 Female, 1995-2000 Female, 2000-2005 Female, 2005-2010  \
# 8                 NaN               NaN               NaN               NaN
# 9                 NaN               NaN               NaN               NaN
# 10                NaN               NaN               NaN               NaN
# 11                NaN               NaN               NaN               NaN
# 12                NaN               NaN               NaN               NaN
# ..                ...               ...               ...               ...
# 275          6.931983          5.117229         -0.638315          -2.08663
# 276         -0.167365         -0.168777          1.152582         11.577161
# 277          1.787022           1.80546          2.943277          3.023552
# 278         -3.646431         -3.611679         -3.152579         -3.452255
# 279          3.886601          3.884553          3.217252          3.211913
#
#     Female, 2010-2015
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# ..                ...
# 275         -0.545343
# 276           2.60325
# 277          2.526318
# 278         -1.819436
# 279          0.516899
#
# [272 rows x 20 columns]

# %%
#Removing Columns and Rows
table5=table5.iloc[2:, 1:]
table5=table5.drop(["Notes", "Type of data (a)"], axis=1)
table5
# Out:
#     Major area, region, country or area of destination  Country Code  \
# 10                                                 NaN           NaN
# 11                                                 NaN           NaN
# 12                                                 NaN           NaN
# 13   Major area, region, country or area of destina...  Country code
# 14                                                 NaN           NaN
# ..                                                 ...           ...
# 275                                              Samoa           882
# 276                                            Tokelau           772
# 277                                              Tonga           776
# 278                                             Tuvalu           798
# 279                          Wallis and Futuna Islands           876
#
#                                  Both sexes, 1990-1995 Both sexes, 1995-2000  \
# 10                                                 NaN                   NaN
# 11                                                 NaN                   NaN
# 12                                                 NaN                   NaN
# 13   Annual rate of change of the migrant stock (bo...                   NaN
# 14                                           1990-1995             1995-2000
# ..                                                 ...                   ...
# 275                                           6.704748               4.90282
# 276                                          -0.298513             -0.303036
# 277                                           2.350316              2.359733
# 278                                          -3.797947             -3.845134
# 279                                            3.61788              3.636508
#
#     Both sexes, 2000-2005 Both sexes, 2005-2010 Both sexes, 2010-2015  \
# 10                    NaN                   NaN                   NaN
# 11                    NaN                   NaN                   NaN
# 12                    NaN                   NaN                   NaN
# 13                    NaN                   NaN                   NaN
# 14              2000-2005             2005-2010             2010-2015
# ..                    ...                   ...                   ...
# 275             -0.858442             -2.299179             -0.768177
# 276             -0.307698             10.169947              2.536144
# 277              3.096969              3.099614              2.641235
# 278             -3.408224             -3.450671             -1.763854
# 279              3.203177               3.20466               0.51914
#
#                                        Male, 1990-1995 Male, 1995-2000  \
# 10                                                 NaN             NaN
# 11                                                 NaN             NaN
# 12                                                 NaN             NaN
# 13   Annual rate of change of the migrant stock (male)             NaN
# 14                                           1990-1995       1995-2000
# ..                                                 ...             ...
# 275                                           6.499035        4.704571
# 276                                          -0.404054       -0.412386
# 277                                           2.874558        2.848819
# 278                                          -3.914892       -4.028435
# 279                                           3.364378        3.396526
#
#     Male, 2000-2005 Male, 2005-2010 Male, 2010-2015  \
# 10              NaN             NaN             NaN
# 11              NaN             NaN             NaN
# 12              NaN             NaN             NaN
# 13              NaN             NaN             NaN
# 14        2000-2005       2005-2010       2010-2015
# ..              ...             ...             ...
# 275       -1.066301        -2.50417       -0.987758
# 276       -1.589283        8.750541        2.463246
# 277        3.228155        3.163851        2.737439
# 278       -3.613401       -3.449385       -1.718849
# 279        3.189382        3.197545         0.52134
#
#                                      Female, 1990-1995 Female, 1995-2000  \
# 10                                                 NaN               NaN
# 11                                                 NaN               NaN
# 12                                                 NaN               NaN
# 13   Annual rate of change of the migrant stock (fe...               NaN
# 14                                           1990-1995         1995-2000
# ..                                                 ...               ...
# 275                                           6.931983          5.117229
# 276                                          -0.167365         -0.168777
# 277                                           1.787022           1.80546
# 278                                          -3.646431         -3.611679
# 279                                           3.886601          3.884553
#
#     Female, 2000-2005 Female, 2005-2010 Female, 2010-2015
# 10                NaN               NaN               NaN
# 11                NaN               NaN               NaN
# 12                NaN               NaN               NaN
# 13                NaN               NaN               NaN
# 14          2000-2005         2005-2010         2010-2015
# ..                ...               ...               ...
# 275         -0.638315          -2.08663         -0.545343
# 276          1.152582         11.577161           2.60325
# 277          2.943277          3.023552          2.526318
# 278         -3.152579         -3.452255         -1.819436
# 279          3.217252          3.211913          0.516899
#
# [270 rows x 17 columns]

# %%
table5_tidy=table5.melt(id_vars=['Major area, region, country or area of destination', 'Country Code'], value_vars=["Both sexes, 1990-1995", "Both sexes, 1995-2000",
                                  "Both sexes, 2000-2005", "Both sexes, 2005-2010", "Both sexes, 2010-2015", "Male, 1990-1995", "Male, 1995-2000", "Male, 2000-2005",
                                  "Male, 2005-2010", "Female, 1990-1995", "Female, 1995-2000", "Female, 2000-2005", "Female, 2005-2010"],
value_name="Annual rate of change of the migrant stock",
var_name="Sex, Year")
table5_tidy
# Out:
#      Major area, region, country or area of destination  Country Code  \
# 0                                                   NaN           NaN
# 1                                                   NaN           NaN
# 2                                                   NaN           NaN
# 3     Major area, region, country or area of destina...  Country code
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 3505                                              Samoa           882
# 3506                                            Tokelau           772
# 3507                                              Tonga           776
# 3508                                             Tuvalu           798
# 3509                          Wallis and Futuna Islands           876
#
#                   Sex, Year         Annual rate of change of the migrant stock
# 0     Both sexes, 1990-1995                                                NaN
# 1     Both sexes, 1990-1995                                                NaN
# 2     Both sexes, 1990-1995                                                NaN
# 3     Both sexes, 1990-1995  Annual rate of change of the migrant stock (bo...
# 4     Both sexes, 1990-1995                                          1990-1995
# ...                     ...                                                ...
# 3505      Female, 2005-2010                                           -2.08663
# 3506      Female, 2005-2010                                          11.577161
# 3507      Female, 2005-2010                                           3.023552
# 3508      Female, 2005-2010                                          -3.452255
# 3509      Female, 2005-2010                                           3.211913
#
# [3510 rows x 4 columns]

# %%
#Seperating Columns into 2
table5_tidy[["Sex", "Year"]]=table5_tidy['Sex, Year'].str.split(',',expand=True)
table5_tidy=table5_tidy.drop("Sex, Year", axis=1)
table5_tidy
# Out:
#      Major area, region, country or area of destination  Country Code  \
# 0                                                   NaN           NaN
# 1                                                   NaN           NaN
# 2                                                   NaN           NaN
# 3     Major area, region, country or area of destina...  Country code
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 3505                                              Samoa           882
# 3506                                            Tokelau           772
# 3507                                              Tonga           776
# 3508                                             Tuvalu           798
# 3509                          Wallis and Futuna Islands           876
#
#              Annual rate of change of the migrant stock         Sex  \
# 0                                                   NaN  Both sexes
# 1                                                   NaN  Both sexes
# 2                                                   NaN  Both sexes
# 3     Annual rate of change of the migrant stock (bo...  Both sexes
# 4                                             1990-1995  Both sexes
# ...                                                 ...         ...
# 3505                                           -2.08663      Female
# 3506                                          11.577161      Female
# 3507                                           3.023552      Female
# 3508                                          -3.452255      Female
# 3509                                           3.211913      Female
#
#             Year
# 0      1990-1995
# 1      1990-1995
# 2      1990-1995
# 3      1990-1995
# 4      1990-1995
# ...          ...
# 3505   2005-2010
# 3506   2005-2010
# 3507   2005-2010
# 3508   2005-2010
# 3509   2005-2010
#
# [3510 rows x 5 columns]
