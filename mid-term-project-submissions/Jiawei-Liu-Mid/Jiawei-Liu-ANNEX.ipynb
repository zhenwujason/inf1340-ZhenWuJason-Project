# %%
import pandas as pd
import numpy as np
import os
os.chdir('C:/Users/COOPER/Desktop/1340 MID') 
table7 = pd.read_excel("UN_MigrantStockTotal_2015.xlsx",sheet_name = "ANNEX", index_col=[0], skiprows=14)

# %% [markdown]
# # Rename some columns since they have the same name but actually different value under the column

# %%
table7.columns = [ 'Country name', 'Country sort order',
       'Major area', 'Major area code',
       'Major area sort order', 'Region', 
       'Region code', 'Region sort order',
       'Developed region', 'Least developed country',
       'Sub-Saharan Africa']
table7.reset_index(inplace=True)
table7
# Out:
#      Country code               Country name  Country sort order Major area  \
# 0               4                Afghanistan                  99       Asia
# 1               8                    Albania                 154     Europe
# 2              12                    Algeria                  40     Africa
# 3              16             American Samoa                 257    Oceania
# 4              20                    Andorra                 155     Europe
# ..            ...                        ...                 ...        ...
# 227           876  Wallis and Futuna Islands                 265    Oceania
# 228           732             Western Sahara                  46     Africa
# 229           887                      Yemen                 126       Asia
# 230           894                     Zambia                  27     Africa
# 231           716                   Zimbabwe                  28     Africa
#
# ...
