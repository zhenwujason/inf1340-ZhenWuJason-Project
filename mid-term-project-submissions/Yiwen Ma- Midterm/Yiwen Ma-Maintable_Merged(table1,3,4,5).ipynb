# %%
import pandas as pd

data1 = pd.read_excel("Table1_Maintable.xlsx")
data3 = pd.read_excel("Table3_Maintable.xlsx")
data4 = pd.read_excel("Table4_Maintable.xlsx")
data4.pop("ID")
#because table 4 only have single sex which is female, and I will drop ID columns to avoid ID conflicts for new merged table
data5 = pd.read_excel("Table5_Maintable.xlsx")

# %%
merge1 = data1.merge(data3,how="outer")
merge1
# Out:
#       Unnamed: 0    ID Major area, region, country or area of destination  \
# 0              0     1                                              WORLD
# 1              1     2                                  Developed regions
# 2              2     3                                 Developing regions
# 3              3     4                          Least developed countries
# 4              4     5  Less developed regions excluding least develop...
# ...          ...   ...                                                ...
# 4765        4765  4766                                              Samoa
# 4766        4766  4767                                            Tokelau
# 4767        4767  4768                                              Tonga
# 4768        4768  4769                                             Tuvalu
# 4769        4769  4770                          Wallis and Futuna Islands
#
#      Notes Type of data (a)  International migrant stock at mid-year Gender  \
# 0      NaN              NaN                              152563212.0   Both
# 1      (b)              NaN                               82378628.0   Both
# 2      (c)              NaN                               70184584.0   Both
# 3      (d)              NaN                               11075966.0   Both
# 4      NaN              NaN                               59105261.0   Both
# ...    ...              ...                                      ...    ...
# 4765   NaN                B                                   2460.0   Male
# 4766   NaN                B                                    254.0   Male
# 4767   NaN                B                                   2604.0   Male
# 4768   NaN                C                                     63.0   Male
# 4769   NaN                B                                   1411.0   Male
#
#       Year  \
# 0     1990
# 1     1990
# 2     1990
# 3     1990
# 4     1990
# ...    ...
# 4765  2015
# 4766  2015
# 4767  2015
# 4768  2015
# 4769  2015
#
#       International migrant stock as a percentage of the total population(%)
# 0                                              2.873310
# 1                                              7.198015
# 2                                              1.685021
# 3                                              2.171513
# 4                                              1.617042
# ...                                                 ...
# 4765                                           2.628654
# 4766                                                NaN
# 4767                                           4.919612
# 4768                                                NaN
# 4769                                                NaN
#
# [4770 rows x 9 columns]

# %%
#using pop function drop the temporary columns that creaed by defult 
merge1.pop("Unnamed: 0")
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 4765    4765
# 4766    4766
# 4767    4767
# 4768    4768
# 4769    4769
# Name: Unnamed: 0, Length: 4770, dtype: int64

# %%
merge2 = merge1.merge(data4,how="outer")
merge2
# Out:
#         ID Major area, region, country or area of destination Notes  \
# 0        1                                              WORLD   NaN
# 1        2                                  Developed regions   (b)
# 2        3                                 Developing regions   (c)
# 3        4                          Least developed countries   (d)
# 4        5  Less developed regions excluding least develop...   NaN
# ...    ...                                                ...   ...
# 4765  4766                                              Samoa   NaN
# 4766  4767                                            Tokelau   NaN
# 4767  4768                                              Tonga   NaN
# 4768  4769                                             Tuvalu   NaN
# 4769  4770                          Wallis and Futuna Islands   NaN
#
#      Type of data (a)  International migrant stock at mid-year Gender  Year  \
# 0                 NaN                              152563212.0   Both  1990
# 1                 NaN                               82378628.0   Both  1990
# 2                 NaN                               70184584.0   Both  1990
# 3                 NaN                               11075966.0   Both  1990
# 4                 NaN                               59105261.0   Both  1990
# ...               ...                                      ...    ...   ...
# 4765                B                                   2460.0   Male  2015
# 4766                B                                    254.0   Male  2015
# 4767                B                                   2604.0   Male  2015
# 4768                C                                     63.0   Male  2015
# 4769                B                                   1411.0   Male  2015
#
#       International migrant stock as a percentage of the total population(%)  \
# 0                                              2.873310
# 1                                              7.198015
# 2                                              1.685021
# 3                                              2.171513
# 4                                              1.617042
# ...                                                 ...
# 4765                                           2.628654
# 4766                                                NaN
# 4767                                           4.919612
# 4768                                                NaN
# 4769                                                NaN
#
#       Unnamed: 0  \
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 4765         NaN
# 4766         NaN
# 4767         NaN
# 4768         NaN
# 4769         NaN
#
#       Female migrants as a percentage of the international migrant stock(%)
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4765                                                NaN
# 4766                                                NaN
# 4767                                                NaN
# 4768                                                NaN
# 4769                                                NaN
#
# [4770 rows x 10 columns]

# %%
#using pop function drop the temporary columns that creaed by deful
merge2.pop("Unnamed: 0")
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 4765   NaN
# 4766   NaN
# 4767   NaN
# 4768   NaN
# 4769   NaN
# Name: Unnamed: 0, Length: 4770, dtype: float64

# %%
Maintable = merge2.merge(data5,how="outer")
Maintable
# Out:
#         ID Major area, region, country or area of destination Notes  \
# 0        1                                              WORLD   NaN
# 1        2                                  Developed regions   (b)
# 2        3                                 Developing regions   (c)
# 3        4                          Least developed countries   (d)
# 4        5  Less developed regions excluding least develop...   NaN
# ...    ...                                                ...   ...
# 4765  4766                                              Samoa   NaN
# 4766  4767                                            Tokelau   NaN
# 4767  4768                                              Tonga   NaN
# 4768  4769                                             Tuvalu   NaN
# 4769  4770                          Wallis and Futuna Islands   NaN
#
#      Type of data (a)  International migrant stock at mid-year Gender  Year  \
# 0                 NaN                              152563212.0   Both  1990
# 1                 NaN                               82378628.0   Both  1990
# 2                 NaN                               70184584.0   Both  1990
# 3                 NaN                               11075966.0   Both  1990
# 4                 NaN                               59105261.0   Both  1990
# ...               ...                                      ...    ...   ...
# 4765                B                                   2460.0   Male  2015
# 4766                B                                    254.0   Male  2015
# 4767                B                                   2604.0   Male  2015
# 4768                C                                     63.0   Male  2015
# 4769                B                                   1411.0   Male  2015
#
#       International migrant stock as a percentage of the total population(%)  \
# 0                                              2.873310
# 1                                              7.198015
# 2                                              1.685021
# 3                                              2.171513
# 4                                              1.617042
# ...                                                 ...
# 4765                                           2.628654
# 4766                                                NaN
# 4767                                           4.919612
# 4768                                                NaN
# 4769                                                NaN
#
#       Female migrants as a percentage of the international migrant stock(%)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4765                                                NaN
# 4766                                                NaN
# 4767                                                NaN
# 4768                                                NaN
# 4769                                                NaN
#
#       Unnamed: 0  Annual rate of change of the migrant stock(%)
# 0              0                                            NaN
# 1              1                                            NaN
# 2              2                                            NaN
# 3              3                                            NaN
# 4              4                                            NaN
# ...          ...                                            ...
# 4765        4765                                      -0.545343
# 4766        4766                                       2.603250
# 4767        4767                                       2.526318
# 4768        4768                                      -1.819436
# 4769        4769                                       0.516899
#
# [4770 rows x 11 columns]

# %%
#using pop function drop the temporary columns that creaed by deful
Maintable.pop("Unnamed: 0")
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 4765    4765
# 4766    4766
# 4767    4767
# 4768    4768
# 4769    4769
# Name: Unnamed: 0, Length: 4770, dtype: int64

# %%
Maintable.head()
# Out:
#    ID Major area, region, country or area of destination Notes  \
# 0   1                                              WORLD   NaN
# 1   2                                  Developed regions   (b)
# 2   3                                 Developing regions   (c)
# 3   4                          Least developed countries   (d)
# 4   5  Less developed regions excluding least develop...   NaN
#
#   Type of data (a)  International migrant stock at mid-year Gender  Year  \
# 0              NaN                              152563212.0   Both  1990
# 1              NaN                               82378628.0   Both  1990
# 2              NaN                               70184584.0   Both  1990
# 3              NaN                               11075966.0   Both  1990
# 4              NaN                               59105261.0   Both  1990
#
#    International migrant stock as a percentage of the total population(%)  \
# 0                                           2.873310
# 1                                           7.198015
# 2                                           1.685021
# 3                                           2.171513
# 4                                           1.617042
#
#    Female migrants as a percentage of the international migrant stock(%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Annual rate of change of the migrant stock(%)
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN

# %%
#Rearrange the column order to make this new merged table more informative
Maintable=Maintable.iloc[:,[0,1,6,5,4,7,8,9,2,3]]

# %%
Maintable
# Out:
#         ID Major area, region, country or area of destination  Year Gender  \
# 0        1                                              WORLD  1990   Both
# 1        2                                  Developed regions  1990   Both
# 2        3                                 Developing regions  1990   Both
# 3        4                          Least developed countries  1990   Both
# 4        5  Less developed regions excluding least develop...  1990   Both
# ...    ...                                                ...   ...    ...
# 4765  4766                                              Samoa  2015   Male
# 4766  4767                                            Tokelau  2015   Male
# 4767  4768                                              Tonga  2015   Male
# 4768  4769                                             Tuvalu  2015   Male
# 4769  4770                          Wallis and Futuna Islands  2015   Male
#
#       International migrant stock at mid-year  \
# 0                                 152563212.0
# 1                                  82378628.0
# 2                                  70184584.0
# 3                                  11075966.0
# 4                                  59105261.0
# ...                                       ...
# 4765                                   2460.0
# 4766                                    254.0
# 4767                                   2604.0
# 4768                                     63.0
# 4769                                   1411.0
#
#       International migrant stock as a percentage of the total population(%)  \
# 0                                              2.873310
# 1                                              7.198015
# 2                                              1.685021
# 3                                              2.171513
# 4                                              1.617042
# ...                                                 ...
# 4765                                           2.628654
# 4766                                                NaN
# 4767                                           4.919612
# 4768                                                NaN
# 4769                                                NaN
#
#       Female migrants as a percentage of the international migrant stock(%)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4765                                                NaN
# 4766                                                NaN
# 4767                                                NaN
# 4768                                                NaN
# 4769                                                NaN
#
#       Annual rate of change of the migrant stock(%) Notes Type of data (a)
# 0                                               NaN   NaN              NaN
# 1                                               NaN   (b)              NaN
# 2                                               NaN   (c)              NaN
# 3                                               NaN   (d)              NaN
# 4                                               NaN   NaN              NaN
# ...                                             ...   ...              ...
# 4765                                      -0.545343   NaN                B
# 4766                                       2.603250   NaN                B
# 4767                                       2.526318   NaN                B
# 4768                                      -1.819436   NaN                C
# 4769                                       0.516899   NaN                B
#
# [4770 rows x 10 columns]

# %%
Maintable.to_excel("Trends in International Migrants Stock 2015 Revision_maintable.xlsx")
