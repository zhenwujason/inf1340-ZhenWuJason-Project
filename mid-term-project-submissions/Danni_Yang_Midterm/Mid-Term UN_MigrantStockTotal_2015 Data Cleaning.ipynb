# %% [markdown]
# Jupyter notebook link: http://localhost:8888/notebooks/Mid-Term%20UN_MigrantStockTotal_2015%20Data%20Cleaning.ipynb

# %%
# import dependices
import numpy as np
import pandas as pd

# %% [markdown]
# # Table 1 Data Cleaning

# %%
# read original xlsx
df_UN_T1 = pd.read_excel("data/UN_MigrantStockTotal_2015.xlsx", sheet_name = "Table 1")
df_UN_T1.head(20)
# Out:
#      Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0           NaN                                                NaN        NaN
# 1           NaN                                                NaN        NaN
# 2           NaN                                                NaN        NaN
# 3           NaN                                                NaN        NaN
# 4           NaN                                                NaN        NaN
# 5           NaN                                                NaN        NaN
# 6           NaN                                                NaN        NaN
# 7           NaN                                                NaN        NaN
# 8           NaN                                                NaN        NaN
# 9           NaN                                                NaN        NaN
# 10          NaN                                                NaN        NaN
# ...

# %%
# remove the introduction text
df_UN_T1.drop(df_UN_T1.index[0:15], axis=0, inplace=True)
df_UN_T1.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 15          1                                              WORLD        NaN
# 16          2                                  Developed regions        (b)
# 17          3                                 Developing regions        (c)
# 18          4                          Least developed countries        (d)
# 19          5  Less developed regions excluding least develop...        NaN
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 15        900        NaN  152563212  160801752  172703309  191269100
# 16        901        NaN   82378628   92306854  103375363  117181109
# 17        902        NaN   70184584   68494898   69327946   74087991
# 18        941        NaN   11075966   11711703   10077824    9809634
# 19        934        NaN   59105261   56778501   59244124   64272611
#
#      Unnamed: 9  ...  Unnamed: 13 Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# ...

# %%
# check headers
df_UN_T1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22'],
#       dtype='object')

# %%
# remove unnecessary columns 
df_UN_T1.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],inplace=True)
df_UN_T1
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 5  \
# 15           1                                              WORLD  152563212
# 16           2                                  Developed regions   82378628
# 17           3                                 Developing regions   70184584
# 18           4                          Least developed countries   11075966
# 19           5  Less developed regions excluding least develop...   59105261
# ..         ...                                                ...        ...
# 275        261                                              Samoa       3357
# 276        262                                            Tokelau        270
# 277        263                                              Tonga       2911
# 278        264                                             Tuvalu        318
# 279        265                          Wallis and Futuna Islands       1402
#
# ...

# %%
# split 1st sub-dataset sorted by developing status
df_dev = df_UN_T1.iloc[0:5]
df_dev
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 5  \
# 15          1                                              WORLD  152563212
# 16          2                                  Developed regions   82378628
# 17          3                                 Developing regions   70184584
# 18          4                          Least developed countries   11075966
# 19          5  Less developed regions excluding least develop...   59105261
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9  Unnamed: 10 Unnamed: 11  \
# 15  160801752  172703309  191269100  221714243.0  243700236.0    77747510
# 16   92306854  103375363  117181109  132560325.0  140481955.0    40263397
# 17   68494898   69327946   74087991   89153918.0  103218281.0    37484113
# 18   11711703   10077824    9809634   10018128.0   11951316.0     5843107
# 19   56778501   59244124   64272611   79130668.0   91262036.0    31641006
#
# ...

# %%
# rename headers
df_dev = df_dev.rename(columns={'Unnamed: 0': 'Sort Order', 'Unnamed: 1': 'Area','Unnamed: 5': 'b1990','Unnamed: 6': 'b1995',
                                'Unnamed: 7': 'b2000','Unnamed: 8': 'b2005','Unnamed: 9': 'b2010','Unnamed: 10': 'b2015',
                               'Unnamed: 11': 'm1990','Unnamed: 12': 'm1995','Unnamed: 13': 'm2000','Unnamed: 14': 'm2005',
                               'Unnamed: 15': 'm2010','Unnamed: 16': 'm2015','Unnamed: 17': 'f1990','Unnamed: 18': 'f1995',
                               'Unnamed: 19': 'f2000','Unnamed: 20': 'f2005','Unnamed: 21': 'f2010','Unnamed: 22': 'f2015'})                     
df_dev
# Out:
#    Sort Order                                               Area      b1990  \
# 15          1                                              WORLD  152563212
# 16          2                                  Developed regions   82378628
# 17          3                                 Developing regions   70184584
# 18          4                          Least developed countries   11075966
# 19          5  Less developed regions excluding least develop...   59105261
#
#         b1995      b2000      b2005        b2010        b2015     m1990  \
# 15  160801752  172703309  191269100  221714243.0  243700236.0  77747510
# 16   92306854  103375363  117181109  132560325.0  140481955.0  40263397
# 17   68494898   69327946   74087991   89153918.0  103218281.0  37484113
# 18   11711703   10077824    9809634   10018128.0   11951316.0   5843107
# 19   56778501   59244124   64272611   79130668.0   91262036.0  31641006
#
#        m1995     m2000     m2005        m2010        m2015     f1990  \
# ...

# %%
# re-organize the df_dev
df_dev = df_dev.melt(id_vars=["Sort Order","Area"], var_name=["Sexyear"],value_name="International Migrant Stock")
df_dev
# Out:
#    Sort Order                                               Area Sexyear  \
# 0           1                                              WORLD   b1990
# 1           2                                  Developed regions   b1990
# 2           3                                 Developing regions   b1990
# 3           4                          Least developed countries   b1990
# 4           5  Less developed regions excluding least develop...   b1990
# ..        ...                                                ...     ...
# 85          1                                              WORLD   f2015
# 86          2                                  Developed regions   f2015
# 87          3                                 Developing regions   f2015
# 88          4                          Least developed countries   f2015
# 89          5  Less developed regions excluding least develop...   f2015
#
#    International Migrant Stock
# 0                    152563212
# ...

# %%
# split column "Sexyear"
df_dev=(df_dev.assign(gender = lambda x: x.Sexyear.str[0].astype(str), year = lambda x: x.Sexyear.str[1:].astype(str)).drop("Sexyear",axis=1))
df_dev
# Out:
#    Sort Order                                               Area  \
# 0           1                                              WORLD
# 1           2                                  Developed regions
# 2           3                                 Developing regions
# 3           4                          Least developed countries
# 4           5  Less developed regions excluding least develop...
# ..        ...                                                ...
# 85          1                                              WORLD
# 86          2                                  Developed regions
# 87          3                                 Developing regions
# 88          4                          Least developed countries
# 89          5  Less developed regions excluding least develop...
#
#    International Migrant Stock gender  year
# 0                    152563212      b  1990
# 1                     82378628      b  1990
# 2                     70184584      b  1990
# ...

# %%
# Styling the dataset
df_dev=(df_dev.replace(to_replace =["b","m","f"],value =["Both sex","Male","Female"])
            .dropna())
df_dev
# Out:
#     Sort Order                                               Area  \
# 0            1                                              WORLD
# 1            2                                  Developed regions
# 2            3                                 Developing regions
# 3            4                          Least developed countries
# 4            5  Less developed regions excluding least develop...
# ..         ...                                                ...
# 85           1                                              WORLD
# 86           2                                  Developed regions
# 87           3                                 Developing regions
# 88           4                          Least developed countries
# 89           5  Less developed regions excluding least develop...
#
#     International Migrant Stock    gender  year
# 0                   152563212.0  Both sex  1990
# 1                    82378628.0  Both sex  1990
# ...

# %% [markdown]
# df_dev data cleaning completed

# %%
# split 2nd sub-dataset sorted by regions
df_reg = df_UN_T1.loc[[20,21,22,43,53,61,67,85,86,92,100,112,122,141,142,153,167,184,194,195,222,231,246,252,253,256,262,270], :]
df_reg
# Out:
#     Unnamed: 0                       Unnamed: 1 Unnamed: 5 Unnamed: 6  \
# 20           6               Sub-Saharan Africa   14690319   15324570
# 21           7                           Africa   15690623   16352814
# 22           8                   Eastern Africa    5964031    5022742
# 43          29                    Middle Africa    1460530    2646108
# 53          39                  Northern Africa    2403200    2081640
# 61          47                  Southern Africa    1392359    1191582
# 67          53                   Western Africa    4470503    5410742
# 85          71                             Asia   48142261   46548225
# 86          72                     Central Asia    6630683    5890035
# 92          78                     Eastern Asia    3959345    4658475
# 100         86               South-Eastern Asia    2876616    3700057
# 112         98                    Southern Asia   19436343   15343019
# ...

# %%
# rename headers
df_reg = df_reg.rename(columns={'Unnamed: 0': 'Sort Order', 'Unnamed: 1': 'Area','Unnamed: 5': 'b1990','Unnamed: 6': 'b1995',
                                'Unnamed: 7': 'b2000','Unnamed: 8': 'b2005','Unnamed: 9': 'b2010','Unnamed: 10': 'b2015',
                               'Unnamed: 11': 'm1990','Unnamed: 12': 'm1995','Unnamed: 13': 'm2000','Unnamed: 14': 'm2005',
                               'Unnamed: 15': 'm2010','Unnamed: 16': 'm2015','Unnamed: 17': 'f1990','Unnamed: 18': 'f1995',
                               'Unnamed: 19': 'f2000','Unnamed: 20': 'f2005','Unnamed: 21': 'f2010','Unnamed: 22': 'f2015'})                     
df_reg.head()
# Out:
#    Sort Order                Area     b1990     b1995     b2000     b2005  \
# 20          6  Sub-Saharan Africa  14690319  15324570  13716539  13951086
# 21          7              Africa  15690623  16352814  14800306  15191146
# 22          8      Eastern Africa   5964031   5022742   4844795   4745792
# 43         29       Middle Africa   1460530   2646108   1756687   1928828
# 53         39     Northern Africa   2403200   2081640   1885650   1782054
#
#          b2010       b2015    m1990    m1995    m2000    m2005      m2010  \
# 20  15496764.0  18993986.0  7745306  8036824  7210452  7444048  8188581.0
# 21  16840014.0  20649557.0  8279564  8616931  7856358  8231437  9039314.0
# 22   4657063.0   6129113.0  3071189  2585053  2480584  2529460  2366216.0
# 43   2139979.0   2307688.0   744494  1346091   904076   983868  1091761.0
# 53   1921613.0   2159048.0  1230643  1105808  1048954  1063304  1145515.0
#
#          m2015    f1990    f1995    f2000    f2005      f2010      f2015
# ...

# %%
# reorganize the df_reg
df_reg = df_reg.melt(id_vars=["Sort Order","Area"], var_name=["Sexyear"],value_name="International Migrant Stock")
df_reg
# Out:
#     Sort Order                       Area Sexyear International Migrant Stock
# 0            6         Sub-Saharan Africa   b1990                    14690319
# 1            7                     Africa   b1990                    15690623
# 2            8             Eastern Africa   b1990                     5964031
# 3           29              Middle Africa   b1990                     1460530
# 4           39            Northern Africa   b1990                     2403200
# ..         ...                        ...     ...                         ...
# 499        238                    Oceania   f2015                   4101334.0
# 500        239  Australia and New Zealand   f2015                   3963032.0
# 501        242                  Melanesia   f2015                     47782.0
# 502        248                 Micronesia   f2015                     57159.0
# 503        256                  Polynesia   f2015                     33361.0
#
# [504 rows x 4 columns]

# %%
# split column "Sexyear"
df_reg=(df_reg.assign(gender = lambda x: x.Sexyear.str[0].astype(str), year = lambda x: x.Sexyear.str[1:].astype(str)).drop("Sexyear",axis=1))
df_reg
# Out:
#     Sort Order                       Area International Migrant Stock gender  \
# 0            6         Sub-Saharan Africa                    14690319      b
# 1            7                     Africa                    15690623      b
# 2            8             Eastern Africa                     5964031      b
# 3           29              Middle Africa                     1460530      b
# 4           39            Northern Africa                     2403200      b
# ..         ...                        ...                         ...    ...
# 499        238                    Oceania                   4101334.0      f
# 500        239  Australia and New Zealand                   3963032.0      f
# 501        242                  Melanesia                     47782.0      f
# 502        248                 Micronesia                     57159.0      f
# 503        256                  Polynesia                     33361.0      f
#
#      year
# 0    1990
# 1    1990
# ...

# %%
# Styling the dataset
df_reg=(df_reg.replace(to_replace =["b","m","f"],value =["Both sex","Male","Female"])
            .dropna())
df_reg
# Out:
#      Sort Order                       Area  International Migrant Stock  \
# 0             6         Sub-Saharan Africa                   14690319.0
# 1             7                     Africa                   15690623.0
# 2             8             Eastern Africa                    5964031.0
# 3            29              Middle Africa                    1460530.0
# 4            39            Northern Africa                    2403200.0
# ..          ...                        ...                          ...
# 499         238                    Oceania                    4101334.0
# 500         239  Australia and New Zealand                    3963032.0
# 501         242                  Melanesia                      47782.0
# 502         248                 Micronesia                      57159.0
# 503         256                  Polynesia                      33361.0
#
#        gender  year
# 0    Both sex  1990
# 1    Both sex  1990
# 2    Both sex  1990
# ...

# %% [markdown]
# df_reg data cleaning completed

# %%
# split 3rd sub-dataset sorted by countries
df_country = df_UN_T1.drop([15,16,17,18,19,20,21,22,43,53,61,67,85,86,92,100,112,122,141,142,153,167,184,194,195,222,231,246,252,253,256,262,270], inplace=False)
df_country
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 23           9                    Burundi     333110     254853     125628
# 24          10                    Comoros      14079      13939      13799
# 25          11                   Djibouti     122221      99774     100507
# 26          12                    Eritrea      11848      12400      12952
# 27          13                   Ethiopia    1155390     806904     611384
# ..         ...                        ...        ...        ...        ...
# 275        261                      Samoa       3357       4694       5998
# 276        262                    Tokelau        270        266        262
# 277        263                      Tonga       2911       3274       3684
# 278        264                     Tuvalu        318        263        217
# 279        265  Wallis and Futuna Islands       1402       1680       2015
#
# ...

# %%
# rename headers
df_country = df_country.rename(columns={'Unnamed: 0': 'Sort Order', 'Unnamed: 1': 'Area','Unnamed: 5': 'b1990','Unnamed: 6': 'b1995',
                                'Unnamed: 7': 'b2000','Unnamed: 8': 'b2005','Unnamed: 9': 'b2010','Unnamed: 10': 'b2015',
                               'Unnamed: 11': 'm1990','Unnamed: 12': 'm1995','Unnamed: 13': 'm2000','Unnamed: 14': 'm2005',
                               'Unnamed: 15': 'm2010','Unnamed: 16': 'm2015','Unnamed: 17': 'f1990','Unnamed: 18': 'f1995',
                               'Unnamed: 19': 'f2000','Unnamed: 20': 'f2005','Unnamed: 21': 'f2010','Unnamed: 22': 'f2015'})                     
df_country
# Out:
#     Sort Order                       Area    b1990   b1995   b2000   b2005  \
# 23           9                    Burundi   333110  254853  125628  172874
# 24          10                    Comoros    14079   13939   13799   13209
# 25          11                   Djibouti   122221   99774  100507   92091
# 26          12                    Eritrea    11848   12400   12952   14314
# 27          13                   Ethiopia  1155390  806904  611384  514242
# ..         ...                        ...      ...     ...     ...     ...
# 275        261                      Samoa     3357    4694    5998    5746
# 276        262                    Tokelau      270     266     262     258
# 277        263                      Tonga     2911    3274    3684    4301
# 278        264                     Tuvalu      318     263     217     183
# 279        265  Wallis and Futuna Islands     1402    1680    2015    2365
#
# ...

# %%
# reorganize the df_country
df_country = df_country.melt(id_vars=["Sort Order","Area"], var_name=["Sexyear"],value_name="International Migrant Stock")
df_country
# Out:
#      Sort Order                       Area Sexyear International Migrant Stock
# 0             9                    Burundi   b1990                      333110
# 1            10                    Comoros   b1990                       14079
# 2            11                   Djibouti   b1990                      122221
# 3            12                    Eritrea   b1990                       11848
# 4            13                   Ethiopia   b1990                     1155390
# ...         ...                        ...     ...                         ...
# 4171        261                      Samoa   f2015                      2460.0
# 4172        262                    Tokelau   f2015                       254.0
# 4173        263                      Tonga   f2015                      2604.0
# 4174        264                     Tuvalu   f2015                        63.0
# 4175        265  Wallis and Futuna Islands   f2015                      1411.0
#
# [4176 rows x 4 columns]

# %%
# split column "Sexyear"
df_country=(df_country.assign(gender = lambda x: x.Sexyear.str[0].astype(str), year = lambda x: x.Sexyear.str[1:].astype(str)).drop("Sexyear",axis=1))
df_country
# Out:
#      Sort Order                       Area International Migrant Stock gender  \
# 0             9                    Burundi                      333110      b
# 1            10                    Comoros                       14079      b
# 2            11                   Djibouti                      122221      b
# 3            12                    Eritrea                       11848      b
# 4            13                   Ethiopia                     1155390      b
# ...         ...                        ...                         ...    ...
# 4171        261                      Samoa                      2460.0      f
# 4172        262                    Tokelau                       254.0      f
# 4173        263                      Tonga                      2604.0      f
# 4174        264                     Tuvalu                        63.0      f
# 4175        265  Wallis and Futuna Islands                      1411.0      f
#
#       year
# 0     1990
# ...

# %%
# Styling the dataset
df_country=(df_country.replace(to_replace =["b","m","f"],value =["Both sex","Male","Female"])
            .dropna())
df_country
# Out:
#       Sort Order                       Area International Migrant Stock  \
# 0              9                    Burundi                      333110
# 1             10                    Comoros                       14079
# 2             11                   Djibouti                      122221
# 3             12                    Eritrea                       11848
# 4             13                   Ethiopia                     1155390
# ...          ...                        ...                         ...
# 4171         261                      Samoa                      2460.0
# 4172         262                    Tokelau                       254.0
# 4173         263                      Tonga                      2604.0
# 4174         264                     Tuvalu                        63.0
# 4175         265  Wallis and Futuna Islands                      1411.0
#
#         gender  year
# 0     Both sex  1990
# 1     Both sex  1990
# 2     Both sex  1990
# ...

# %%
# replace ".." to NaN
df_country.replace('..', np.nan, inplace = True)
df_country.head(20)
# Out:
#     Sort Order                         Area  International Migrant Stock  \
# 0            9                      Burundi                     333110.0
# 1           10                      Comoros                      14079.0
# 2           11                     Djibouti                     122221.0
# 3           12                      Eritrea                      11848.0
# 4           13                     Ethiopia                    1155390.0
# 5           14                        Kenya                     297292.0
# 6           15                   Madagascar                      23917.0
# 7           16                       Malawi                    1127724.0
# 8           17                    Mauritius                       3613.0
# 9           18                      Mayotte                      15229.0
# 10          19                   Mozambique                     122332.0
# 11          20                      Réunion                      57210.0
# ...

# %%
# replace NaN to 0
df_country.fillna(0, inplace=True)
df_country
# Out:
#       Sort Order                       Area  International Migrant Stock  \
# 0              9                    Burundi                     333110.0
# 1             10                    Comoros                      14079.0
# 2             11                   Djibouti                     122221.0
# 3             12                    Eritrea                      11848.0
# 4             13                   Ethiopia                    1155390.0
# ...          ...                        ...                          ...
# 4171         261                      Samoa                       2460.0
# 4172         262                    Tokelau                        254.0
# 4173         263                      Tonga                       2604.0
# 4174         264                     Tuvalu                         63.0
# 4175         265  Wallis and Futuna Islands                       1411.0
#
#         gender  year
# 0     Both sex  1990
# 1     Both sex  1990
# 2     Both sex  1990
# ...

# %% [markdown]
# df_country data cleaning completed.df_UN_T1 data cleaning completed.

# %% [markdown]
# # Table 2 Data Cleaning

# %%
# read original xlsx
df_UN_T2 = pd.read_excel("data/UN_MigrantStockTotal_2015.xlsx", sheet_name = "Table 2")
df_UN_T2.head(20)
# Out:
#      Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0           NaN                                                NaN        NaN
# 1           NaN                                                NaN        NaN
# 2           NaN                                                NaN        NaN
# 3           NaN                                                NaN        NaN
# 4           NaN                                                NaN        NaN
# 5           NaN                                                NaN        NaN
# 6           NaN                                                NaN        NaN
# 7           NaN                                                NaN        NaN
# 8           NaN                                                NaN        NaN
# 9           NaN                                                NaN        NaN
# 10          NaN                                                NaN        NaN
# ...

# %%
# remove the introduction text
df_UN_T2.drop(df_UN_T2.index[0:15], axis=0, inplace=True)
df_UN_T2.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 15          1                                              WORLD        NaN
# 16          2                                  Developed regions        (b)
# 17          3                                 Developing regions        (c)
# 18          4                          Least developed countries        (d)
# 19          5  Less developed regions excluding least develop...        NaN
#
#    Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6   Unnamed: 7  \
# 15        900  5309667.699  5735123.084  6126622.121  6519635.850
# 16        901  1144463.062  1169761.211  1188811.731  1208919.509
# 17        902  4165204.637  4565361.873  4937810.390  5310716.341
# 18        941   510057.629   585189.354   664386.087   752804.951
# 19        934  3655147.008  3980172.519  4273424.303  4557911.390
#
#      Unnamed: 8   Unnamed: 9  ...  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# ...

# %%
# check headers
df_UN_T2.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21'],
#       dtype='object')

# %%
# remove unnecessary columns 
df_UN_T2.drop(columns=['Unnamed: 2', 'Unnamed: 3'],inplace=True)
df_UN_T2
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 15           1                                              WORLD
# 16           2                                  Developed regions
# 17           3                                 Developing regions
# 18           4                          Least developed countries
# 19           5  Less developed regions excluding least develop...
# ..         ...                                                ...
# 275        261                                              Samoa
# 276        262                                            Tokelau
# 277        263                                              Tonga
# 278        264                                             Tuvalu
# 279        265                          Wallis and Futuna Islands
#
#       Unnamed: 4   Unnamed: 5   Unnamed: 6   Unnamed: 7   Unnamed: 8  \
# 15   5309667.699  5735123.084  6126622.121  6519635.850  6929725.043
# ...

# %%
# split 1st sub-dataset sorted by developing status
df_dev2 = df_UN_T2.iloc[0:5]
df_dev2
# Out:
#    Unnamed: 0                                         Unnamed: 1   Unnamed: 4  \
# 15          1                                              WORLD  5309667.699
# 16          2                                  Developed regions  1144463.062
# 17          3                                 Developing regions  4165204.637
# 18          4                          Least developed countries   510057.629
# 19          5  Less developed regions excluding least develop...  3655147.008
#
#      Unnamed: 5   Unnamed: 6   Unnamed: 7   Unnamed: 8   Unnamed: 9  \
# 15  5735123.084  6126622.121  6519635.850  6929725.043  7349472.099
# 16  1169761.211  1188811.731  1208919.509  1233375.711  1251351.086
# 17  4565361.873  4937810.390  5310716.341  5696349.332  6098121.013
# 18   585189.354   664386.087   752804.951   847254.847   954157.804
# 19  3980172.519  4273424.303  4557911.390  4849094.485  5143963.209
#
#     Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# ...

# %%
# rename headers
df_dev2 = df_dev2.rename(columns={'Unnamed: 0': 'Sort Order', 'Unnamed: 1': 'Area','Unnamed: 4': 'b1990','Unnamed: 5': 'b1995',
                                'Unnamed: 6': 'b2000','Unnamed: 7': 'b2005','Unnamed: 8': 'b2010','Unnamed: 9': 'b2015',
                               'Unnamed: 10': 'm1990','Unnamed: 11': 'm1995','Unnamed: 12': 'm2000','Unnamed: 13': 'm2005',
                               'Unnamed: 14': 'm2010','Unnamed: 15': 'm2015','Unnamed: 16': 'f1990','Unnamed: 17': 'f1995',
                               'Unnamed: 18': 'f2000','Unnamed: 19': 'f2005','Unnamed: 20': 'f2010','Unnamed: 21': 'f2015'})                     
df_dev2
# Out:
#    Sort Order                                               Area        b1990  \
# 15          1                                              WORLD  5309667.699
# 16          2                                  Developed regions  1144463.062
# 17          3                                 Developing regions  4165204.637
# 18          4                          Least developed countries   510057.629
# 19          5  Less developed regions excluding least develop...  3655147.008
#
#           b1995        b2000        b2005        b2010        b2015  \
# 15  5735123.084  6126622.121  6519635.850  6929725.043  7349472.099
# 16  1169761.211  1188811.731  1208919.509  1233375.711  1251351.086
# 17  4565361.873  4937810.390  5310716.341  5696349.332  6098121.013
# 18   585189.354   664386.087   752804.951   847254.847   954157.804
# 19  3980172.519  4273424.303  4557911.390  4849094.485  5143963.209
#
#           m1990        m1995        m2000        m2005        m2010  \
# ...

# %%
# re-organize the df_dev2
df_dev2 = df_dev2.melt(id_vars=["Sort Order","Area"], var_name=["Sexyear"],value_name="Total Population")
df_dev2.head(20)
# Out:
#    Sort Order                                               Area Sexyear  \
# 0           1                                              WORLD   b1990
# 1           2                                  Developed regions   b1990
# 2           3                                 Developing regions   b1990
# 3           4                          Least developed countries   b1990
# 4           5  Less developed regions excluding least develop...   b1990
# 5           1                                              WORLD   b1995
# 6           2                                  Developed regions   b1995
# 7           3                                 Developing regions   b1995
# 8           4                          Least developed countries   b1995
# 9           5  Less developed regions excluding least develop...   b1995
# 10          1                                              WORLD   b2000
# 11          2                                  Developed regions   b2000
# ...

# %%
# split column "Sexyear"
df_dev2=(df_dev2.assign(gender = lambda x: x.Sexyear.str[0].astype(str), year = lambda x: x.Sexyear.str[1:].astype(str)).drop("Sexyear",axis=1))
df_dev2
# Out:
#    Sort Order                                               Area  \
# 0           1                                              WORLD
# 1           2                                  Developed regions
# 2           3                                 Developing regions
# 3           4                          Least developed countries
# 4           5  Less developed regions excluding least develop...
# ..        ...                                                ...
# 85          1                                              WORLD
# 86          2                                  Developed regions
# 87          3                                 Developing regions
# 88          4                          Least developed countries
# 89          5  Less developed regions excluding least develop...
#
#    Total Population gender  year
# 0       5309667.699      b  1990
# 1       1144463.062      b  1990
# 2       4165204.637      b  1990
# 3        510057.629      b  1990
# ...

# %%
# Styling the dataset
df_dev2=(df_dev2.replace(to_replace =["b","m","f"],value =["Both sex","Male","Female"])
            .dropna())
df_dev2
# Out:
#     Sort Order                                               Area  \
# 0            1                                              WORLD
# 1            2                                  Developed regions
# 2            3                                 Developing regions
# 3            4                          Least developed countries
# 4            5  Less developed regions excluding least develop...
# ..         ...                                                ...
# 85           1                                              WORLD
# 86           2                                  Developed regions
# 87           3                                 Developing regions
# 88           4                          Least developed countries
# 89           5  Less developed regions excluding least develop...
#
#     Total Population    gender  year
# 0        5309667.699  Both sex  1990
# 1        1144463.062  Both sex  1990
# 2        4165204.637  Both sex  1990
# ...

# %% [markdown]
# df_dev2 data cleaning completed.

# %%
df_UN_T2.tail(20)
# Out:
#     Unnamed: 0                        Unnamed: 1 Unnamed: 4  Unnamed: 5  \
# 260        246                   Solomon Islands    311.849     359.236
# 261        247                           Vanuatu    146.633     168.236
# 262        248                        Micronesia    414.742     466.608
# 263        249                              Guam    130.482     145.562
# 264        250                          Kiribati     72.411      77.727
# 265        251                  Marshall Islands       47.3      51.020
# 266        252  Micronesia (Federated States of)     96.331     107.556
# 267        253                             Nauru      9.157       9.970
# 268        254          Northern Mariana Islands     43.972      57.518
# 269        255                             Palau     15.089      17.255
# 270        256                         Polynesia    547.869     579.483
# 271        257                    American Samoa     47.044      52.874
# ...

# %%
# split 2rd sub-dataset sorted by regions
df_reg2 = df_UN_T2.loc[[20,21,22,43,53,61,67,85,86,92,100,112,122,141,142,153,167,184,194,195,222,231,246,252,253,256,262,270], :]
df_reg2
# Out:
#     Unnamed: 0                       Unnamed: 1   Unnamed: 4   Unnamed: 5  \
# 20           6               Sub-Saharan Africa   491497.691   562978.224
# 21           7                           Africa   631614.304   720416.386
# 22           8                   Eastern Africa   198231.687   225309.503
# 43          29                    Middle Africa    70886.433    83875.087
# 53          39                  Northern Africa   140116.613   157438.162
# 61          47                  Southern Africa    42049.013    47374.567
# 67          53                   Western Africa   180330.558   206419.067
# 85          71                             Asia  3202474.692  3474848.677
# 86          72                     Central Asia    50405.063    53177.844
# 92          78                     Eastern Asia  1368591.934  1448737.966
# 100         86               South-Eastern Asia    445665.26   486881.244
# 112         98                    Southern Asia  1189260.506  1319395.960
# ...

# %%
# rename headers
df_reg2 = df_reg2.rename(columns={'Unnamed: 0': 'Sort Order', 'Unnamed: 1': 'Area','Unnamed: 4': 'b1990','Unnamed: 5': 'b1995',
                                'Unnamed: 6': 'b2000','Unnamed: 7': 'b2005','Unnamed: 8': 'b2010','Unnamed: 9': 'b2015',
                               'Unnamed: 10': 'm1990','Unnamed: 11': 'm1995','Unnamed: 12': 'm2000','Unnamed: 13': 'm2005',
                               'Unnamed: 14': 'm2010','Unnamed: 15': 'm2015','Unnamed: 16': 'f1990','Unnamed: 17': 'f1995',
                               'Unnamed: 18': 'f2000','Unnamed: 19': 'f2005','Unnamed: 20': 'f2010','Unnamed: 21': 'f2015'})                     
df_reg2
# Out:
#     Sort Order                             Area        b1990        b1995  \
# 20           6               Sub-Saharan Africa   491497.691   562978.224
# 21           7                           Africa   631614.304   720416.386
# 22           8                   Eastern Africa   198231.687   225309.503
# 43          29                    Middle Africa    70886.433    83875.087
# 53          39                  Northern Africa   140116.613   157438.162
# 61          47                  Southern Africa    42049.013    47374.567
# 67          53                   Western Africa   180330.558   206419.067
# 85          71                             Asia  3202474.692  3474848.677
# 86          72                     Central Asia    50405.063    53177.844
# 92          78                     Eastern Asia  1368591.934  1448737.966
# 100         86               South-Eastern Asia    445665.26   486881.244
# 112         98                    Southern Asia  1189260.506  1319395.960
# ...

# %%
# re-organize the df_reg2
df_reg2 = df_reg2.melt(id_vars=["Sort Order","Area"], var_name=["Sexyear"],value_name="Total Population")
df_reg2.head(20)
# Out:
#    Sort Order                             Area Sexyear Total Population
# 0           6               Sub-Saharan Africa   b1990       491497.691
# 1           7                           Africa   b1990       631614.304
# 2           8                   Eastern Africa   b1990       198231.687
# 3          29                    Middle Africa   b1990        70886.433
# 4          39                  Northern Africa   b1990       140116.613
# 5          47                  Southern Africa   b1990        42049.013
# 6          53                   Western Africa   b1990       180330.558
# 7          71                             Asia   b1990      3202474.692
# 8          72                     Central Asia   b1990        50405.063
# 9          78                     Eastern Asia   b1990      1368591.934
# 10         86               South-Eastern Asia   b1990        445665.26
# 11         98                    Southern Asia   b1990      1189260.506
# ...

# %%
# split column "Sexyear"
df_reg2=(df_reg2.assign(gender = lambda x: x.Sexyear.str[0].astype(str), year = lambda x: x.Sexyear.str[1:].astype(str)).drop("Sexyear",axis=1))
df_reg2
# Out:
#     Sort Order                       Area Total Population gender  year
# 0            6         Sub-Saharan Africa       491497.691      b  1990
# 1            7                     Africa       631614.304      b  1990
# 2            8             Eastern Africa       198231.687      b  1990
# 3           29              Middle Africa        70886.433      b  1990
# 4           39            Northern Africa       140116.613      b  1990
# ..         ...                        ...              ...    ...   ...
# 499        238                    Oceania        19624.181      f  2015
# 500        239  Australia and New Zealand        14308.441      f  2015
# 501        242                  Melanesia         4719.309      f  2015
# 502        248                 Micronesia          260.316      f  2015
# 503        256                  Polynesia          336.115      f  2015
#
# [504 rows x 5 columns]

# %%
# Styling the dataset
df_reg2=(df_reg2.replace(to_replace =["b","m","f"],value =["Both sex","Male","Female"])
            .dropna())
df_reg2
# Out:
#      Sort Order                       Area  Total Population    gender  year
# 0             6         Sub-Saharan Africa        491497.691  Both sex  1990
# 1             7                     Africa        631614.304  Both sex  1990
# 2             8             Eastern Africa        198231.687  Both sex  1990
# 3            29              Middle Africa         70886.433  Both sex  1990
# 4            39            Northern Africa        140116.613  Both sex  1990
# ..          ...                        ...               ...       ...   ...
# 499         238                    Oceania         19624.181    Female  2015
# 500         239  Australia and New Zealand         14308.441    Female  2015
# 501         242                  Melanesia          4719.309    Female  2015
# 502         248                 Micronesia           260.316    Female  2015
# 503         256                  Polynesia           336.115    Female  2015
#
# [504 rows x 5 columns]

# %% [markdown]
# df_reg2 data cleaning completed.

# %%
# split 3rd sub-dataset sorted by countries
df_country2 = df_UN_T2.drop([15,16,17,18,19,20,21,22,43,53,61,67,85,86,92,100,112,122,141,142,153,167,184,194,195,222,231,246,252,253,256,262,270], inplace=False)
df_country2
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 23           9                    Burundi   5613.141    6239.030    6767.073
# 24          10                    Comoros    415.144     479.574     547.696
# 25          11                   Djibouti    588.356     661.076     722.562
# 26          12                    Eritrea   3139.083    3164.095    3535.156
# 27          13                   Ethiopia  48057.094   57237.226   66443.603
# ..         ...                        ...        ...         ...         ...
# 275        261                      Samoa    162.865     170.158     174.614
# 276        262                    Tokelau      1.609       1.520       1.552
# 277        263                      Tonga     95.152      95.889      97.898
# 278        264                     Tuvalu      9.004       9.227       9.419
# 279        265  Wallis and Futuna Islands      13.88      14.143      14.497
#
# ...

# %%
# rename headers
df_country2 = df_country2.rename(columns={'Unnamed: 0': 'Sort Order', 'Unnamed: 1': 'Area','Unnamed: 4': 'b1990','Unnamed: 5': 'b1995',
                                'Unnamed: 6': 'b2000','Unnamed: 7': 'b2005','Unnamed: 8': 'b2010','Unnamed: 9': 'b2015',
                               'Unnamed: 10': 'm1990','Unnamed: 11': 'm1995','Unnamed: 12': 'm2000','Unnamed: 13': 'm2005',
                               'Unnamed: 14': 'm2010','Unnamed: 15': 'm2015','Unnamed: 16': 'f1990','Unnamed: 17': 'f1995',
                               'Unnamed: 18': 'f2000','Unnamed: 19': 'f2005','Unnamed: 20': 'f2010','Unnamed: 21': 'f2015'})                     
df_country2
# Out:
#     Sort Order                       Area      b1990      b1995      b2000  \
# 23           9                    Burundi   5613.141   6239.030   6767.073
# 24          10                    Comoros    415.144    479.574    547.696
# 25          11                   Djibouti    588.356    661.076    722.562
# 26          12                    Eritrea   3139.083   3164.095   3535.156
# 27          13                   Ethiopia  48057.094  57237.226  66443.603
# ..         ...                        ...        ...        ...        ...
# 275        261                      Samoa    162.865    170.158    174.614
# 276        262                    Tokelau      1.609      1.520      1.552
# 277        263                      Tonga     95.152     95.889     97.898
# 278        264                     Tuvalu      9.004      9.227      9.419
# 279        265  Wallis and Futuna Islands      13.88     14.143     14.497
#
# ...

# %%
# re-organize the df_reg2
df_country2 = df_country2.melt(id_vars=["Sort Order","Area"], var_name=["Sexyear"],value_name="Total Population")
df_country2.head(20)
# Out:
#    Sort Order                         Area Sexyear Total Population
# 0           9                      Burundi   b1990         5613.141
# 1          10                      Comoros   b1990          415.144
# 2          11                     Djibouti   b1990          588.356
# 3          12                      Eritrea   b1990         3139.083
# 4          13                     Ethiopia   b1990        48057.094
# 5          14                        Kenya   b1990        23446.229
# 6          15                   Madagascar   b1990        11545.782
# 7          16                       Malawi   b1990         9408.998
# 8          17                    Mauritius   b1990         1055.865
# 9          18                      Mayotte   b1990            94.78
# 10         19                   Mozambique   b1990        13371.971
# 11         20                      Réunion   b1990          610.582
# 12         21                       Rwanda   b1990          7259.74
# ...

# %%
# split column "Sexyear"
df_country2=(df_country2.assign(gender = lambda x: x.Sexyear.str[0].astype(str), year = lambda x: x.Sexyear.str[1:].astype(str)).drop("Sexyear",axis=1))
df_country2
# Out:
#      Sort Order                       Area Total Population gender  year
# 0             9                    Burundi         5613.141      b  1990
# 1            10                    Comoros          415.144      b  1990
# 2            11                   Djibouti          588.356      b  1990
# 3            12                    Eritrea         3139.083      b  1990
# 4            13                   Ethiopia        48057.094      b  1990
# ...         ...                        ...              ...    ...   ...
# 4171        261                      Samoa           93.584      f  2015
# 4172        262                    Tokelau               ..      f  2015
# 4173        263                      Tonga           52.931      f  2015
# 4174        264                     Tuvalu               ..      f  2015
# 4175        265  Wallis and Futuna Islands               ..      f  2015
#
# [4176 rows x 5 columns]

# %%
# Styling the dataset
df_country2=(df_country2.replace(to_replace =["b","m","f"],value =["Both sex","Male","Female"])
            .dropna())
df_country2
# Out:
#       Sort Order                       Area Total Population    gender  year
# 0              9                    Burundi         5613.141  Both sex  1990
# 1             10                    Comoros          415.144  Both sex  1990
# 2             11                   Djibouti          588.356  Both sex  1990
# 3             12                    Eritrea         3139.083  Both sex  1990
# 4             13                   Ethiopia        48057.094  Both sex  1990
# ...          ...                        ...              ...       ...   ...
# 4171         261                      Samoa           93.584    Female  2015
# 4172         262                    Tokelau               ..    Female  2015
# 4173         263                      Tonga           52.931    Female  2015
# 4174         264                     Tuvalu               ..    Female  2015
# 4175         265  Wallis and Futuna Islands               ..    Female  2015
#
# [4176 rows x 5 columns]

# %%
# replace ".." to NaN
df_country2.replace('..', np.nan, inplace = True)
df_country2.tail(20)
# Out:
#       Sort Order                              Area  Total Population  gender  \
# 4156         244                     New Caledonia           130.393  Female
# 4157         245                  Papua New Guinea          3732.533  Female
# 4158         246                   Solomon Islands           287.268  Female
# 4159         247                           Vanuatu           130.597  Female
# 4160         249                              Guam            83.732  Female
# 4161         250                          Kiribati            56.999  Female
# 4162         251                  Marshall Islands               NaN  Female
# 4163         252  Micronesia (Federated States of)            50.950  Female
# 4164         253                             Nauru               NaN  Female
# 4165         254          Northern Mariana Islands               NaN  Female
# 4166         255                             Palau               NaN  Female
# ...

# %%
# replace NaN to 0
df_country2.fillna(0, inplace=True)
df_country2
# Out:
#       Sort Order                       Area  Total Population    gender  year
# 0              9                    Burundi          5613.141  Both sex  1990
# 1             10                    Comoros           415.144  Both sex  1990
# 2             11                   Djibouti           588.356  Both sex  1990
# 3             12                    Eritrea          3139.083  Both sex  1990
# 4             13                   Ethiopia         48057.094  Both sex  1990
# ...          ...                        ...               ...       ...   ...
# 4171         261                      Samoa            93.584    Female  2015
# 4172         262                    Tokelau             0.000    Female  2015
# 4173         263                      Tonga            52.931    Female  2015
# 4174         264                     Tuvalu             0.000    Female  2015
# 4175         265  Wallis and Futuna Islands             0.000    Female  2015
#
# [4176 rows x 5 columns]

# %% [markdown]
# df_country2 data cleaning completed. df_UN_T2 data cleaning completed.

# %% [markdown]
# # Table 3 Data Cleaning

# %%
# read original xlsx
df_UN_T3 = pd.read_excel("data/UN_MigrantStockTotal_2015.xlsx", sheet_name = "Table 3")
df_UN_T3.head(20)
# Out:
#      Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0           NaN                                                NaN        NaN
# 1           NaN                                                NaN        NaN
# 2           NaN                                                NaN        NaN
# 3           NaN                                                NaN        NaN
# 4           NaN                                                NaN        NaN
# 5           NaN                                                NaN        NaN
# 6           NaN                                                NaN        NaN
# 7           NaN                                                NaN        NaN
# 8           NaN                                                NaN        NaN
# 9           NaN                                                NaN        NaN
# 10          NaN                                                NaN        NaN
# ...

# %%
# remove the introduction text
df_UN_T3.drop(df_UN_T3.index[0:15], axis=0, inplace=True)
df_UN_T3.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 15          1                                              WORLD        NaN
# 16          2                                  Developed regions        (b)
# 17          3                                 Developing regions        (c)
# 18          4                          Least developed countries        (d)
# 19          5  Less developed regions excluding least develop...        NaN
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 15        900        NaN    2.87331   2.803806   2.818899   2.933739
# 16        901        NaN   7.198015   7.891085   8.695688   9.693045
# 17        902        NaN   1.685021   1.500317   1.404022   1.395066
# 18        941        NaN   2.171513   2.001353   1.516863   1.303078
# 19        934        NaN   1.617042   1.426534   1.386338   1.410133
#
#     Unnamed: 9  ...  Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# ...

# %%
# check headers
df_UN_T3.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22'],
#       dtype='object')

# %%
# remove unnecessary columns 
df_UN_T3.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],inplace=True)
df_UN_T3
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 5  \
# 15           1                                              WORLD    2.87331
# 16           2                                  Developed regions   7.198015
# 17           3                                 Developing regions   1.685021
# 18           4                          Least developed countries   2.171513
# 19           5  Less developed regions excluding least develop...   1.617042
# ..         ...                                                ...        ...
# 275        261                                              Samoa   2.061216
# 276        262                                            Tokelau  16.780609
# 277        263                                              Tonga   3.059316
# 278        264                                             Tuvalu   3.531764
# 279        265                          Wallis and Futuna Islands  10.100865
#
# ...

# %%
# split 1st sub-dataset sorted by developing status
df_dev3 = df_UN_T3.iloc[0:5]
df_dev3
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 5  \
# 15          1                                              WORLD    2.87331
# 16          2                                  Developed regions   7.198015
# 17          3                                 Developing regions   1.685021
# 18          4                          Least developed countries   2.171513
# 19          5  Less developed regions excluding least develop...   1.617042
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  Unnamed: 10 Unnamed: 11  \
# 15   2.803806   2.818899   2.933739    3.199467     3.315888     2.91143
# 16   7.891085   8.695688   9.693045   10.747765    11.226422    7.251326
# 17   1.500317   1.404022   1.395066    1.565106     1.692624    1.772158
# 18   2.001353   1.516863   1.303078    1.182422     1.252551     2.30005
# 19   1.426534   1.386338   1.410133    1.631865     1.774158    1.700101
#
# ...

# %%
# rename headers
df_dev3 = df_dev3.rename(columns={'Unnamed: 0': 'Sort Order', 'Unnamed: 1': 'Area','Unnamed: 5': 'b1990','Unnamed: 6': 'b1995',
                                'Unnamed: 7': 'b2000','Unnamed: 8': 'b2005','Unnamed: 9': 'b2010','Unnamed: 10': 'b2015',
                               'Unnamed: 11': 'm1990','Unnamed: 12': 'm1995','Unnamed: 13': 'm2000','Unnamed: 14': 'm2005',
                               'Unnamed: 15': 'm2010','Unnamed: 16': 'm2015','Unnamed: 17': 'f1990','Unnamed: 18': 'f1995',
                               'Unnamed: 19': 'f2000','Unnamed: 20': 'f2005','Unnamed: 21': 'f2010','Unnamed: 22': 'f2015'})                     
df_dev3
# Out:
#    Sort Order                                               Area     b1990  \
# 15          1                                              WORLD   2.87331
# 16          2                                  Developed regions  7.198015
# 17          3                                 Developing regions  1.685021
# 18          4                          Least developed countries  2.171513
# 19          5  Less developed regions excluding least develop...  1.617042
#
#        b1995     b2000     b2005      b2010      b2015     m1990     m1995  \
# 15  2.803806  2.818899  2.933739   3.199467   3.315888   2.91143  2.831583
# 16  7.891085  8.695688  9.693045  10.747765  11.226422  7.251326  7.935123
# 17  1.500317  1.404022  1.395066   1.565106   1.692624  1.772158  1.580624
# 18  2.001353  1.516863  1.303078   1.182422   1.252551   2.30005  2.103476
# 19  1.426534  1.386338  1.410133   1.631865   1.774158  1.700101  1.505273
#
# ...

# %%
# re-organize the df_dev
df_dev3 = df_dev3.melt(id_vars=["Sort Order","Area"], var_name=["Sexyear"],value_name="International migrant stock as a percentage of the total population")
df_dev3
# Out:
#    Sort Order                                               Area Sexyear  \
# 0           1                                              WORLD   b1990
# 1           2                                  Developed regions   b1990
# 2           3                                 Developing regions   b1990
# 3           4                          Least developed countries   b1990
# 4           5  Less developed regions excluding least develop...   b1990
# ..        ...                                                ...     ...
# 85          1                                              WORLD   f2015
# 86          2                                  Developed regions   f2015
# 87          3                                 Developing regions   f2015
# 88          4                          Least developed countries   f2015
# 89          5  Less developed regions excluding least develop...   f2015
#
#    International migrant stock as a percentage of the total population
# ...

# %%
# split column "Sexyear"
df_dev3=(df_dev3.assign(gender = lambda x: x.Sexyear.str[0].astype(str), year = lambda x: x.Sexyear.str[1:].astype(str)).drop("Sexyear",axis=1))
df_dev3
# Out:
#    Sort Order                                               Area  \
# 0           1                                              WORLD
# 1           2                                  Developed regions
# 2           3                                 Developing regions
# 3           4                          Least developed countries
# 4           5  Less developed regions excluding least develop...
# ..        ...                                                ...
# 85          1                                              WORLD
# 86          2                                  Developed regions
# 87          3                                 Developing regions
# 88          4                          Least developed countries
# 89          5  Less developed regions excluding least develop...
#
#    International migrant stock as a percentage of the total population gender  \
# 0                                             2.87331                       b
# ...

# %%
# Styling the dataset
df_dev3=(df_dev3.replace(to_replace =["b","m","f"],value =["Both sex","Male","Female"])
            .dropna())
df_dev3
# Out:
#     Sort Order                                               Area  \
# 0            1                                              WORLD
# 1            2                                  Developed regions
# 2            3                                 Developing regions
# 3            4                          Least developed countries
# 4            5  Less developed regions excluding least develop...
# ..         ...                                                ...
# 85           1                                              WORLD
# 86           2                                  Developed regions
# 87           3                                 Developing regions
# 88           4                          Least developed countries
# 89           5  Less developed regions excluding least develop...
#
#     International migrant stock as a percentage of the total population  \
# 0                                            2.873310
# ...

# %% [markdown]
# df_dev3 data cleaning completed.

# %%
# split 2nd sub-dataset sorted by regions
df_reg3 = df_UN_T3.loc[[20,21,22,43,53,61,67,85,86,92,100,112,122,141,142,153,167,184,194,195,222,231,246,252,253,256,262,270], :]
df_reg3
# Out:
#     Unnamed: 0                       Unnamed: 1 Unnamed: 5 Unnamed: 6  \
# 20           6               Sub-Saharan Africa   2.988889   2.722054
# 21           7                           Africa    2.48421   2.269911
# 22           8                   Eastern Africa   3.008616   2.229263
# 43          29                    Middle Africa    2.06038    3.15482
# 53          39                  Northern Africa   1.715143   1.322195
# 61          47                  Southern Africa   3.311276   2.515236
# 67          53                   Western Africa    2.47906   2.621241
# 85          71                             Asia   1.503283   1.339576
# 86          72                     Central Asia  13.154796  11.076107
# 92          78                     Eastern Asia   0.289301   0.321554
# 100         86               South-Eastern Asia   0.645466   0.759951
# 112         98                    Southern Asia   1.634322   1.162882
# ...

# %%
# rename headers
df_reg3 = df_reg3.rename(columns={'Unnamed: 0': 'Sort Order', 'Unnamed: 1': 'Area','Unnamed: 5': 'b1990','Unnamed: 6': 'b1995',
                                'Unnamed: 7': 'b2000','Unnamed: 8': 'b2005','Unnamed: 9': 'b2010','Unnamed: 10': 'b2015',
                               'Unnamed: 11': 'm1990','Unnamed: 12': 'm1995','Unnamed: 13': 'm2000','Unnamed: 14': 'm2005',
                               'Unnamed: 15': 'm2010','Unnamed: 16': 'm2015','Unnamed: 17': 'f1990','Unnamed: 18': 'f1995',
                               'Unnamed: 19': 'f2000','Unnamed: 20': 'f2005','Unnamed: 21': 'f2010','Unnamed: 22': 'f2015'})                     
df_reg3.head()
# Out:
#    Sort Order                Area     b1990     b1995     b2000     b2005  \
# 20          6  Sub-Saharan Africa  2.988889  2.722054  2.135959  1.902451
# 21          7              Africa   2.48421  2.269911  1.818078  1.650783
# 22          8      Eastern Africa  3.008616  2.229263   1.86789  1.594493
# 43         29       Middle Africa   2.06038   3.15482  1.827726  1.723508
# 53         39     Northern Africa  1.715143  1.322195  1.097004  0.953392
#
#        b2010     b2015     m1990     m1995     m2000     m2005     m2010  \
# 20  1.843996  1.973838  3.166642  2.868405  2.253275  2.035414  1.951951
# 21  1.612863  1.740848  2.627838  2.397529  1.933132  1.791037  1.732533
# 22  1.358764  1.553730  3.127208  2.316782  1.928733  1.712288  1.389789
# 43  1.638597  1.518698  2.124993   3.24112  1.895932  1.768351   1.67852
# 53  0.943277  0.964328  1.746067  1.395793  1.213971  1.132812  1.120502
#
#        m2015     f1990     f1995     f2000     f2005     f2010     f2015
# ...

# %%
# reorganize the df_reg3
df_reg3 = df_reg3.melt(id_vars=["Sort Order","Area"], var_name=["Sexyear"],value_name="International migrant stock as a percentage of the total population")
df_reg3
# Out:
#     Sort Order                       Area Sexyear  \
# 0            6         Sub-Saharan Africa   b1990
# 1            7                     Africa   b1990
# 2            8             Eastern Africa   b1990
# 3           29              Middle Africa   b1990
# 4           39            Northern Africa   b1990
# ..         ...                        ...     ...
# 499        238                    Oceania   f2015
# 500        239  Australia and New Zealand   f2015
# 501        242                  Melanesia   f2015
# 502        248                 Micronesia   f2015
# 503        256                  Polynesia   f2015
#
#     International migrant stock as a percentage of the total population
# 0                                             2.988889
# 1                                              2.48421
# 2                                             3.008616
# 3                                              2.06038
# 4                                             1.715143
# ...

# %%
# split column "Sexyear"
df_reg3=(df_reg3.assign(gender = lambda x: x.Sexyear.str[0].astype(str), year = lambda x: x.Sexyear.str[1:].astype(str)).drop("Sexyear",axis=1))
df_reg3
# Out:
#     Sort Order                       Area  \
# 0            6         Sub-Saharan Africa
# 1            7                     Africa
# 2            8             Eastern Africa
# 3           29              Middle Africa
# 4           39            Northern Africa
# ..         ...                        ...
# 499        238                    Oceania
# 500        239  Australia and New Zealand
# 501        242                  Melanesia
# 502        248                 Micronesia
# 503        256                  Polynesia
#
#     International migrant stock as a percentage of the total population  \
# 0                                             2.988889
# 1                                              2.48421
# 2                                             3.008616
# 3                                              2.06038
# 4                                             1.715143
# ..                                                 ...
# ...

# %%
# Styling the dataset
df_reg3=(df_reg3.replace(to_replace =["b","m","f"],value =["Both sex","Male","Female"])
            .dropna())
df_reg3
# Out:
#      Sort Order                       Area  \
# 0             6         Sub-Saharan Africa
# 1             7                     Africa
# 2             8             Eastern Africa
# 3            29              Middle Africa
# 4            39            Northern Africa
# ..          ...                        ...
# 499         238                    Oceania
# 500         239  Australia and New Zealand
# 501         242                  Melanesia
# 502         248                 Micronesia
# 503         256                  Polynesia
#
#      International migrant stock as a percentage of the total population  \
# 0                                             2.988889
# 1                                             2.484210
# 2                                             3.008616
# 3                                             2.060380
# 4                                             1.715143
# ..                                                 ...
# ...

# %% [markdown]
# df_reg3 data cleaning completed.

# %%
# split 3rd sub-dataset sorted by countries
df_country3 = df_UN_T3.drop([15,16,17,18,19,20,21,22,43,53,61,67,85,86,92,100,112,122,141,142,153,167,184,194,195,222,231,246,252,253,256,262,270], inplace=False)
df_country3
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 23           9                    Burundi   5.934467   4.084818    1.85646
# 24          10                    Comoros   3.391353   2.906538   2.519463
# 25          11                   Djibouti  20.773307  15.092667   13.90981
# 26          12                    Eritrea   0.377435   0.391897   0.366377
# 27          13                   Ethiopia   2.404203   1.409754   0.920155
# ..         ...                        ...        ...        ...        ...
# 275        261                      Samoa   2.061216   2.758613   3.435005
# 276        262                    Tokelau  16.780609       17.5  16.881443
# 277        263                      Tonga   3.059316   3.414365     3.7631
# 278        264                     Tuvalu   3.531764   2.850331   2.303854
# 279        265  Wallis and Futuna Islands  10.100865  11.878668  13.899427
#
# ...

# %%
# rename headers
df_country3 = df_country3.rename(columns={'Unnamed: 0': 'Sort Order', 'Unnamed: 1': 'Area','Unnamed: 5': 'b1990','Unnamed: 6': 'b1995',
                                'Unnamed: 7': 'b2000','Unnamed: 8': 'b2005','Unnamed: 9': 'b2010','Unnamed: 10': 'b2015',
                               'Unnamed: 11': 'm1990','Unnamed: 12': 'm1995','Unnamed: 13': 'm2000','Unnamed: 14': 'm2005',
                               'Unnamed: 15': 'm2010','Unnamed: 16': 'm2015','Unnamed: 17': 'f1990','Unnamed: 18': 'f1995',
                               'Unnamed: 19': 'f2000','Unnamed: 20': 'f2005','Unnamed: 21': 'f2010','Unnamed: 22': 'f2015'})                     
df_country3
# Out:
#     Sort Order                       Area      b1990      b1995      b2000  \
# 23           9                    Burundi   5.934467   4.084818    1.85646
# 24          10                    Comoros   3.391353   2.906538   2.519463
# 25          11                   Djibouti  20.773307  15.092667   13.90981
# 26          12                    Eritrea   0.377435   0.391897   0.366377
# 27          13                   Ethiopia   2.404203   1.409754   0.920155
# ..         ...                        ...        ...        ...        ...
# 275        261                      Samoa   2.061216   2.758613   3.435005
# 276        262                    Tokelau  16.780609       17.5  16.881443
# 277        263                      Tonga   3.059316   3.414365     3.7631
# 278        264                     Tuvalu   3.531764   2.850331   2.303854
# 279        265  Wallis and Futuna Islands  10.100865  11.878668  13.899427
#
# ...

# %%
# reorganize the df_country3
df_country3 = df_country3.melt(id_vars=["Sort Order","Area"], var_name=["Sexyear"],value_name="International migrant stock as a percentage of the total population")
df_country3
# Out:
#      Sort Order                       Area Sexyear  \
# 0             9                    Burundi   b1990
# 1            10                    Comoros   b1990
# 2            11                   Djibouti   b1990
# 3            12                    Eritrea   b1990
# 4            13                   Ethiopia   b1990
# ...         ...                        ...     ...
# 4171        261                      Samoa   f2015
# 4172        262                    Tokelau   f2015
# 4173        263                      Tonga   f2015
# 4174        264                     Tuvalu   f2015
# 4175        265  Wallis and Futuna Islands   f2015
#
#      International migrant stock as a percentage of the total population
# 0                                              5.934467
# 1                                              3.391353
# 2                                             20.773307
# 3                                              0.377435
# ...

# %%
# split column "Sexyear"
df_country3=(df_country3.assign(gender = lambda x: x.Sexyear.str[0].astype(str), year = lambda x: x.Sexyear.str[1:].astype(str)).drop("Sexyear",axis=1))
df_country3
# Out:
#      Sort Order                       Area  \
# 0             9                    Burundi
# 1            10                    Comoros
# 2            11                   Djibouti
# 3            12                    Eritrea
# 4            13                   Ethiopia
# ...         ...                        ...
# 4171        261                      Samoa
# 4172        262                    Tokelau
# 4173        263                      Tonga
# 4174        264                     Tuvalu
# 4175        265  Wallis and Futuna Islands
#
#      International migrant stock as a percentage of the total population  \
# 0                                              5.934467
# 1                                              3.391353
# 2                                             20.773307
# 3                                              0.377435
# 4                                              2.404203
# ...                                                 ...
# ...

# %%
# Styling the dataset
df_country3=(df_country3.replace(to_replace =["b","m","f"],value =["Both sex","Male","Female"])
            .dropna())
df_country3
# Out:
#       Sort Order                       Area  \
# 0              9                    Burundi
# 1             10                    Comoros
# 2             11                   Djibouti
# 3             12                    Eritrea
# 4             13                   Ethiopia
# ...          ...                        ...
# 4171         261                      Samoa
# 4172         262                    Tokelau
# 4173         263                      Tonga
# 4174         264                     Tuvalu
# 4175         265  Wallis and Futuna Islands
#
#      International migrant stock as a percentage of the total population  \
# 0                                              5.934467
# 1                                              3.391353
# 2                                             20.773307
# 3                                              0.377435
# 4                                              2.404203
# ...                                                 ...
# ...

# %%
# replace ".." to NaN
df_country3.replace('..', np.nan, inplace = True)
df_country3.head(20)
# Out:
#     Sort Order                         Area  \
# 0            9                      Burundi
# 1           10                      Comoros
# 2           11                     Djibouti
# 3           12                      Eritrea
# 4           13                     Ethiopia
# 5           14                        Kenya
# 6           15                   Madagascar
# 7           16                       Malawi
# 8           17                    Mauritius
# 9           18                      Mayotte
# 10          19                   Mozambique
# 11          20                      Réunion
# 12          21                       Rwanda
# 13          22                   Seychelles
# 14          23                      Somalia
# 15          24                  South Sudan
# 16          25                       Uganda
# 17          26  United Republic of Tanzania
# 18          27                       Zambia
# 19          28                     Zimbabwe
#
# ...

# %%
# replace NaN to 0
df_country3.fillna(0, inplace=True)
df_country3
# Out:
#       Sort Order                       Area  \
# 0              9                    Burundi
# 1             10                    Comoros
# 2             11                   Djibouti
# 3             12                    Eritrea
# 4             13                   Ethiopia
# ...          ...                        ...
# 4171         261                      Samoa
# 4172         262                    Tokelau
# 4173         263                      Tonga
# 4174         264                     Tuvalu
# 4175         265  Wallis and Futuna Islands
#
#       International migrant stock as a percentage of the total population  \
# 0                                              5.934467
# 1                                              3.391353
# 2                                             20.773307
# 3                                              0.377435
# 4                                              2.404203
# ...                                                 ...
# ...

# %% [markdown]
# df_country3 data cleaning completed. df_UN_T3 data cleaning completed.

# %% [markdown]
# # Table 4 Data Cleaning

# %%
# read original xlsx
df_UN_T4 = pd.read_excel("data/UN_MigrantStockTotal_2015.xlsx", sheet_name = "Table 4")
df_UN_T4.head(20)
# Out:
#      Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0           NaN                                                NaN        NaN
# 1           NaN                                                NaN        NaN
# 2           NaN                                                NaN        NaN
# 3           NaN                                                NaN        NaN
# 4           NaN                                                NaN        NaN
# 5           NaN                                                NaN        NaN
# 6           NaN                                                NaN        NaN
# 7           NaN                                                NaN        NaN
# 8           NaN                                                NaN        NaN
# 9           NaN                                                NaN        NaN
# 10          NaN                                                NaN        NaN
# ...

# %%
# remove the introduction text
df_UN_T4.drop(df_UN_T4.index[0:15], axis=0, inplace=True)
df_UN_T4.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 15          1                                              WORLD        NaN
# 16          2                                  Developed regions        (b)
# 17          3                                 Developing regions        (c)
# 18          4                          Least developed countries        (d)
# 19          5  Less developed regions excluding least develop...        NaN
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 15        900        NaN   49.03915   49.16879  49.112244  48.832993
# 16        901        NaN  51.123977  51.149024  51.113307  51.171501
# 17        902        NaN  46.592099  46.500135  46.128444  45.134297
# 18        941        NaN  47.261155  47.571664  46.826689  45.157406
# 19        934        NaN  46.466684  46.279022  46.009598  45.130768
#
#     Unnamed: 9  Unnamed: 10
# 15   48.305660    48.249769
# 16   51.658932    51.866687
# ...

# %%
# check headers
df_UN_T4.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10'],
#       dtype='object')

# %%
# remove unnecessary columns 
df_UN_T4.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],inplace=True)
df_UN_T4
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 5  \
# 15           1                                              WORLD   49.03915
# 16           2                                  Developed regions  51.123977
# 17           3                                 Developing regions  46.592099
# 18           4                          Least developed countries  47.261155
# 19           5  Less developed regions excluding least develop...  46.466684
# ..         ...                                                ...        ...
# 275        261                                              Samoa  47.244564
# 276        262                                            Tokelau  44.444444
# 277        263                                              Tonga  48.883545
# 278        264                                             Tuvalu  43.396226
# 279        265                          Wallis and Futuna Islands  48.216833
#
# ...

# %%
# split 1st sub-dataset sorted by developing status
df_dev4 = df_UN_T4.iloc[0:5]
df_dev4
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 5  \
# 15          1                                              WORLD   49.03915
# 16          2                                  Developed regions  51.123977
# 17          3                                 Developing regions  46.592099
# 18          4                          Least developed countries  47.261155
# 19          5  Less developed regions excluding least develop...  46.466684
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  Unnamed: 10
# 15   49.16879  49.112244  48.832993   48.305660    48.249769
# 16  51.149024  51.113307  51.171501   51.658932    51.866687
# 17  46.500135  46.128444  45.134297   43.319780    43.327078
# 18  47.571664  46.826689  45.157406   45.499573    45.942752
# 19  46.279022  46.009598  45.130768   43.043672    42.984398

# %%
# rename headers
df_dev4 = df_dev4.rename(columns={'Unnamed: 0': 'Sort Order', 'Unnamed: 1': 'Area','Unnamed: 5': '1990','Unnamed: 6': '1995',
                                'Unnamed: 7': '2000','Unnamed: 8': '2005','Unnamed: 9': '2010','Unnamed: 10': '2015'})                     
df_dev4
# Out:
#    Sort Order                                               Area       1990  \
# 15          1                                              WORLD   49.03915
# 16          2                                  Developed regions  51.123977
# 17          3                                 Developing regions  46.592099
# 18          4                          Least developed countries  47.261155
# 19          5  Less developed regions excluding least develop...  46.466684
#
#          1995       2000       2005       2010       2015
# 15   49.16879  49.112244  48.832993  48.305660  48.249769
# 16  51.149024  51.113307  51.171501  51.658932  51.866687
# 17  46.500135  46.128444  45.134297  43.319780  43.327078
# 18  47.571664  46.826689  45.157406  45.499573  45.942752
# 19  46.279022  46.009598  45.130768  43.043672  42.984398

# %%
# re-organize the df_dev4
df_dev4 = df_dev4.melt(id_vars=["Sort Order","Area"], var_name=["Year"],value_name="Female migrants as a percentage of the international migrant stock")
df_dev4.head()
# Out:
#   Sort Order                                               Area  Year  \
# 0          1                                              WORLD  1990
# 1          2                                  Developed regions  1990
# 2          3                                 Developing regions  1990
# 3          4                          Least developed countries  1990
# 4          5  Less developed regions excluding least develop...  1990
#
#   Female migrants as a percentage of the international migrant stock
# 0                                           49.03915
# 1                                          51.123977
# 2                                          46.592099
# 3                                          47.261155
# 4                                          46.466684

# %% [markdown]
# df_dev4 data cleaning completed.

# %%
# split 2nd sub-dataset sorted by regions
df_reg4 = df_UN_T4.loc[[20,21,22,43,53,61,67,85,86,92,100,112,122,141,142,153,167,184,194,195,222,231,246,252,253,256,262,270], :]
df_reg4
# Out:
#     Unnamed: 0                       Unnamed: 1 Unnamed: 5 Unnamed: 6  \
# 20           6               Sub-Saharan Africa  47.276121  47.555958
# 21           7                           Africa  47.232408  47.306127
# 22           8                   Eastern Africa  48.504812  48.533032
# 43          29                    Middle Africa  49.025765  49.129401
# 53          39                  Northern Africa  48.791486  46.878038
# 61          47                  Southern Africa  39.606165  40.063378
# 67          53                   Western Africa  46.486134  47.035268
# 85          71                             Asia   45.96873  45.867921
# 86          72                     Central Asia  55.170531  55.253509
# 92          78                     Eastern Asia  49.337933  51.346181
# 100         86               South-Eastern Asia  47.469388  48.200257
# 112         98                    Southern Asia  45.457533  45.367349
# ...

# %%
# rename headers
df_reg4 = df_reg4.rename(columns={'Unnamed: 0': 'Sort Order', 'Unnamed: 1': 'Area','Unnamed: 5': '1990','Unnamed: 6': '1995',
                                'Unnamed: 7': '2000','Unnamed: 8': '2005','Unnamed: 9': '2010','Unnamed: 10': '2015'})                     
df_reg4
# Out:
#     Sort Order                             Area       1990       1995  \
# 20           6               Sub-Saharan Africa  47.276121  47.555958
# 21           7                           Africa  47.232408  47.306127
# 22           8                   Eastern Africa  48.504812  48.533032
# 43          29                    Middle Africa  49.025765  49.129401
# 53          39                  Northern Africa  48.791486  46.878038
# 61          47                  Southern Africa  39.606165  40.063378
# 67          53                   Western Africa  46.486134  47.035268
# 85          71                             Asia   45.96873  45.867921
# 86          72                     Central Asia  55.170531  55.253509
# 92          78                     Eastern Asia  49.337933  51.346181
# 100         86               South-Eastern Asia  47.469388  48.200257
# 112         98                    Southern Asia  45.457533  45.367349
# ...

# %%
# re-organize the df_reg4
df_reg4 = df_reg4.melt(id_vars=["Sort Order","Area"], var_name=["Year"],value_name="Female migrants as a percentage of the international migrant stock")
df_reg4
# Out:
#     Sort Order                       Area  Year  \
# 0            6         Sub-Saharan Africa  1990
# 1            7                     Africa  1990
# 2            8             Eastern Africa  1990
# 3           29              Middle Africa  1990
# 4           39            Northern Africa  1990
# ..         ...                        ...   ...
# 163        238                    Oceania  2015
# 164        239  Australia and New Zealand  2015
# 165        242                  Melanesia  2015
# 166        248                 Micronesia  2015
# 167        256                  Polynesia  2015
#
#     Female migrants as a percentage of the international migrant stock
# 0                                            47.276121
# 1                                            47.232408
# 2                                            48.504812
# 3                                            49.025765
# 4                                            48.791486
# ...

# %% [markdown]
# df_reg4 data cleaning completed.

# %%
# split 3rd sub-dataset sorted by countries
df_country4 = df_UN_T4.drop([15,16,17,18,19,20,21,22,43,53,61,67,85,86,92,100,112,122,141,142,153,167,184,194,195,222,231,246,252,253,256,262,270], inplace=False)
df_country4
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 23           9                    Burundi  50.987061  51.279757  51.369122
# 24          10                    Comoros  52.290646  52.550398  52.815421
# 25          11                   Djibouti  47.437838  47.405136  47.346951
# 26          12                    Eritrea  47.434166  47.241935   47.06609
# 27          13                   Ethiopia  47.439047  47.438977  47.296789
# ..         ...                        ...        ...        ...        ...
# 275        261                      Samoa  47.244564  47.784406  48.299433
# 276        262                    Tokelau  44.444444  44.736842  45.038168
# 277        263                      Tonga  48.883545  47.525962  46.226927
# 278        264                     Tuvalu  43.396226  43.726236  44.239631
# 279        265  Wallis and Futuna Islands  48.216833  48.869048  49.478908
#
#     Unnamed: 8  Unnamed: 9  Unnamed: 10
# ...

# %%
# rename headers
df_country4 = df_country4.rename(columns={'Unnamed: 0': 'Sort Order', 'Unnamed: 1': 'Area','Unnamed: 5': '1990','Unnamed: 6': '1995',
                                'Unnamed: 7': '2000','Unnamed: 8': '2005','Unnamed: 9': '2010','Unnamed: 10': '2015'})                     
df_country4
# Out:
#     Sort Order                       Area       1990       1995       2000  \
# 23           9                    Burundi  50.987061  51.279757  51.369122
# 24          10                    Comoros  52.290646  52.550398  52.815421
# 25          11                   Djibouti  47.437838  47.405136  47.346951
# 26          12                    Eritrea  47.434166  47.241935   47.06609
# 27          13                   Ethiopia  47.439047  47.438977  47.296789
# ..         ...                        ...        ...        ...        ...
# 275        261                      Samoa  47.244564  47.784406  48.299433
# 276        262                    Tokelau  44.444444  44.736842  45.038168
# 277        263                      Tonga  48.883545  47.525962  46.226927
# 278        264                     Tuvalu  43.396226  43.726236  44.239631
# 279        265  Wallis and Futuna Islands  48.216833  48.869048  49.478908
#
#           2005       2010       2015
# ...

# %%
# re-organize the df_reg4
df_country4 = df_country4.melt(id_vars=["Sort Order","Area"], var_name=["Year"],value_name="Female migrants as a percentage of the international migrant stock")
df_country4
# Out:
#      Sort Order                       Area  Year  \
# 0             9                    Burundi  1990
# 1            10                    Comoros  1990
# 2            11                   Djibouti  1990
# 3            12                    Eritrea  1990
# 4            13                   Ethiopia  1990
# ...         ...                        ...   ...
# 1387        261                      Samoa  2015
# 1388        262                    Tokelau  2015
# 1389        263                      Tonga  2015
# 1390        264                     Tuvalu  2015
# 1391        265  Wallis and Futuna Islands  2015
#
#      Female migrants as a percentage of the international migrant stock
# 0                                             50.987061
# 1                                             52.290646
# 2                                             47.437838
# 3                                             47.434166
# 4                                             47.439047
# ...

# %%
# replace ".." to NaN
df_country4.replace('..', np.nan, inplace = True)
df_country4.head(20)
# Out:
#     Sort Order                         Area  Year  \
# 0            9                      Burundi  1990
# 1           10                      Comoros  1990
# 2           11                     Djibouti  1990
# 3           12                      Eritrea  1990
# 4           13                     Ethiopia  1990
# 5           14                        Kenya  1990
# 6           15                   Madagascar  1990
# 7           16                       Malawi  1990
# 8           17                    Mauritius  1990
# 9           18                      Mayotte  1990
# 10          19                   Mozambique  1990
# 11          20                      Réunion  1990
# 12          21                       Rwanda  1990
# 13          22                   Seychelles  1990
# 14          23                      Somalia  1990
# 15          24                  South Sudan  1990
# 16          25                       Uganda  1990
# 17          26  United Republic of Tanzania  1990
# ...

# %%
# replace NaN to 0
df_country4.fillna(0, inplace=True)
df_country4.head(20)
# Out:
#     Sort Order                         Area  Year  \
# 0            9                      Burundi  1990
# 1           10                      Comoros  1990
# 2           11                     Djibouti  1990
# 3           12                      Eritrea  1990
# 4           13                     Ethiopia  1990
# 5           14                        Kenya  1990
# 6           15                   Madagascar  1990
# 7           16                       Malawi  1990
# 8           17                    Mauritius  1990
# 9           18                      Mayotte  1990
# 10          19                   Mozambique  1990
# 11          20                      Réunion  1990
# 12          21                       Rwanda  1990
# 13          22                   Seychelles  1990
# 14          23                      Somalia  1990
# 15          24                  South Sudan  1990
# 16          25                       Uganda  1990
# 17          26  United Republic of Tanzania  1990
# ...

# %% [markdown]
# df_country4 data cleaning completed. df_UN_T4 data cleaning completed.

# %% [markdown]
# # Table 5 Data Cleaning

# %%
# read original xlsx
df_UN_T5 = pd.read_excel("data/UN_MigrantStockTotal_2015.xlsx", sheet_name = "Table 5")
df_UN_T5.head(20)
# Out:
#      Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0           NaN                                                NaN        NaN
# 1           NaN                                                NaN        NaN
# 2           NaN                                                NaN        NaN
# 3           NaN                                                NaN        NaN
# 4           NaN                                                NaN        NaN
# 5           NaN                                                NaN        NaN
# 6           NaN                                                NaN        NaN
# 7           NaN                                                NaN        NaN
# 8           NaN                                                NaN        NaN
# 9           NaN                                                NaN        NaN
# 10          NaN                                                NaN        NaN
# ...

# %%
# remove the introduction text
df_UN_T5.drop(df_UN_T5.index[0:15], axis=0, inplace=True)
df_UN_T5.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 15          1                                              WORLD        NaN
# 16          2                                  Developed regions        (b)
# 17          3                                 Developing regions        (c)
# 18          4                          Least developed countries        (d)
# 19          5  Less developed regions excluding least develop...        NaN
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 15        900        NaN   1.051865   1.428058   2.042124    2.95416
# 16        901        NaN   2.275847   2.264965    2.50708   2.466343
# 17        902        NaN  -0.487389   0.241777   1.328107   3.702217
# 18        941        NaN   1.118175  -3.001139  -0.539636   0.419137
# 19        934        NaN  -0.803244   0.850177    1.62934   4.159339
#
#    Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# ...

# %%
# check headers
df_UN_T5.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19'],
#       dtype='object')

# %%
# remove unnecessary columns 
df_UN_T5.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],inplace=True)
df_UN_T5
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 5  \
# 15           1                                              WORLD   1.051865
# 16           2                                  Developed regions   2.275847
# 17           3                                 Developing regions  -0.487389
# 18           4                          Least developed countries   1.118175
# 19           5  Less developed regions excluding least develop...  -0.803244
# ..         ...                                                ...        ...
# 275        261                                              Samoa   6.704748
# 276        262                                            Tokelau  -0.298513
# 277        263                                              Tonga   2.350316
# 278        264                                             Tuvalu  -3.797947
# 279        265                          Wallis and Futuna Islands    3.61788
#
# ...

# %%
# split 1st sub-dataset sorted by developing status
df_dev5 = df_UN_T5.iloc[0:5]
df_dev5
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 5  \
# 15          1                                              WORLD   1.051865
# 16          2                                  Developed regions   2.275847
# 17          3                                 Developing regions  -0.487389
# 18          4                          Least developed countries   1.118175
# 19          5  Less developed regions excluding least develop...  -0.803244
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 15   1.428058   2.042124    2.95416   1.890991    1.000922    1.450294
# 16   2.264965    2.50708   2.466343   1.160824    2.265595    2.279583
# 17   0.241777   1.328107   3.702217   2.929634    -0.45298    0.380246
# 18  -3.001139  -0.539636   0.419137   3.526927    1.000073   -2.718952
# 19   0.850177    1.62934   4.159339   2.852687   -0.733256    0.950231
#
#    Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17  \
# ...

# %%
# rename headers
df_dev5 = df_dev5.rename(columns={'Unnamed: 0': 'Sort Order', 'Unnamed: 1': 'Area','Unnamed: 5': 'b1990-1995','Unnamed: 6': 'b1995-2000',
                                'Unnamed: 7': 'b2000-2005','Unnamed: 8': 'b2005-2010','Unnamed: 9': 'b2010-2015','Unnamed: 10': 'm1990-1995',
                               'Unnamed: 11': 'm1995-2000','Unnamed: 12': 'm2000-2005','Unnamed: 13': 'm2005-2010','Unnamed: 14': 'm2010-2015',
                               'Unnamed: 15': 'f1990-1995','Unnamed: 16': 'f1995-2000','Unnamed: 17': 'f2000-2005','Unnamed: 18': 'f2005-2010',
                               'Unnamed: 19': 'f2010-2015'})                     
df_dev5
# Out:
#    Sort Order                                               Area b1990-1995  \
# 15          1                                              WORLD   1.051865
# 16          2                                  Developed regions   2.275847
# 17          3                                 Developing regions  -0.487389
# 18          4                          Least developed countries   1.118175
# 19          5  Less developed regions excluding least develop...  -0.803244
#
#    b1995-2000 b2000-2005 b2005-2010 b2010-2015 m1990-1995 m1995-2000  \
# 15   1.428058   2.042124    2.95416   1.890991   1.000922   1.450294
# 16   2.264965    2.50708   2.466343   1.160824   2.265595   2.279583
# 17   0.241777   1.328107   3.702217   2.929634   -0.45298   0.380246
# 18  -3.001139  -0.539636   0.419137   3.526927   1.000073  -2.718952
# 19   0.850177    1.62934   4.159339   2.852687  -0.733256   0.950231
#
#    m2000-2005 m2005-2010 m2010-2015 f1990-1995 f1995-2000 f2000-2005  \
# ...

# %%
# re-organize the df_dev5
df_dev5 = df_dev5.melt(id_vars=["Sort Order","Area"], var_name=["Sexyear"],value_name="Annual rate of change of the migrant stock")
df_dev5
# Out:
#    Sort Order                                               Area     Sexyear  \
# 0           1                                              WORLD  b1990-1995
# 1           2                                  Developed regions  b1990-1995
# 2           3                                 Developing regions  b1990-1995
# 3           4                          Least developed countries  b1990-1995
# 4           5  Less developed regions excluding least develop...  b1990-1995
# ..        ...                                                ...         ...
# 70          1                                              WORLD  f2010-2015
# 71          2                                  Developed regions  f2010-2015
# 72          3                                 Developing regions  f2010-2015
# 73          4                          Least developed countries  f2010-2015
# 74          5  Less developed regions excluding least develop...  f2010-2015
#
# ...

# %%
# split column "Sexyear"
df_dev5=(df_dev5.assign(gender = lambda x: x.Sexyear.str[0].astype(str), year = lambda x: x.Sexyear.str[1:].astype(str)).drop("Sexyear",axis=1))
df_dev5
# Out:
#    Sort Order                                               Area  \
# 0           1                                              WORLD
# 1           2                                  Developed regions
# 2           3                                 Developing regions
# 3           4                          Least developed countries
# 4           5  Less developed regions excluding least develop...
# ..        ...                                                ...
# 70          1                                              WORLD
# 71          2                                  Developed regions
# 72          3                                 Developing regions
# 73          4                          Least developed countries
# 74          5  Less developed regions excluding least develop...
#
#    Annual rate of change of the migrant stock gender       year
# 0                                    1.051865      b  1990-1995
# ...

# %%
# Styling the dataset
df_dev5=(df_dev5.replace(to_replace =["b","m","f"],value =["Both sex","Male","Female"])
            .dropna())
df_dev5
# Out:
#     Sort Order                                               Area  \
# 0            1                                              WORLD
# 1            2                                  Developed regions
# 2            3                                 Developing regions
# 3            4                          Least developed countries
# 4            5  Less developed regions excluding least develop...
# ..         ...                                                ...
# 70           1                                              WORLD
# 71           2                                  Developed regions
# 72           3                                 Developing regions
# 73           4                          Least developed countries
# 74           5  Less developed regions excluding least develop...
#
#     Annual rate of change of the migrant stock    gender       year
# 0                                     1.051865  Both sex  1990-1995
# ...

# %% [markdown]
# df_dev5 data cleaning completed.

# %%
# split 2nd sub-dataset sorted by regions
df_reg5 = df_UN_T5.loc[[20,21,22,43,53,61,67,85,86,92,100,112,122,141,142,153,167,184,194,195,222,231,246,252,253,256,262,270], :]
df_reg5
# Out:
#     Unnamed: 0                       Unnamed: 1 Unnamed: 5 Unnamed: 6  \
# 20           6               Sub-Saharan Africa   0.845374  -2.217102
# 21           7                           Africa   0.826734  -1.995043
# 22           8                   Eastern Africa  -3.435412  -0.721421
# 43          29                    Middle Africa   11.88581  -8.193205
# 53          39                  Northern Africa  -2.872903  -1.977669
# 61          47                  Southern Africa  -3.114352   0.509279
# 67          53                   Western Africa   3.817706  -1.218789
# 85          71                             Asia  -0.673431   1.165255
# 86          72                     Central Asia  -2.368918  -2.554193
# 92          78                     Eastern Asia   3.252191   2.928574
# 100         86               South-Eastern Asia   5.034672   5.726963
# 112         98                    Southern Asia  -4.729682  -0.084908
# ...

# %%
# rename headers
df_reg5 = df_reg5.rename(columns={'Unnamed: 0': 'Sort Order', 'Unnamed: 1': 'Area','Unnamed: 5': 'b1990-1995','Unnamed: 6': 'b1995-2000',
                                'Unnamed: 7': 'b2000-2005','Unnamed: 8': 'b2005-2010','Unnamed: 9': 'b2010-2015','Unnamed: 10': 'm1990-1995',
                               'Unnamed: 11': 'm1995-2000','Unnamed: 12': 'm2000-2005','Unnamed: 13': 'm2005-2010','Unnamed: 14': 'm2010-2015',
                               'Unnamed: 15': 'f1990-1995','Unnamed: 16': 'f1995-2000','Unnamed: 17': 'f2000-2005','Unnamed: 18': 'f2005-2010',
                               'Unnamed: 19': 'f2010-2015'})                     
df_reg5
# Out:
#     Sort Order                             Area b1990-1995 b1995-2000  \
# 20           6               Sub-Saharan Africa   0.845374  -2.217102
# 21           7                           Africa   0.826734  -1.995043
# 22           8                   Eastern Africa  -3.435412  -0.721421
# 43          29                    Middle Africa   11.88581  -8.193205
# 53          39                  Northern Africa  -2.872903  -1.977669
# 61          47                  Southern Africa  -3.114352   0.509279
# 67          53                   Western Africa   3.817706  -1.218789
# 85          71                             Asia  -0.673431   1.165255
# 86          72                     Central Asia  -2.368918  -2.554193
# 92          78                     Eastern Asia   3.252191   2.928574
# 100         86               South-Eastern Asia   5.034672   5.726963
# 112         98                    Southern Asia  -4.729682  -0.084908
# ...

# %%
# re-organize the df_dev5
df_reg5 = df_reg5.melt(id_vars=["Sort Order","Area"], var_name=["Sexyear"],value_name="Annual rate of change of the migrant stock")
df_reg5
# Out:
#     Sort Order                       Area     Sexyear  \
# 0            6         Sub-Saharan Africa  b1990-1995
# 1            7                     Africa  b1990-1995
# 2            8             Eastern Africa  b1990-1995
# 3           29              Middle Africa  b1990-1995
# 4           39            Northern Africa  b1990-1995
# ..         ...                        ...         ...
# 415        238                    Oceania  f2010-2015
# 416        239  Australia and New Zealand  f2010-2015
# 417        242                  Melanesia  f2010-2015
# 418        248                 Micronesia  f2010-2015
# 419        256                  Polynesia  f2010-2015
#
#     Annual rate of change of the migrant stock
# 0                                     0.845374
# 1                                     0.826734
# 2                                    -3.435412
# 3                                     11.88581
# 4                                    -2.872903
# ...

# %%
# split column "Sexyear"
df_reg5=(df_reg5.assign(gender = lambda x: x.Sexyear.str[0].astype(str), year = lambda x: x.Sexyear.str[1:].astype(str)).drop("Sexyear",axis=1))
df_reg5
# Out:
#     Sort Order                       Area  \
# 0            6         Sub-Saharan Africa
# 1            7                     Africa
# 2            8             Eastern Africa
# 3           29              Middle Africa
# 4           39            Northern Africa
# ..         ...                        ...
# 415        238                    Oceania
# 416        239  Australia and New Zealand
# 417        242                  Melanesia
# 418        248                 Micronesia
# 419        256                  Polynesia
#
#     Annual rate of change of the migrant stock gender       year
# 0                                     0.845374      b  1990-1995
# 1                                     0.826734      b  1990-1995
# 2                                    -3.435412      b  1990-1995
# 3                                     11.88581      b  1990-1995
# 4                                    -2.872903      b  1990-1995
# ...

# %%
# Styling the dataset
df_reg5=(df_reg5.replace(to_replace =["b","m","f"],value =["Both sex","Male","Female"])
            .dropna())
df_reg5
# Out:
#      Sort Order                       Area  \
# 0             6         Sub-Saharan Africa
# 1             7                     Africa
# 2             8             Eastern Africa
# 3            29              Middle Africa
# 4            39            Northern Africa
# ..          ...                        ...
# 415         238                    Oceania
# 416         239  Australia and New Zealand
# 417         242                  Melanesia
# 418         248                 Micronesia
# 419         256                  Polynesia
#
#      Annual rate of change of the migrant stock    gender       year
# 0                                      0.845374  Both sex  1990-1995
# 1                                      0.826734  Both sex  1990-1995
# 2                                     -3.435412  Both sex  1990-1995
# 3                                     11.885810  Both sex  1990-1995
# 4                                     -2.872903  Both sex  1990-1995
# ...

# %% [markdown]
# df_reg5 data cleaning completed.

# %%
# split 3rd sub-dataset sorted by countries
df_country5 = df_UN_T5.drop([15,16,17,18,19,20,21,22,43,53,61,67,85,86,92,100,112,122,141,142,153,167,184,194,195,222,231,246,252,253,256,262,270], inplace=False)
df_country5
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 23           9                    Burundi  -5.355717 -14.147235   6.384757
# 24          10                    Comoros  -0.199873  -0.201891  -0.873954
# 25          11                   Djibouti  -4.058465   0.146395  -1.749003
# 26          12                    Eritrea   0.910748   0.871075   1.999757
# 27          13                   Ethiopia  -7.179771  -5.549589  -3.460625
# ..         ...                        ...        ...        ...        ...
# 275        261                      Samoa   6.704748    4.90282  -0.858442
# 276        262                    Tokelau  -0.298513  -0.303036  -0.307698
# 277        263                      Tonga   2.350316   2.359733   3.096969
# 278        264                     Tuvalu  -3.797947  -3.845134  -3.408224
# 279        265  Wallis and Futuna Islands    3.61788   3.636508   3.203177
#
# ...

# %%
# rename headers
df_country5 = df_country5.rename(columns={'Unnamed: 0': 'Sort Order', 'Unnamed: 1': 'Area','Unnamed: 5': 'b1990-1995','Unnamed: 6': 'b1995-2000',
                                'Unnamed: 7': 'b2000-2005','Unnamed: 8': 'b2005-2010','Unnamed: 9': 'b2010-2015','Unnamed: 10': 'm1990-1995',
                               'Unnamed: 11': 'm1995-2000','Unnamed: 12': 'm2000-2005','Unnamed: 13': 'm2005-2010','Unnamed: 14': 'm2010-2015',
                               'Unnamed: 15': 'f1990-1995','Unnamed: 16': 'f1995-2000','Unnamed: 17': 'f2000-2005','Unnamed: 18': 'f2005-2010',
                               'Unnamed: 19': 'f2010-2015'})                     
df_country5
# Out:
#     Sort Order                       Area b1990-1995 b1995-2000 b2000-2005  \
# 23           9                    Burundi  -5.355717 -14.147235   6.384757
# 24          10                    Comoros  -0.199873  -0.201891  -0.873954
# 25          11                   Djibouti  -4.058465   0.146395  -1.749003
# 26          12                    Eritrea   0.910748   0.871075   1.999757
# 27          13                   Ethiopia  -7.179771  -5.549589  -3.460625
# ..         ...                        ...        ...        ...        ...
# 275        261                      Samoa   6.704748    4.90282  -0.858442
# 276        262                    Tokelau  -0.298513  -0.303036  -0.307698
# 277        263                      Tonga   2.350316   2.359733   3.096969
# 278        264                     Tuvalu  -3.797947  -3.845134  -3.408224
# 279        265  Wallis and Futuna Islands    3.61788   3.636508   3.203177
#
# ...

# %%
# re-organize the df_dev5
df_country5 = df_country5.melt(id_vars=["Sort Order","Area"], var_name=["Sexyear"],value_name="Annual rate of change of the migrant stock")
df_country5
# Out:
#      Sort Order                       Area     Sexyear  \
# 0             9                    Burundi  b1990-1995
# 1            10                    Comoros  b1990-1995
# 2            11                   Djibouti  b1990-1995
# 3            12                    Eritrea  b1990-1995
# 4            13                   Ethiopia  b1990-1995
# ...         ...                        ...         ...
# 3475        261                      Samoa  f2010-2015
# 3476        262                    Tokelau  f2010-2015
# 3477        263                      Tonga  f2010-2015
# 3478        264                     Tuvalu  f2010-2015
# 3479        265  Wallis and Futuna Islands  f2010-2015
#
#      Annual rate of change of the migrant stock
# 0                                     -5.355717
# 1                                     -0.199873
# 2                                     -4.058465
# 3                                      0.910748
# 4                                     -7.179771
# ...

# %%
# split column "Sexyear"
df_country5=(df_country5.assign(gender = lambda x: x.Sexyear.str[0].astype(str), year = lambda x: x.Sexyear.str[1:].astype(str)).drop("Sexyear",axis=1))
df_country5
# Out:
#      Sort Order                       Area  \
# 0             9                    Burundi
# 1            10                    Comoros
# 2            11                   Djibouti
# 3            12                    Eritrea
# 4            13                   Ethiopia
# ...         ...                        ...
# 3475        261                      Samoa
# 3476        262                    Tokelau
# 3477        263                      Tonga
# 3478        264                     Tuvalu
# 3479        265  Wallis and Futuna Islands
#
#      Annual rate of change of the migrant stock gender       year
# 0                                     -5.355717      b  1990-1995
# 1                                     -0.199873      b  1990-1995
# 2                                     -4.058465      b  1990-1995
# 3                                      0.910748      b  1990-1995
# 4                                     -7.179771      b  1990-1995
# ...

# %%
# Styling the dataset
df_country5=(df_country5.replace(to_replace =["b","m","f"],value =["Both sex","Male","Female"])
            .dropna())
df_country5
# Out:
#       Sort Order                       Area  \
# 0              9                    Burundi
# 1             10                    Comoros
# 2             11                   Djibouti
# 3             12                    Eritrea
# 4             13                   Ethiopia
# ...          ...                        ...
# 3475         261                      Samoa
# 3476         262                    Tokelau
# 3477         263                      Tonga
# 3478         264                     Tuvalu
# 3479         265  Wallis and Futuna Islands
#
#      Annual rate of change of the migrant stock    gender       year
# 0                                     -5.355717  Both sex  1990-1995
# 1                                     -0.199873  Both sex  1990-1995
# 2                                     -4.058465  Both sex  1990-1995
# 3                                      0.910748  Both sex  1990-1995
# 4                                     -7.179771  Both sex  1990-1995
# ...

# %%
# replace ".." to NaN
df_country5.replace('..', np.nan, inplace = True)
df_country5.head(20)
# Out:
#     Sort Order                         Area  \
# 0            9                      Burundi
# 1           10                      Comoros
# 2           11                     Djibouti
# 3           12                      Eritrea
# 4           13                     Ethiopia
# 5           14                        Kenya
# 6           15                   Madagascar
# 7           16                       Malawi
# 8           17                    Mauritius
# 9           18                      Mayotte
# 10          19                   Mozambique
# 11          20                      Réunion
# 12          21                       Rwanda
# 13          22                   Seychelles
# 14          23                      Somalia
# 15          24                  South Sudan
# 16          25                       Uganda
# 17          26  United Republic of Tanzania
# 18          27                       Zambia
# 19          28                     Zimbabwe
#
# ...

# %%
# replace NaN to 0
df_country5.fillna(0, inplace=True)
df_country5.head(20)
# Out:
#     Sort Order                         Area  \
# 0            9                      Burundi
# 1           10                      Comoros
# 2           11                     Djibouti
# 3           12                      Eritrea
# 4           13                     Ethiopia
# 5           14                        Kenya
# 6           15                   Madagascar
# 7           16                       Malawi
# 8           17                    Mauritius
# 9           18                      Mayotte
# 10          19                   Mozambique
# 11          20                      Réunion
# 12          21                       Rwanda
# 13          22                   Seychelles
# 14          23                      Somalia
# 15          24                  South Sudan
# 16          25                       Uganda
# 17          26  United Republic of Tanzania
# 18          27                       Zambia
# 19          28                     Zimbabwe
#
# ...

# %% [markdown]
# df_country5 data cleaning completed. df_UN_T5 data cleaning completed.

# %% [markdown]
# # Table 6 Data Cleaning

# %%
# read original xlsx
df_UN_T6 = pd.read_excel("data/UN_MigrantStockTotal_2015.xlsx", sheet_name = "Table 6")
df_UN_T6.head(20)
# Out:
#      Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0           NaN                                                NaN        NaN
# 1           NaN                                                NaN        NaN
# 2           NaN                                                NaN        NaN
# 3           NaN                                                NaN        NaN
# 4           NaN                                                NaN        NaN
# 5           NaN                                                NaN        NaN
# 6           NaN                                                NaN        NaN
# 7           NaN                                                NaN        NaN
# 8           NaN                                                NaN        NaN
# 9           NaN                                                NaN        NaN
# 10          NaN                                                NaN        NaN
# ...

# %%
# remove the introduction text
df_UN_T6.drop(df_UN_T6.index[0:15], axis=0, inplace=True)
df_UN_T6.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 15          1                                              WORLD        NaN
# 16          2                                  Developed regions        (b)
# 17          3                                 Developing regions        (c)
# 18          4                          Least developed countries        (d)
# 19          5  Less developed regions excluding least develop...        NaN
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 15        900        NaN   18836571   17853840   15827803   13276733
# 16        901        NaN    2014564    3609670    2997256    2361229
# 17        902        NaN   16822007   14244170   12830547   10915504
# 18        941        NaN    5048391    5160131    3047488    2363782
# 19        934        NaN   11773616    9084039    9783059    8551722
#
#     Unnamed: 9  ...  Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# ...

# %%
# check headers
df_UN_T6.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21'],
#       dtype='object')

# %%
# remove unnecessary columns 
df_UN_T6.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],inplace=True)
df_UN_T6
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 5  \
# 15           1                                              WORLD   18836571
# 16           2                                  Developed regions    2014564
# 17           3                                 Developing regions   16822007
# 18           4                          Least developed countries    5048391
# 19           5  Less developed regions excluding least develop...   11773616
# ..         ...                                                ...        ...
# 275        261                                              Samoa          0
# 276        262                                            Tokelau          0
# 277        263                                              Tonga          0
# 278        264                                             Tuvalu          0
# 279        265                          Wallis and Futuna Islands          0
#
# ...

# %%
# rename headers
df_UN_T6 = df_UN_T6.rename(columns={'Unnamed: 0': 'Sort Order', 'Unnamed: 1': 'Area','Unnamed: 5': 'e1990','Unnamed: 6': 'e1995',
                                'Unnamed: 7': 'e2000','Unnamed: 8': 'e2005','Unnamed: 9': 'e2010','Unnamed: 10': 'e2015',
                               'Unnamed: 11': 'p1990','Unnamed: 12': 'p1995','Unnamed: 13': 'p2000','Unnamed: 14': 'p2005',
                               'Unnamed: 15': 'p2010','Unnamed: 16': 'p2015','Unnamed: 17': 'c1990-1995','Unnamed: 18': 'c1995-2000',
                               'Unnamed: 19': 'c2000-2005','Unnamed: 20': 'c2005-2010','Unnamed: 21': 'c2010-2015'})                     
df_UN_T6
# Out:
#     Sort Order                                               Area     e1990  \
# 15           1                                              WORLD  18836571
# 16           2                                  Developed regions   2014564
# 17           3                                 Developing regions  16822007
# 18           4                          Least developed countries   5048391
# 19           5  Less developed regions excluding least develop...  11773616
# ..         ...                                                ...       ...
# 275        261                                              Samoa         0
# 276        262                                            Tokelau         0
# 277        263                                              Tonga         0
# 278        264                                             Tuvalu         0
# 279        265                          Wallis and Futuna Islands         0
#
# ...

# %%
# split 1st sub-dataset sorted by developing status
df_dev6 = df_UN_T6.loc[15:19]
df_dev6
# Out:
#    Sort Order                                               Area     e1990  \
# 15          1                                              WORLD  18836571
# 16          2                                  Developed regions   2014564
# 17          3                                 Developing regions  16822007
# 18          4                          Least developed countries   5048391
# 19          5  Less developed regions excluding least develop...  11773616
#
#        e1995     e2000     e2005       e2010       e2015      p1990  \
# 15  17853840  15827803  13276733  15370755.0  19577474.0  12.346732
# 16   3609670   2997256   2361229   2046917.0   1954224.0   2.445494
# 17  14244170  12830547  10915504  13323838.0  17623250.0  23.968236
# 18   5160131   3047488   2363782   1957884.0   3443582.0   45.56588
# 19   9084039   9783059   8551722  11365954.0  14179668.0  19.919743
#
#         p1995      p2000      p2005      p2010      p2015 c1990-1995  \
# ...

# %%
# re-organize the df_dev
df_dev6 = df_dev6.melt(id_vars=["Sort Order","Area"], var_name=["epcyear"],value_name="Value")
df_dev6
# Out:
#    Sort Order                                               Area     epcyear  \
# 0           1                                              WORLD       e1990
# 1           2                                  Developed regions       e1990
# 2           3                                 Developing regions       e1990
# 3           4                          Least developed countries       e1990
# 4           5  Less developed regions excluding least develop...       e1990
# ..        ...                                                ...         ...
# 80          1                                              WORLD  c2010-2015
# 81          2                                  Developed regions  c2010-2015
# 82          3                                 Developing regions  c2010-2015
# 83          4                          Least developed countries  c2010-2015
# 84          5  Less developed regions excluding least develop...  c2010-2015
#
#        Value
# 0   18836571
# 1    2014564
# ...

# %%
# split column "epcyear"
df_dev6=(df_dev6.assign(Type = lambda x: x.epcyear.str[0].astype(str), year = lambda x: x.epcyear.str[1:].astype(str)).drop("epcyear",axis=1))
df_dev6
# Out:
#    Sort Order                                               Area     Value  \
# 0           1                                              WORLD  18836571
# 1           2                                  Developed regions   2014564
# 2           3                                 Developing regions  16822007
# 3           4                          Least developed countries   5048391
# 4           5  Less developed regions excluding least develop...  11773616
# ..        ...                                                ...       ...
# 80          1                                              WORLD  2.947267
# 81          2                                  Developed regions -2.087656
# 82          3                                 Developing regions  2.663652
# 83          4                          Least developed countries  7.766031
# 84          5  Less developed regions excluding least develop...  1.571047
#
#    Type       year
# 0     e       1990
# 1     e       1990
# ...

# %%
# Styling the dataset
df_dev6=(df_dev6.replace(to_replace =["e","p","c"],value =["Estimated refugee stock","Refugees as a percentage of the international migrant stock","Annual rate of change of the refugee stock"])
            .dropna())
df_dev6
# Out:
#     Sort Order                                               Area  \
# 0            1                                              WORLD
# 1            2                                  Developed regions
# 2            3                                 Developing regions
# 3            4                          Least developed countries
# 4            5  Less developed regions excluding least develop...
# ..         ...                                                ...
# 80           1                                              WORLD
# 81           2                                  Developed regions
# 82           3                                 Developing regions
# 83           4                          Least developed countries
# 84           5  Less developed regions excluding least develop...
#
#            Value                                        Type       year
# 0   1.883657e+07                     Estimated refugee stock       1990
# ...

# %% [markdown]
# df_dev6 data cleaning completed.

# %%
# split 2nd sub-dataset sorted by regions
df_reg6 = df_UN_T6.loc[[20,21,22,43,53,61,67,85,86,92,100,112,122,141,142,153,167,184,194,195,222,231,246,252,253,256,262,270], :]
df_reg6
# Out:
#     Sort Order                             Area    e1990    e1995    e2000  \
# 20           6               Sub-Saharan Africa  5516042  5747830  3421165
# 21           7                           Africa  5687352  5949953  3609138
# 22           8                   Eastern Africa  3168001  2046088  1641559
# 43          29                    Middle Africa   446609  1547169   606067
# 53          39                  Northern Africa  1202360   876194   602901
# 61          47                  Southern Africa   135525   105184    46568
# 67          53                   Western Africa   734857  1375318   712043
# 85          71                             Asia  9937007  7937682  9175210
# 86          72                     Central Asia     3000    40778    96316
# 92          78                     Eastern Asia   302529   300610   298442
# 100         86               South-Eastern Asia   157977   165400   314169
# ...

# %%
# re-organize the df_dev
df_reg6 = df_reg6.melt(id_vars=["Sort Order","Area"], var_name=["epcyear"],value_name="Value")
df_reg6
# Out:
#     Sort Order                       Area     epcyear     Value
# 0            6         Sub-Saharan Africa       e1990   5516042
# 1            7                     Africa       e1990   5687352
# 2            8             Eastern Africa       e1990   3168001
# 3           29              Middle Africa       e1990    446609
# 4           39            Northern Africa       e1990   1202360
# ..         ...                        ...         ...       ...
# 471        238                    Oceania  c2010-2015  7.804057
# 472        239  Australia and New Zealand  c2010-2015  8.829439
# 473        242                  Melanesia  c2010-2015 -0.268521
# 474        248                 Micronesia  c2010-2015        ..
# 475        256                  Polynesia  c2010-2015        ..
#
# [476 rows x 4 columns]

# %%
# split column "epcyear"
df_reg6=(df_reg6.assign(Type = lambda x: x.epcyear.str[0].astype(str), year = lambda x: x.epcyear.str[1:].astype(str)).drop("epcyear",axis=1))
df_reg6
# Out:
#     Sort Order                       Area     Value Type       year
# 0            6         Sub-Saharan Africa   5516042    e       1990
# 1            7                     Africa   5687352    e       1990
# 2            8             Eastern Africa   3168001    e       1990
# 3           29              Middle Africa    446609    e       1990
# 4           39            Northern Africa   1202360    e       1990
# ..         ...                        ...       ...  ...        ...
# 471        238                    Oceania  7.804057    c  2010-2015
# 472        239  Australia and New Zealand  8.829439    c  2010-2015
# 473        242                  Melanesia -0.268521    c  2010-2015
# 474        248                 Micronesia        ..    c  2010-2015
# 475        256                  Polynesia        ..    c  2010-2015
#
# [476 rows x 5 columns]

# %%
# Styling the dataset
df_reg6=(df_reg6.replace(to_replace =["e","p","c"],value =["Estimated refugee stock","Refugees as a percentage of the international migrant stock","Annual rate of change of the refugee stock"])
            .dropna())
df_reg6
# Out:
#      Sort Order                       Area     Value  \
# 0             6         Sub-Saharan Africa   5516042
# 1             7                     Africa   5687352
# 2             8             Eastern Africa   3168001
# 3            29              Middle Africa    446609
# 4            39            Northern Africa   1202360
# ..          ...                        ...       ...
# 471         238                    Oceania  7.804057
# 472         239  Australia and New Zealand  8.829439
# 473         242                  Melanesia -0.268521
# 474         248                 Micronesia        ..
# 475         256                  Polynesia        ..
#
#                                            Type       year
# 0                       Estimated refugee stock       1990
# 1                       Estimated refugee stock       1990
# 2                       Estimated refugee stock       1990
# 3                       Estimated refugee stock       1990
# ...

# %% [markdown]
# df_reg6 data cleaning completed.

# %%
# split 3rd sub-dataset sorted by countries
df_country6 = df_UN_T6.drop([15,16,17,18,19,20,21,22,43,53,61,67,85,86,92,100,112,122,141,142,153,167,184,194,195,222,231,246,252,253,256,262,270], inplace=False)
df_country6
# Out:
#     Sort Order                       Area   e1990   e1995   e2000   e2005  \
# 23           9                    Burundi  267929  173017   27136   20681
# 24          10                    Comoros       0       5      10       5
# 25          11                   Djibouti   54508   27310   23257   10456
# 26          12                    Eritrea       0    1083    1984    4418
# 27          13                   Ethiopia  741965  393479  197959  100817
# ..         ...                        ...     ...     ...     ...     ...
# 275        261                      Samoa       0       0       0       0
# 276        262                    Tokelau       0       0       0       0
# 277        263                      Tonga       0       0       0       0
# 278        264                     Tuvalu       0       0       0       0
# 279        265  Wallis and Futuna Islands       0       0       0       0
#
#         e2010     e2015      p1990      p1995      p2000      p2005  \
# ...

# %%
# re-organize the df_dev
df_country6 = df_country6.melt(id_vars=["Sort Order","Area"], var_name=["epcyear"],value_name="Value")
df_country6
# Out:
#      Sort Order                       Area     epcyear   Value
# 0             9                    Burundi       e1990  267929
# 1            10                    Comoros       e1990       0
# 2            11                   Djibouti       e1990   54508
# 3            12                    Eritrea       e1990       0
# 4            13                   Ethiopia       e1990  741965
# ...         ...                        ...         ...     ...
# 3939        261                      Samoa  c2010-2015      ..
# 3940        262                    Tokelau  c2010-2015      ..
# 3941        263                      Tonga  c2010-2015      ..
# 3942        264                     Tuvalu  c2010-2015      ..
# 3943        265  Wallis and Futuna Islands  c2010-2015      ..
#
# [3944 rows x 4 columns]

# %%
# split column "epcyear"
df_country6=(df_country6.assign(Type = lambda x: x.epcyear.str[0].astype(str), year = lambda x: x.epcyear.str[1:].astype(str)).drop("epcyear",axis=1))
df_country6
# Out:
#      Sort Order                       Area   Value Type       year
# 0             9                    Burundi  267929    e       1990
# 1            10                    Comoros       0    e       1990
# 2            11                   Djibouti   54508    e       1990
# 3            12                    Eritrea       0    e       1990
# 4            13                   Ethiopia  741965    e       1990
# ...         ...                        ...     ...  ...        ...
# 3939        261                      Samoa      ..    c  2010-2015
# 3940        262                    Tokelau      ..    c  2010-2015
# 3941        263                      Tonga      ..    c  2010-2015
# 3942        264                     Tuvalu      ..    c  2010-2015
# 3943        265  Wallis and Futuna Islands      ..    c  2010-2015
#
# [3944 rows x 5 columns]

# %%
# Styling the dataset
df_country6=(df_country6.replace(to_replace =["e","p","c"],value =["Estimated refugee stock","Refugees as a percentage of the international migrant stock","Annual rate of change of the refugee stock"])
            .dropna())
df_country6
# Out:
#       Sort Order                       Area   Value  \
# 0              9                    Burundi  267929
# 1             10                    Comoros       0
# 2             11                   Djibouti   54508
# 3             12                    Eritrea       0
# 4             13                   Ethiopia  741965
# ...          ...                        ...     ...
# 3939         261                      Samoa      ..
# 3940         262                    Tokelau      ..
# 3941         263                      Tonga      ..
# 3942         264                     Tuvalu      ..
# 3943         265  Wallis and Futuna Islands      ..
#
#                                             Type       year
# 0                        Estimated refugee stock       1990
# 1                        Estimated refugee stock       1990
# 2                        Estimated refugee stock       1990
# 3                        Estimated refugee stock       1990
# ...

# %%
# replace ".." to NaN
df_country6.replace('..', np.nan, inplace = True)
df_country6.head(20)
# Out:
#     Sort Order                         Area     Value  \
# 0            9                      Burundi  267929.0
# 1           10                      Comoros       0.0
# 2           11                     Djibouti   54508.0
# 3           12                      Eritrea       0.0
# 4           13                     Ethiopia  741965.0
# 5           14                        Kenya   13452.0
# 6           15                   Madagascar       0.0
# 7           16                       Malawi  874614.0
# 8           17                    Mauritius       0.0
# 9           18                      Mayotte       0.0
# 10          19                   Mozambique     420.0
# 11          20                      Réunion       0.0
# 12          21                       Rwanda   23446.0
# 13          22                   Seychelles       0.0
# 14          23                      Somalia  460000.0
# 15          24                  South Sudan       NaN
# ...

# %%
# replace NaN to 0
df_country6.fillna(0, inplace=True)
df_country6.head(20)
# Out:
#     Sort Order                         Area     Value  \
# 0            9                      Burundi  267929.0
# 1           10                      Comoros       0.0
# 2           11                     Djibouti   54508.0
# 3           12                      Eritrea       0.0
# 4           13                     Ethiopia  741965.0
# 5           14                        Kenya   13452.0
# 6           15                   Madagascar       0.0
# 7           16                       Malawi  874614.0
# 8           17                    Mauritius       0.0
# 9           18                      Mayotte       0.0
# 10          19                   Mozambique     420.0
# 11          20                      Réunion       0.0
# 12          21                       Rwanda   23446.0
# 13          22                   Seychelles       0.0
# 14          23                      Somalia  460000.0
# 15          24                  South Sudan       0.0
# ...

# %% [markdown]
# df_country6 data cleaning completed. df_UN_T6 data cleaning completed.
