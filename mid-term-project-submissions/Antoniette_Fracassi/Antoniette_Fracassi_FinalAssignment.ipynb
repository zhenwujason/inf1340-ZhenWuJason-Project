# %% [markdown]
# <a href="https://colab.research.google.com/github/AFracassi/inf1340-programmingfordatascience-fa22/blob/main/mid-term-project-submissions/Antoniette_Fracassi/Antoniette_Fracassi_FinalAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Table 1 Analysis

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.ExcelFile('/content/drive/MyDrive/UN_MigrantStockTotal_2015.xlsx')
df.sheet_names
# Out:
# ['CONTENTS',
#  'Table 1',
#  'Table 2',
#  'Table 3',
#  'Table 4',
#  'Table 5',
#  'Table 6',
#  'ANNEX',
#  'NOTES']

# %%
table1=pd.read_excel(df, sheet_name="Table 1")
table1
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0          NaN                        NaN        NaN        NaN
# 1          NaN                        NaN        NaN        NaN
# 2          NaN                        NaN        NaN        NaN
# 3          NaN                        NaN        NaN        NaN
# 4          NaN                        NaN        NaN        NaN
# ..         ...                        ...        ...        ...
# 275        261                      Samoa        NaN        882
# 276        262                    Tokelau        NaN        772
# 277        263                      Tonga        NaN        776
# 278        264                     Tuvalu        NaN        798
# 279        265  Wallis and Futuna Islands        NaN        876
#
#               Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                    NaN        NaN        NaN        NaN        NaN
# ...

# %%
#removing the header
table1=table1[13:]
table1
# Out:
#       Unnamed: 0                                         Unnamed: 1  \
# 13   Sort\norder  Major area, region, country or area of destina...
# 14           NaN                                                NaN
# 15             1                                              WORLD
# 16             2                                  Developed regions
# 17             3                                 Developing regions
# ..           ...                                                ...
# 275          261                                              Samoa
# 276          262                                            Tokelau
# 277          263                                              Tonga
# 278          264                                             Tuvalu
# 279          265                          Wallis and Futuna Islands
#
#     Unnamed: 2    Unnamed: 3        Unnamed: 4  \
# 13       Notes  Country code  Type of data (a)
# 14         NaN           NaN               NaN
# ...

# %%
#New Column Names

my_columns=["sort\norder","Major area, region, country or area of destination", "Notes", "Country Code", "Type of data (a)", 
            "Both sexes, 1990", "Both sexes, 1995", "Both sexes, 2000", "Both sexes, 2005", "Both sexes, 2010", "Both sexes, 2015", 
            "Male, 1990", "Male, 1995", "Male, 2000", "Male, 2005", "Male, 2010", "Male, 2015", "Female, 1990", "Female, 1995", 
            "Female, 2000", "Female, 2005", "Female, 2010", "Female, 2015"]
my_columns
# Out:
# ['sort\norder',
#  'Major area, region, country or area of destination',
#  'Notes',
#  'Country Code',
#  'Type of data (a)',
#  'Both sexes, 1990',
#  'Both sexes, 1995',
#  'Both sexes, 2000',
#  'Both sexes, 2005',
#  'Both sexes, 2010',
#  'Both sexes, 2015',
#  'Male, 1990',
#  'Male, 1995',
#  'Male, 2000',
#  'Male, 2005',
#  'Male, 2010',
#  'Male, 2015',
#  'Female, 1990',
#  'Female, 1995',
#  'Female, 2000',
#  'Female, 2005',
#  'Female, 2010',
#  'Female, 2015']

# %%
table1.columns=my_columns
table1
# Out:
#      sort\norder Major area, region, country or area of destination  Notes  \
# 13   Sort\norder  Major area, region, country or area of destina...  Notes
# 14           NaN                                                NaN    NaN
# 15             1                                              WORLD    NaN
# 16             2                                  Developed regions    (b)
# 17             3                                 Developing regions    (c)
# ..           ...                                                ...    ...
# 275          261                                              Samoa    NaN
# 276          262                                            Tokelau    NaN
# 277          263                                              Tonga    NaN
# 278          264                                             Tuvalu    NaN
# 279          265                          Wallis and Futuna Islands    NaN
#
#      Country Code  Type of data (a)  \
# ...

# %%
# Removing Column rows and columns
table1=table1.iloc[2:, 1:]
table1=table1.drop(["Notes", "Type of data (a)"], axis=1)
table1
# Out:
#     Major area, region, country or area of destination Country Code  \
# 15                                               WORLD          900
# 16                                   Developed regions          901
# 17                                  Developing regions          902
# 18                           Least developed countries          941
# 19   Less developed regions excluding least develop...          934
# ..                                                 ...          ...
# 275                                              Samoa          882
# 276                                            Tokelau          772
# 277                                              Tonga          776
# 278                                             Tuvalu          798
# 279                          Wallis and Futuna Islands          876
#
#     Both sexes, 1990 Both sexes, 1995 Both sexes, 2000 Both sexes, 2005  \
# 15         152563212        160801752        172703309        191269100
# ...

# %%
table1_tidy=table1.melt(id_vars=['Major area, region, country or area of destination', 'Country Code'], 
  value_vars=["Both sexes, 1990", "Both sexes, 1995", "Both sexes, 2000", "Both sexes, 2005",
  "Both sexes, 2010", "Both sexes, 2015", "Male, 1990", "Male, 1995", "Male, 2000", "Male, 2005", "Male, 2010", 
  "Male, 2015", "Female, 1990", 
  "Female, 1995", "Female, 2000", "Female, 2005", "Female, 2010", "Female, 2015"],
value_name="International migrant stock at mid-year",
var_name="Sex, Year")
table1_tidy
# Out:
#      Major area, region, country or area of destination Country Code  \
# 0                                                 WORLD          900
# 1                                     Developed regions          901
# 2                                    Developing regions          902
# 3                             Least developed countries          941
# 4     Less developed regions excluding least develop...          934
# ...                                                 ...          ...
# 4765                                              Samoa          882
# 4766                                            Tokelau          772
# 4767                                              Tonga          776
# 4768                                             Tuvalu          798
# 4769                          Wallis and Futuna Islands          876
#
#              Sex, Year International migrant stock at mid-year
# 0     Both sexes, 1990                               152563212
# ...

# %%
#Seperating Columns into 2
table1_tidy[["Sex", "Year"]]=table1_tidy['Sex, Year'].str.split(',',expand=True)
table1_tidy=table1_tidy.drop("Sex, Year", axis=1)
table1_tidy
# Out:
#      Major area, region, country or area of destination Country Code  \
# 0                                                 WORLD          900
# 1                                     Developed regions          901
# 2                                    Developing regions          902
# 3                             Least developed countries          941
# 4     Less developed regions excluding least develop...          934
# ...                                                 ...          ...
# 4765                                              Samoa          882
# 4766                                            Tokelau          772
# 4767                                              Tonga          776
# 4768                                             Tuvalu          798
# 4769                          Wallis and Futuna Islands          876
#
#      International migrant stock at mid-year         Sex   Year
# 0                                  152563212  Both sexes   1990
# ...

# %%
#Removing the continents and region data
table1_tidy=table1_tidy[table1_tidy['International migrant stock at mid-year']!=".."]
table1_tidy=table1_tidy[(table1_tidy['Major area, region, country or area of destination']!="WORLD")&
                        (table1_tidy['Major area, region, country or area of destination']!="Developed regions")&
                        (table1_tidy['Major area, region, country or area of destination']!="Developing regions")&
                        (table1_tidy['Major area, region, country or area of destination']!="Less developed regions excluding least developed countries")&
                        (table1_tidy['Major area, region, country or area of destination']!="Least developed countries")&
                        (table1_tidy['Major area, region, country or area of destination']!="Sub-Saharan Africa")&
                        (table1_tidy['Major area, region, country or area of destination']!="Africa")&
                        (table1_tidy['Major area, region, country or area of destination']!="Eastern Africa")&
                        (table1_tidy['Major area, region, country or area of destination']!="Europe")&
                        (table1_tidy['Major area, region, country or area of destination']!="Asia")&
                        (table1_tidy['Major area, region, country or area of destination']!="Northern America")&
                        (table1_tidy['Major area, region, country or area of destination']!="Western Asia")&
                        (table1_tidy['Major area, region, country or area of destination']!="Western Europe")&
                        (table1_tidy['Major area, region, country or area of destination']!="Eastern Europe")&
                        (table1_tidy['Major area, region, country or area of destination']!="Southern Asia")&
                        (table1_tidy['Major area, region, country or area of destination']!="Southern Europe")&
                        (table1_tidy['Major area, region, country or area of destination']!="Northern Europe")&
                        (table1_tidy['Major area, region, country or area of destination']!="South-Eastern Asia")&
                        (table1_tidy['Major area, region, country or area of destination']!="Oceania")&
                        (table1_tidy['Major area, region, country or area of destination']!="Western Africa")&
                        (table1_tidy['Major area, region, country or area of destination']!="Southern Africa")&
                        (table1_tidy['Major area, region, country or area of destination']!="Western Sahara")&
                        (table1_tidy['Major area, region, country or area of destination']!="Eastern Asia")&
                        (table1_tidy['Major area, region, country or area of destination']!="Latin America and the Caribbean")&
                        (table1_tidy['Major area, region, country or area of destination']!="Central Asia")&
                        (table1_tidy['Major area, region, country or area of destination']!="South America")]

# %%
#table1_tidy_sorted=table1_tidy.sort_values("International migrant stock at mid-year",ascending=False)
table1_tidy=table1_tidy[table1_tidy["Sex"]=="Both sexes"]
table1_tidy
# Out:
#      Major area, region, country or area of destination Country Code  \
# 8                                               Burundi          108
# 9                                               Comoros          174
# 10                                             Djibouti          262
# 11                                              Eritrea          232
# 12                                             Ethiopia          231
# ...                                                 ...          ...
# 1585                                              Samoa          882
# 1586                                            Tokelau          772
# 1587                                              Tonga          776
# 1588                                             Tuvalu          798
# 1589                          Wallis and Futuna Islands          876
#
#      International migrant stock at mid-year         Sex   Year
# 8                                     333110  Both sexes   1990
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import random
import seaborn as sns
import plotly.express as px

# %%
#Removing invalid data for the International migrant stock at mid-year column:
table1_tidy=table1_tidy[table1_tidy['International migrant stock at mid-year']!=".."]

# %%
#Removing the continents and region data:
table1_tidy=table1_tidy[(table1_tidy['Major area, region, country or area of destination']!="WORLD")&
(table1_tidy['Major area, region, country or area of destination']!="Developed regions")&
(table1_tidy['Major area, region, country or area of destination']!="Developing regions")&
(table1_tidy['Major area, region, country or area of destination']!="Less developed regions excluding least developed countries")&
(table1_tidy['Major area, region, country or area of destination']!="Least developed countries")&
(table1_tidy['Major area, region, country or area of destination']!="Sub-Saharan Africa")&
(table1_tidy['Major area, region, country or area of destination']!="Africa")&
(table1_tidy['Major area, region, country or area of destination']!="Eastern Africa")&
(table1_tidy['Major area, region, country or area of destination']!="Europe")&
(table1_tidy['Major area, region, country or area of destination']!="Asia")&
(table1_tidy['Major area, region, country or area of destination']!="Northern America")&
(table1_tidy['Major area, region, country or area of destination']!="Western Asia")&
(table1_tidy['Major area, region, country or area of destination']!="Western Europe")&
(table1_tidy['Major area, region, country or area of destination']!="Eastern Europe")&
(table1_tidy['Major area, region, country or area of destination']!="Southern Asia")&
(table1_tidy['Major area, region, country or area of destination']!="Southern Europe")&
(table1_tidy['Major area, region, country or area of destination']!="Northern Europe")&
(table1_tidy['Major area, region, country or area of destination']!="South-Eastern Asia")&
(table1_tidy['Major area, region, country or area of destination']!="Oceania")&
(table1_tidy['Major area, region, country or area of destination']!="Western Africa")&
(table1_tidy['Major area, region, country or area of destination']!="Southern Africa")&
(table1_tidy['Major area, region, country or area of destination']!="Western Sahara")&
(table1_tidy['Major area, region, country or area of destination']!="Eastern Asia")&
(table1_tidy['Major area, region, country or area of destination']!="Latin America and the Caribbean")&
(table1_tidy['Major area, region, country or area of destination']!="Central Asia")&
(table1_tidy['Major area, region, country or area of destination']!="South America")&
(table1_tidy['Major area, region, country or area of destination']!="Australia and New Zealand")]

# %%
#Filtering the data for both sexes:
table1_tidy=table1_tidy[table1_tidy["Sex"]=="Both sexes"]

# %%
#Filtering the data to include 2015 only:
table1_tidy2015=table1_tidy[table1_tidy["Year"]==" 2015"]

# %%
#Sorting the data to select the top 10 countries:
table1_tidy2015=table1_tidy2015.sort_values("International migrant stock at mid-year",ascending=False).iloc[:10,:]

# %%
#Adjusting country names so that they fit on the bar plot:
table1_tidy2015.iloc[0,0]="United States"
table1_tidy2015.iloc[2,0]="Russia"
table1_tidy2015.iloc[3,0]="S.Arabia"
table1_tidy2015.iloc[4,0]="UK&N.Ireland"
table1_tidy2015.iloc[5,0]="UAE"

# %%
#Importing the seaborn module:
import seaborn as sns

#Creating the bar plot:
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.barplot(data=table1_tidy2015, x="Major area, region, country or area of destination",y="International migrant stock at mid-year").set(title="International migrant stock at mid-year, 2015, Top 10 Countries")
# Out:
# [Text(0.5, 1.0, 'International migrant stock at mid-year, 2015, Top 10 Countries')]

# %%
#Table 2 analysis

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.ExcelFile('/content/drive/MyDrive/UN_MigrantStockTotal_2015.xlsx')

# %%
df.sheet_names
# Out:
# ['CONTENTS',
#  'Table 1',
#  'Table 2',
#  'Table 3',
#  'Table 4',
#  'Table 5',
#  'Table 6',
#  'ANNEX',
#  'NOTES']

# %%
table2=pd.read_excel(df, sheet_name="Table 2")
table2
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0          NaN                        NaN        NaN        NaN
# 1          NaN                        NaN        NaN        NaN
# 2          NaN                        NaN        NaN        NaN
# 3          NaN                        NaN        NaN        NaN
# 4          NaN                        NaN        NaN        NaN
# ..         ...                        ...        ...        ...
# 275        261                      Samoa        NaN        882
# 276        262                    Tokelau        NaN        772
# 277        263                      Tonga        NaN        776
# 278        264                     Tuvalu        NaN        798
# 279        265  Wallis and Futuna Islands        NaN        876
#
#               Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0                    NaN         NaN         NaN         NaN         NaN
# ...

# %%
#removing the "header"
table2=table2[13:]
table2
# Out:
#       Unnamed: 0                                         Unnamed: 1  \
# 13   Sort\norder  Major area, region, country or area of destina...
# 14           NaN                                                NaN
# 15             1                                              WORLD
# 16             2                                  Developed regions
# 17             3                                 Developing regions
# ..           ...                                                ...
# 275          261                                              Samoa
# 276          262                                            Tokelau
# 277          263                                              Tonga
# 278          264                                             Tuvalu
# 279          265                          Wallis and Futuna Islands
#
#     Unnamed: 2    Unnamed: 3  \
# 13       Notes  Country code
# 14         NaN           NaN
# 15         NaN           900
# ...

# %%
#New Column Names
my_columns=["sort\norder", "Major area, region, country or area of destination", "Notes", "Country Code", "Both Sexes, 1990",
            "Both Sexes, 1995", "Both Sexes, 2000", "Both Sexes, 2005", "Both Sexes, 2010", "Both Sexes, 2015", "Male, 1990", "Male, 1995",
            "Male, 2000", "Male, 2005", "Male, 2010", "Male, 2015", "Female, 1990", "Female, 1995", "Female, 2000", "Female, 2005", "Female, 2010",
            "Female, 2015"]
my_columns
# Out:
# ['sort\norder',
#  'Major area, region, country or area of destination',
#  'Notes',
#  'Country Code',
#  'Both Sexes, 1990',
#  'Both Sexes, 1995',
#  'Both Sexes, 2000',
#  'Both Sexes, 2005',
#  'Both Sexes, 2010',
#  'Both Sexes, 2015',
#  'Male, 1990',
#  'Male, 1995',
#  'Male, 2000',
#  'Male, 2005',
#  'Male, 2010',
#  'Male, 2015',
#  'Female, 1990',
#  'Female, 1995',
#  'Female, 2000',
#  'Female, 2005',
#  'Female, 2010',
#  'Female, 2015']

# %%
table2.columns=my_columns
table2
# Out:
#      sort\norder Major area, region, country or area of destination  Notes  \
# 13   Sort\norder  Major area, region, country or area of destina...  Notes
# 14           NaN                                                NaN    NaN
# 15             1                                              WORLD    NaN
# 16             2                                  Developed regions    (b)
# 17             3                                 Developing regions    (c)
# ..           ...                                                ...    ...
# 275          261                                              Samoa    NaN
# 276          262                                            Tokelau    NaN
# 277          263                                              Tonga    NaN
# 278          264                                             Tuvalu    NaN
# 279          265                          Wallis and Futuna Islands    NaN
#
# ...

# %%
#Removing Columns and rows
table2=table2.iloc[2:, 1:]
table2=table2.drop(["Notes"], axis=1)
table2
# Out:
#     Major area, region, country or area of destination Country Code  \
# 15                                               WORLD          900
# 16                                   Developed regions          901
# 17                                  Developing regions          902
# 18                           Least developed countries          941
# 19   Less developed regions excluding least develop...          934
# ..                                                 ...          ...
# 275                                              Samoa          882
# 276                                            Tokelau          772
# 277                                              Tonga          776
# 278                                             Tuvalu          798
# 279                          Wallis and Futuna Islands          876
#
#     Both Sexes, 1990  Both Sexes, 1995  Both Sexes, 2000  Both Sexes, 2005  \
# ...

# %%
table2_tidy=table2.melt(id_vars=['Major area, region, country or area of destination', 'Country Code'], 
  value_vars=["Both Sexes, 1990", "Both Sexes, 1995", "Both Sexes, 2000", "Both Sexes, 2005", "Both Sexes, 2010", "Both Sexes, 2015", 
  "Male, 1990", "Male, 1995", "Male, 2000", "Male, 2005", "Male, 2010", "Male, 2015", "Female, 1990", "Female, 1995", "Female, 2000", 
  "Female, 2005", "Female, 2010", "Female, 2015"],
value_name="Total population at mid-year",
var_name="Sex, Year")
table2_tidy
# Out:
#      Major area, region, country or area of destination Country Code  \
# 0                                                 WORLD          900
# 1                                     Developed regions          901
# 2                                    Developing regions          902
# 3                             Least developed countries          941
# 4     Less developed regions excluding least develop...          934
# ...                                                 ...          ...
# 4765                                              Samoa          882
# 4766                                            Tokelau          772
# 4767                                              Tonga          776
# 4768                                             Tuvalu          798
# 4769                          Wallis and Futuna Islands          876
#
#              Sex, Year Total population at mid-year
# 0     Both Sexes, 1990                  5309667.699
# ...

# %%
#seperating data into 2 columns
table2_tidy[["Sex", "Year"]]=table2_tidy['Sex, Year'].str.split(',',expand=True)
table2_tidy=table2_tidy.drop("Sex, Year", axis=1)
table2_tidy
# Out:
#      Major area, region, country or area of destination Country Code  \
# 0                                                 WORLD          900
# 1                                     Developed regions          901
# 2                                    Developing regions          902
# 3                             Least developed countries          941
# 4     Less developed regions excluding least develop...          934
# ...                                                 ...          ...
# 4765                                              Samoa          882
# 4766                                            Tokelau          772
# 4767                                              Tonga          776
# 4768                                             Tuvalu          798
# 4769                          Wallis and Futuna Islands          876
#
#      Total population at mid-year         Sex   Year
# 0                     5309667.699  Both Sexes   1990
# ...

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
#Removing the continents and region data in order to gain understanding of country information

# %%
table2_tidy=table2_tidy[table2_tidy['Total population at mid-year']!=".."]
table2_tidy=table2_tidy[(table2_tidy['Major area, region, country or area of destination']!="WORLD")&
(table2_tidy['Major area, region, country or area of destination']!="Developed regions")&
(table2_tidy['Major area, region, country or area of destination']!="Developing regions")&
(table2_tidy['Major area, region, country or area of destination']!="Less developed regions excluding least developed countries")&
(table2_tidy['Major area, region, country or area of destination']!="Least developed countries")&
(table2_tidy['Major area, region, country or area of destination']!="Sub-Saharan Africa")&
(table2_tidy['Major area, region, country or area of destination']!="Africa")&
(table2_tidy['Major area, region, country or area of destination']!="Eastern Africa")&
(table2_tidy['Major area, region, country or area of destination']!="Europe")&
(table2_tidy['Major area, region, country or area of destination']!="Asia")&
(table2_tidy['Major area, region, country or area of destination']!="Northern America")&
(table2_tidy['Major area, region, country or area of destination']!="Western Asia")&
(table2_tidy['Major area, region, country or area of destination']!="Western Europe")&
(table2_tidy['Major area, region, country or area of destination']!="Eastern Europe")&
(table2_tidy['Major area, region, country or area of destination']!="Southern Asia")&
(table2_tidy['Major area, region, country or area of destination']!="Southern Europe")&
(table2_tidy['Major area, region, country or area of destination']!="Northern Europe")&
(table2_tidy['Major area, region, country or area of destination']!="South-Eastern Asia")&
(table2_tidy['Major area, region, country or area of destination']!="Oceania")&
(table2_tidy['Major area, region, country or area of destination']!="Western Africa")&
(table2_tidy['Major area, region, country or area of destination']!="Southern Africa")&
(table2_tidy['Major area, region, country or area of destination']!="Western Sahara")&
(table2_tidy['Major area, region, country or area of destination']!="Eastern Asia")&
(table2_tidy['Major area, region, country or area of destination']!="Latin America and the Caribbean")&
(table2_tidy['Major area, region, country or area of destination']!="Central Asia")&
(table2_tidy['Major area, region, country or area of destination']!="South America")]

# %%
#Filtering for male and female & total population at mid year by Sex and Year and Removing the invalid data for the Total Population at mid-year
table2_tidy_box_sexes=table2_tidy[(table2_tidy["Sex"]=="Male")|(table2_tidy["Sex"]=="Female")][["Total population at mid-year","Sex","Year"]]
table2_tidy_box_sexes=table2_tidy_box_sexes[table2_tidy_box_sexes['Total population at mid-year']!=".."]

# %%
#Grouping by Year and Sex, calculating mean for plotting
groupby_table=table2_tidy_box_sexes.groupby(["Year","Sex"]).mean()

# %%
#Set-up line plot for the mean of Migrant Stock 
my_plot=sns.lineplot(x='Year', 
y='Total population at mid-year',
hue='Sex', 
data=groupby_table)
my_plot.set_title('Annual Average Migrant Stock')
# Out:
# Text(0.5, 1.0, 'Annual Average Migrant Stock')

# %%
#Table 3 Analysis
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.ExcelFile('/content/drive/MyDrive/UN_MigrantStockTotal_2015.xlsx')

# %%
df.sheet_names
# Out:
# ['CONTENTS',
#  'Table 1',
#  'Table 2',
#  'Table 3',
#  'Table 4',
#  'Table 5',
#  'Table 6',
#  'ANNEX',
#  'NOTES']

# %%
table3=pd.read_excel(df, sheet_name="Table 3")
table3
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0          NaN                        NaN        NaN        NaN
# 1          NaN                        NaN        NaN        NaN
# 2          NaN                        NaN        NaN        NaN
# 3          NaN                        NaN        NaN        NaN
# 4          NaN                        NaN        NaN        NaN
# ..         ...                        ...        ...        ...
# 275        261                      Samoa        NaN        882
# 276        262                    Tokelau        NaN        772
# 277        263                      Tonga        NaN        776
# 278        264                     Tuvalu        NaN        798
# 279        265  Wallis and Futuna Islands        NaN        876
#
#               Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                    NaN        NaN        NaN        NaN        NaN
# ...

# %%
# removing the header for visibility of data
table3=table3[14:]
table3
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 14         NaN                        NaN        NaN        NaN        NaN
# 15           1                      WORLD        NaN        900        NaN
# 16           2          Developed regions        (b)        901        NaN
# 17           3         Developing regions        (c)        902        NaN
# 18           4  Least developed countries        (d)        941        NaN
# ..         ...                        ...        ...        ...        ...
# 275        261                      Samoa        NaN        882          B
# 276        262                    Tokelau        NaN        772          B
# 277        263                      Tonga        NaN        776          B
# 278        264                     Tuvalu        NaN        798          C
# 279        265  Wallis and Futuna Islands        NaN        876          B
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9  ...  \
# ...

# %%
#New Column Names
my_columns=["sort\norder", "Major area, region, country or area of destination", "Notes", "Country Code", "Type of data (a)", 
          "Both sexes, 1990", "Both sexes, 1995", "Both sexes, 2000", "Both sexes, 2005", "Both sexes, 2010", "Both sexes, 2015", 
          "Male, 1990", "Male, 1995", "Male, 2000", "Male, 2005", "Male, 2010", "Male, 2015", "Female, 1990", "Female, 1995", 
          "Female, 2000", "Female, 2005", "Female, 2010", "Female, 2015"]
my_columns
# Out:
# ['sort\norder',
#  'Major area, region, country or area of destination',
#  'Notes',
#  'Country Code',
#  'Type of data (a)',
#  'Both sexes, 1990',
#  'Both sexes, 1995',
#  'Both sexes, 2000',
#  'Both sexes, 2005',
#  'Both sexes, 2010',
#  'Both sexes, 2015',
#  'Male, 1990',
#  'Male, 1995',
#  'Male, 2000',
#  'Male, 2005',
#  'Male, 2010',
#  'Male, 2015',
#  'Female, 1990',
#  'Female, 1995',
#  'Female, 2000',
#  'Female, 2005',
#  'Female, 2010',
#  'Female, 2015']

# %%
table3.columns=my_columns
table3
# Out:
#     sort\norder Major area, region, country or area of destination Notes  \
# 14          NaN                                                NaN   NaN
# 15            1                                              WORLD   NaN
# 16            2                                  Developed regions   (b)
# 17            3                                 Developing regions   (c)
# 18            4                          Least developed countries   (d)
# ..          ...                                                ...   ...
# 275         261                                              Samoa   NaN
# 276         262                                            Tokelau   NaN
# 277         263                                              Tonga   NaN
# 278         264                                             Tuvalu   NaN
# 279         265                          Wallis and Futuna Islands   NaN
#
#     Country Code Type of data (a) Both sexes, 1990 Both sexes, 1995  \
# ...

# %%
#Removing Columns and rows
table3=table3.iloc[2:, 1:]
table3=table3.drop(["Notes", "Type of data (a)"], axis=1)
table3
# Out:
#     Major area, region, country or area of destination Country Code  \
# 16                                   Developed regions          901
# 17                                  Developing regions          902
# 18                           Least developed countries          941
# 19   Less developed regions excluding least develop...          934
# 20                                  Sub-Saharan Africa          947
# ..                                                 ...          ...
# 275                                              Samoa          882
# 276                                            Tokelau          772
# 277                                              Tonga          776
# 278                                             Tuvalu          798
# 279                          Wallis and Futuna Islands          876
#
#     Both sexes, 1990 Both sexes, 1995 Both sexes, 2000 Both sexes, 2005  \
# 16          7.198015         7.891085         8.695688         9.693045
# ...

# %%
table3_tidy=table3.melt(id_vars=['Major area, region, country or area of destination', 'Country Code'], 
                        value_vars=["Both sexes, 1990", "Both sexes, 1995", "Both sexes, 2000", "Both sexes, 2005", 
                        "Both sexes, 2010", "Both sexes, 2015", "Male, 1990", "Male, 1995", "Male, 2000", "Male, 2005", 
                        "Male, 2010", "Male, 2015", "Female, 1990", "Female, 1995", "Female, 2000", "Female, 2005", 
                        "Female, 2010", "Female, 2015"],
value_name="International migrant stock as a percentage of the total population",
var_name ="Sex, Year")
table3_tidy
# Out:
#      Major area, region, country or area of destination Country Code  \
# 0                                     Developed regions          901
# 1                                    Developing regions          902
# 2                             Least developed countries          941
# 3     Less developed regions excluding least develop...          934
# 4                                    Sub-Saharan Africa          947
# ...                                                 ...          ...
# 4747                                              Samoa          882
# 4748                                            Tokelau          772
# 4749                                              Tonga          776
# 4750                                             Tuvalu          798
# 4751                          Wallis and Futuna Islands          876
#
#              Sex, Year  \
# 0     Both sexes, 1990
# 1     Both sexes, 1990
# 2     Both sexes, 1990
# 3     Both sexes, 1990
# ...

# %%
# Seperating Columns into 2
table3_tidy[["Sex", "Year"]]=table3_tidy['Sex, Year'].str.split(',',expand=True)
table3_tidy=table3_tidy.drop("Sex, Year", axis=1)
table3_tidy
# Out:
#      Major area, region, country or area of destination Country Code  \
# 0                                     Developed regions          901
# 1                                    Developing regions          902
# 2                             Least developed countries          941
# 3     Less developed regions excluding least develop...          934
# 4                                    Sub-Saharan Africa          947
# ...                                                 ...          ...
# 4747                                              Samoa          882
# 4748                                            Tokelau          772
# 4749                                              Tonga          776
# 4750                                             Tuvalu          798
# 4751                          Wallis and Futuna Islands          876
#
#      International migrant stock as a percentage of the total population  \
# 0                                              7.198015
# ...

# %%
#Removing the continents and region data in order to gain understanding of  country information

# %%
table3_tidy=table3_tidy[table3_tidy['International migrant stock as a percentage of the total population']!=".."]
table3_tidy=table3_tidy[(table3_tidy['Major area, region, country or area of destination']!="WORLD")&
(table3_tidy['Major area, region, country or area of destination']!="Developed regions")&
(table3_tidy['Major area, region, country or area of destination']!="Developing regions")&
(table3_tidy['Major area, region, country or area of destination']!="Less developed regions excluding least developed countries")&
(table3_tidy['Major area, region, country or area of destination']!="Least developed countries")&
(table3_tidy['Major area, region, country or area of destination']!="Sub-Saharan Africa")&
(table3_tidy['Major area, region, country or area of destination']!="Africa")&
(table3_tidy['Major area, region, country or area of destination']!="Eastern Africa")&
(table3_tidy['Major area, region, country or area of destination']!="Europe")&
(table3_tidy['Major area, region, country or area of destination']!="Asia")&
(table3_tidy['Major area, region, country or area of destination']!="Northern America")&
(table3_tidy['Major area, region, country or area of destination']!="Western Asia")&
(table3_tidy['Major area, region, country or area of destination']!="Western Europe")&
(table3_tidy['Major area, region, country or area of destination']!="Eastern Europe")&
(table3_tidy['Major area, region, country or area of destination']!="Southern Asia")&
(table3_tidy['Major area, region, country or area of destination']!="Southern Europe")&
(table3_tidy['Major area, region, country or area of destination']!="Northern Europe")&
(table3_tidy['Major area, region, country or area of destination']!="South-Eastern Asia")&
(table3_tidy['Major area, region, country or area of destination']!="Oceania")&
(table3_tidy['Major area, region, country or area of destination']!="Western Africa")&
(table3_tidy['Major area, region, country or area of destination']!="Southern Africa")&
(table3_tidy['Major area, region, country or area of destination']!="Western Sahara")&
(table3_tidy['Major area, region, country or area of destination']!="Eastern Asia")&
(table3_tidy['Major area, region, country or area of destination']!="Latin America and the Caribbean")&
(table3_tidy['Major area, region, country or area of destination']!="Central Asia")&
(table3_tidy['Major area, region, country or area of destination']!="South America")]

# %%
#Filtering the data for both sexes and removing the invalid data for the International Mirgrant Stock at mid-year column
table3_tidy_box_sexes=table3_tidy[table3_tidy["Sex"]=="Both sexes"][["International migrant stock as a percentage of the total population","Sex","Year"]]
table3_tidy_box_sexes=table3_tidy_box_sexes[table3_tidy_box_sexes['International migrant stock as a percentage of the total population']!=".."]

# %%
#building a box plot

my_plot=sns.boxplot(x="Year",y="International migrant stock as a percentage of the total population",data=table3_tidy_box_sexes)
my_plot.set_title("International migrant stock as a of the total population")
my_plot.set(xlabel='Year', ylabel="Int'l migrant stock as a % of the total population")
my_plot

# %%
#Table 4 Analysis

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.ExcelFile('/content/drive/MyDrive/UN_MigrantStockTotal_2015.xlsx')

# %%
df.sheet_names
# Out:
# ['CONTENTS',
#  'Table 1',
#  'Table 2',
#  'Table 3',
#  'Table 4',
#  'Table 5',
#  'Table 6',
#  'ANNEX',
#  'NOTES']

# %%
table4=pd.read_excel(df, sheet_name="Table 4")
table4
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0          NaN                        NaN        NaN        NaN
# 1          NaN                        NaN        NaN        NaN
# 2          NaN                        NaN        NaN        NaN
# 3          NaN                        NaN        NaN        NaN
# 4          NaN                        NaN        NaN        NaN
# ..         ...                        ...        ...        ...
# 275        261                      Samoa        NaN        882
# 276        262                    Tokelau        NaN        772
# 277        263                      Tonga        NaN        776
# 278        264                     Tuvalu        NaN        798
# 279        265  Wallis and Futuna Islands        NaN        876
#
#               Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                    NaN        NaN        NaN        NaN        NaN
# ...

# %%
table4=pd.read_excel(df, sheet_name="Table 4")
table4
# Out:
#     Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0          NaN                        NaN        NaN        NaN
# 1          NaN                        NaN        NaN        NaN
# 2          NaN                        NaN        NaN        NaN
# 3          NaN                        NaN        NaN        NaN
# 4          NaN                        NaN        NaN        NaN
# ..         ...                        ...        ...        ...
# 275        261                      Samoa        NaN        882
# 276        262                    Tokelau        NaN        772
# 277        263                      Tonga        NaN        776
# 278        264                     Tuvalu        NaN        798
# 279        265  Wallis and Futuna Islands        NaN        876
#
#               Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                    NaN        NaN        NaN        NaN        NaN
# ...

# %%
#removing the header
table4=table4[13:]
table4
# Out:
#       Unnamed: 0                                         Unnamed: 1  \
# 13   Sort\norder  Major area, region, country or area of destina...
# 14           NaN                                                NaN
# 15             1                                              WORLD
# 16             2                                  Developed regions
# 17             3                                 Developing regions
# ..           ...                                                ...
# 275          261                                              Samoa
# 276          262                                            Tokelau
# 277          263                                              Tonga
# 278          264                                             Tuvalu
# 279          265                          Wallis and Futuna Islands
#
#     Unnamed: 2    Unnamed: 3        Unnamed: 4  \
# 13       Notes  Country code  Type of data (a)
# 14         NaN           NaN               NaN
# ...

# %%
#New Column Names
my_columns=["sort\norder", "Major area, region, country or area of destination", "Notes", "Country code", "Type of data (a)", "1990", "1995", "2000", "2005", "2010", "2015"]
my_columns
# Out:
# ['sort\norder',
#  'Major area, region, country or area of destination',
#  'Notes',
#  'Country code',
#  'Type of data (a)',
#  '1990',
#  '1995',
#  '2000',
#  '2005',
#  '2010',
#  '2015']

# %%
table4.columns=my_columns
table4
# Out:
#      sort\norder Major area, region, country or area of destination  Notes  \
# 13   Sort\norder  Major area, region, country or area of destina...  Notes
# 14           NaN                                                NaN    NaN
# 15             1                                              WORLD    NaN
# 16             2                                  Developed regions    (b)
# 17             3                                 Developing regions    (c)
# ..           ...                                                ...    ...
# 275          261                                              Samoa    NaN
# 276          262                                            Tokelau    NaN
# 277          263                                              Tonga    NaN
# 278          264                                             Tuvalu    NaN
# 279          265                          Wallis and Futuna Islands    NaN
#
#      Country code  Type of data (a)  \
# ...

# %%
#Removing Columns and rows
table4=table4.iloc[2:, 1:]
table4=table4.drop(["Notes", "Type of data (a)"], axis=1)
table4
# Out:
#     Major area, region, country or area of destination Country code  \
# 15                                               WORLD          900
# 16                                   Developed regions          901
# 17                                  Developing regions          902
# 18                           Least developed countries          941
# 19   Less developed regions excluding least develop...          934
# ..                                                 ...          ...
# 275                                              Samoa          882
# 276                                            Tokelau          772
# 277                                              Tonga          776
# 278                                             Tuvalu          798
# 279                          Wallis and Futuna Islands          876
#
#           1990       1995       2000       2005       2010       2015
# 15    49.03915   49.16879  49.112244  48.832993  48.305660  48.249769
# ...

# %%
table4_tidy=table4.melt(id_vars=['Major area, region, country or area of destination', 'Country code'], value_vars=["1990", "1995", "2000", "2005", "2010", "2015"], 
                        value_name="Female migrants as a % of the international migrant stock",
                        var_name="Year")
table4_tidy
# Out:
#      Major area, region, country or area of destination Country code  Year  \
# 0                                                 WORLD          900  1990
# 1                                     Developed regions          901  1990
# 2                                    Developing regions          902  1990
# 3                             Least developed countries          941  1990
# 4     Less developed regions excluding least develop...          934  1990
# ...                                                 ...          ...   ...
# 1585                                              Samoa          882  2015
# 1586                                            Tokelau          772  2015
# 1587                                              Tonga          776  2015
# 1588                                             Tuvalu          798  2015
# 1589                          Wallis and Futuna Islands          876  2015
#
#      Female migrants as a % of the international migrant stock
# ...

# %%
#Removing invalid data for the International migrant stock at mid-year column:
table4_tidy=table4_tidy[table4_tidy['Female migrants as a % of the international migrant stock']!=".."]

# %%
#Removing invalid data for the International migrant stock at mid-year column:
table4_tidy=table4_tidy[table4_tidy['Female migrants as a % of the international migrant stock']!=".."]
#Removing the continents and region data:
table4_tidy=table4_tidy[(table4_tidy['Major area, region, country or area of destination']!="WORLD")&
                        (table4_tidy['Major area, region, country or area of destination']!="Developed regions")&
                        (table4_tidy['Major area, region, country or area of destination']!="Developing regions")&
                        (table4_tidy['Major area, region, country or area of destination']!="Less developed regions excluding least developed countries")&
                        (table4_tidy['Major area, region, country or area of destination']!="Least developed countries")&
                        (table4_tidy['Major area, region, country or area of destination']!="Sub-Saharan Africa")&
                        (table4_tidy['Major area, region, country or area of destination']!="Africa")&
                        (table4_tidy['Major area, region, country or area of destination']!="Eastern Africa")&
                        (table4_tidy['Major area, region, country or area of destination']!="Europe")&
                        (table4_tidy['Major area, region, country or area of destination']!="Asia")&
                        (table4_tidy['Major area, region, country or area of destination']!="Northern America")&
                        (table4_tidy['Major area, region, country or area of destination']!="Western Asia")&
                        (table4_tidy['Major area, region, country or area of destination']!="Western Europe")&
                        (table4_tidy['Major area, region, country or area of destination']!="Eastern Europe")&
                        (table4_tidy['Major area, region, country or area of destination']!="Southern Asia")&
                        (table4_tidy['Major area, region, country or area of destination']!="Southern Europe")&
                        (table4_tidy['Major area, region, country or area of destination']!="Northern Europe")&
                        (table4_tidy['Major area, region, country or area of destination']!="South-Eastern Asia")&
                        (table4_tidy['Major area, region, country or area of destination']!="Oceania")&
                        (table4_tidy['Major area, region, country or area of destination']!="Western Africa")&
                        (table4_tidy['Major area, region, country or area of destination']!="Southern Africa")&
                        (table4_tidy['Major area, region, country or area of destination']!="Western Sahara")&
                        (table4_tidy['Major area, region, country or area of destination']!="Eastern Asia")&
                        (table4_tidy['Major area, region, country or area of destination']!="Latin America and the Caribbean")&
                        (table4_tidy['Major area, region, country or area of destination']!="Central Asia")&
                        (table4_tidy['Major area, region, country or area of destination']!="South America")&
                        (table4_tidy['Major area, region, country or area of destination']!="Australia and New Zealand")]

# %%
#Subsetting the data to include only Female migrants as a % of the international migrant stock and Year columns:
table4_tidy_subset=table4_tidy[["Year","Female migrants as a % of the international migrant stock"]]
#Grouping the data by year:
grouped_data=table4_tidy_subset.groupby("Year").mean()
# Out:
#       Female migrants as a % of the international migrant stock
# Year
# 1990                                          48.151796
# 1995                                          48.409452
# 2000                                          48.547940
# 2005                                          48.232334
# 2010                                          48.257792
# 2015                                          48.328103

# %%
#Importing the seaborn module:
import seaborn as sns

# %%
#Setting the figure size:
sns.set(rc={'figure.figsize':(11.7,8.27)})
#Creating a scatterplot:
my_plot=sns.scatterplot(x="Year",y="Female migrants as a % of the international migrant stock",data=grouped_data)
#Adding a title and changing y-axis label:
my_plot.set(title="Female migrants as a % of the Int'l migrant stock by Year",ylabel="Female migrants as a % of the Int'l migrant stock")
# Out:
# [Text(0, 0.5, "Female migrants as a % of the Int'l migrant stock"),
#  Text(0.5, 1.0, "Female migrants as a % of the Int'l migrant stock by Year")]

# %%
#Table 5 Analysis

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.ExcelFile('/content/drive/MyDrive/UN_MigrantStockTotal_2015.xlsx')

# %%
df.sheet_names
# Out:
# ['CONTENTS',
#  'Table 1',
#  'Table 2',
#  'Table 3',
#  'Table 4',
#  'Table 5',
#  'Table 6',
#  'ANNEX',
#  'NOTES']

# %%
table5=pd.read_excel(df, sheet_name="Table 5")

# %%
table5[:15]
# Out:
#      Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0           NaN                                                NaN        NaN
# 1           NaN                                                NaN        NaN
# 2           NaN                                                NaN        NaN
# 3           NaN                                                NaN        NaN
# 4           NaN                                                NaN        NaN
# 5           NaN                                                NaN        NaN
# 6           NaN                                                NaN        NaN
# 7           NaN                                                NaN        NaN
# 8           NaN                                                NaN        NaN
# 9           NaN                                                NaN        NaN
# 10          NaN                                                NaN        NaN
# ...

# %%
#Removing the header
table5=table5[13:]
table5
# Out:
#       Unnamed: 0                                         Unnamed: 1  \
# 13   Sort\norder  Major area, region, country or area of destina...
# 14           NaN                                                NaN
# 15             1                                              WORLD
# 16             2                                  Developed regions
# 17             3                                 Developing regions
# ..           ...                                                ...
# 275          261                                              Samoa
# 276          262                                            Tokelau
# 277          263                                              Tonga
# 278          264                                             Tuvalu
# 279          265                          Wallis and Futuna Islands
#
#     Unnamed: 2    Unnamed: 3        Unnamed: 4  \
# 13       Notes  Country code  Type of data (a)
# 14         NaN           NaN               NaN
# ...

# %%
#New Column Names
my_columns=["sort\norder", "Major area, region, country or area of destination", "Notes", "Country Code", "Type of data (a)", "Both sexes, 1990-1995", "Both sexes, 1995-2000", 
            "Both sexes, 2000-2005", "Both sexes, 2005-2010", "Both sexes, 2010-2015", "Male, 1990-1995", 
            "Male, 1995-2000", "Male, 2000-2005", "Male, 2005-2010", "Male, 2010-2015", "Female, 1990-1995", "Female, 1995-2000", "Female, 2000-2005",
            "Female, 2005-2010", "Female, 2010-2015"]
my_columns
# Out:
# ['sort\norder',
#  'Major area, region, country or area of destination',
#  'Notes',
#  'Country Code',
#  'Type of data (a)',
#  'Both sexes, 1990-1995',
#  'Both sexes, 1995-2000',
#  'Both sexes, 2000-2005',
#  'Both sexes, 2005-2010',
#  'Both sexes, 2010-2015',
#  'Male, 1990-1995',
#  'Male, 1995-2000',
#  'Male, 2000-2005',
#  'Male, 2005-2010',
#  'Male, 2010-2015',
#  'Female, 1990-1995',
#  'Female, 1995-2000',
#  'Female, 2000-2005',
#  'Female, 2005-2010',
#  'Female, 2010-2015']

# %%
table5.columns=my_columns
table5
# Out:
#      sort\norder Major area, region, country or area of destination  Notes  \
# 13   Sort\norder  Major area, region, country or area of destina...  Notes
# 14           NaN                                                NaN    NaN
# 15             1                                              WORLD    NaN
# 16             2                                  Developed regions    (b)
# 17             3                                 Developing regions    (c)
# ..           ...                                                ...    ...
# 275          261                                              Samoa    NaN
# 276          262                                            Tokelau    NaN
# 277          263                                              Tonga    NaN
# 278          264                                             Tuvalu    NaN
# 279          265                          Wallis and Futuna Islands    NaN
#
#      Country Code  Type of data (a)  \
# ...

# %%
#Removing Columns and Rows
table5=table5.iloc[2:, 1:]
table5=table5.drop(["Notes", "Type of data (a)"], axis=1)
table5
# Out:
#     Major area, region, country or area of destination Country Code  \
# 15                                               WORLD          900
# 16                                   Developed regions          901
# 17                                  Developing regions          902
# 18                           Least developed countries          941
# 19   Less developed regions excluding least develop...          934
# ..                                                 ...          ...
# 275                                              Samoa          882
# 276                                            Tokelau          772
# 277                                              Tonga          776
# 278                                             Tuvalu          798
# 279                          Wallis and Futuna Islands          876
#
#     Both sexes, 1990-1995 Both sexes, 1995-2000 Both sexes, 2000-2005  \
# 15               1.051865              1.428058              2.042124
# ...

# %%
table5_tidy=table5.melt(id_vars=['Major area, region, country or area of destination', 'Country Code'], value_vars=["Both sexes, 1990-1995", "Both sexes, 1995-2000",
                                  "Both sexes, 2000-2005", "Both sexes, 2005-2010", "Both sexes, 2010-2015", "Male, 1990-1995", "Male, 1995-2000", "Male, 2000-2005",
                                  "Male, 2005-2010", "Female, 1990-1995", "Female, 1995-2000", "Female, 2000-2005", "Female, 2005-2010"],
value_name="Annual rate of change of the migrant stock",
var_name="Sex, Year")
table5_tidy
# Out:
#      Major area, region, country or area of destination Country Code  \
# 0                                                 WORLD          900
# 1                                     Developed regions          901
# 2                                    Developing regions          902
# 3                             Least developed countries          941
# 4     Less developed regions excluding least develop...          934
# ...                                                 ...          ...
# 3440                                              Samoa          882
# 3441                                            Tokelau          772
# 3442                                              Tonga          776
# 3443                                             Tuvalu          798
# 3444                          Wallis and Futuna Islands          876
#
#                   Sex, Year Annual rate of change of the migrant stock
# ...

# %%
#Seperating Columns into 2
table5_tidy[["Sex", "Year"]]=table5_tidy['Sex, Year'].str.split(',',expand=True)
table5_tidy=table5_tidy.drop("Sex, Year", axis=1)
table5_tidy
# Out:
#      Major area, region, country or area of destination Country Code  \
# 0                                                 WORLD          900
# 1                                     Developed regions          901
# 2                                    Developing regions          902
# 3                             Least developed countries          941
# 4     Less developed regions excluding least develop...          934
# ...                                                 ...          ...
# 3440                                              Samoa          882
# 3441                                            Tokelau          772
# 3442                                              Tonga          776
# 3443                                             Tuvalu          798
# 3444                          Wallis and Futuna Islands          876
#
#      Annual rate of change of the migrant stock         Sex        Year
# ...

# %%
#Removing invalid data for the International migrant stock at mid-year column:
table5_tidy=table5_tidy[table5_tidy['Annual rate of change of the migrant stock']!=".."]
#Removing the continents and region data:
table5_tidy=table5_tidy[(table5_tidy['Major area, region, country or area of destination']!="WORLD")&
                        (table5_tidy['Major area, region, country or area of destination']!="Developed regions")&
                        (table5_tidy['Major area, region, country or area of destination']!="Developing regions")&
                        (table5_tidy['Major area, region, country or area of destination']!="Less developed regions excluding least developed countries")&
                        (table5_tidy['Major area, region, country or area of destination']!="Least developed countries")&
                        (table5_tidy['Major area, region, country or area of destination']!="Sub-Saharan Africa")&
                        (table5_tidy['Major area, region, country or area of destination']!="Africa")&
                        (table5_tidy['Major area, region, country or area of destination']!="Eastern Africa")&
                        (table5_tidy['Major area, region, country or area of destination']!="Europe")&
                        (table5_tidy['Major area, region, country or area of destination']!="Asia")&
                        (table5_tidy['Major area, region, country or area of destination']!="Northern America")&
                        (table5_tidy['Major area, region, country or area of destination']!="Western Asia")&
                        (table5_tidy['Major area, region, country or area of destination']!="Western Europe")&
                        (table5_tidy['Major area, region, country or area of destination']!="Eastern Europe")&
                        (table5_tidy['Major area, region, country or area of destination']!="Southern Asia")&
                        (table5_tidy['Major area, region, country or area of destination']!="Southern Europe")&
                        (table5_tidy['Major area, region, country or area of destination']!="Northern Europe")&
                        (table5_tidy['Major area, region, country or area of destination']!="South-Eastern Asia")&
                        (table5_tidy['Major area, region, country or area of destination']!="Oceania")&
                        (table5_tidy['Major area, region, country or area of destination']!="Western Africa")&
                        (table5_tidy['Major area, region, country or area of destination']!="Southern Africa")&
                        (table5_tidy['Major area, region, country or area of destination']!="Western Sahara")&
                        (table5_tidy['Major area, region, country or area of destination']!="Eastern Asia")&
                        (table5_tidy['Major area, region, country or area of destination']!="Latin America and the Caribbean")&
                        (table5_tidy['Major area, region, country or area of destination']!="Central Asia")&
                        (table5_tidy['Major area, region, country or area of destination']!="South America")&
                        (table5_tidy['Major area, region, country or area of destination']!="Australia and New Zealand")]

# %%
#Filtering the data to only include records from 2005-2010:
table5_tidy_subset=table5_tidy[(table5_tidy["Year"]==" 2005-2010")&(table5_tidy["Sex"]=="Both sexes")]
table5_tidy_subset
# Out:
#      Major area, region, country or area of destination Country Code  \
# 803                                             Burundi          108
# 804                                             Comoros          174
# 805                                            Djibouti          262
# 806                                             Eritrea          232
# 807                                            Ethiopia          231
# ...                                                 ...          ...
# 1055                                              Samoa          882
# 1056                                            Tokelau          772
# 1057                                              Tonga          776
# 1058                                             Tuvalu          798
# 1059                          Wallis and Futuna Islands          876
#
#      Annual rate of change of the migrant stock         Sex        Year
# ...

# %%
#Importing the seaborn module:
import seaborn as sns

# %%
#Creating the histogram:
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.histplot(x="Annual rate of change of the migrant stock",data=table5_tidy_subset).set(title="Annual rate of change of the migrant stock, 2005-2010, Both Sexes")
# Out:
# [Text(0.5, 1.0, 'Annual rate of change of the migrant stock, 2005-2010, Both Sexes')]
