# %%
#@title Table 1 Cleaning

# %%
import pandas as pd
import numpy as np
from google.colab import drive
tb_1 = pd.read_excel("/content/UN_MigrantStockTotal_2015.xlsx", sheet_name ="Table 1")
tb_1.drop(tb_1.index[0:15], inplace=True)
tb_1.columns = ["Sort order", "Major area, region, country or area of destination", "Notes",
               "Country code", "Type of data (a)", "both_sexs1990", "both_sexs1995", "both_sexs2000", "both_sexs2005", "both_sexs2010",
               "both_sexs2015", "male1990", "male1995", "male2000", "male2005", "male2010", "male2015", "female1990", "female1995", "female2000",
               "female2005", "female2010", "female2015"]
tb_1.head(5)
tb_1.tail(5)
# Out:
#     Sort order Major area, region, country or area of destination Notes  \
# 275        261                                              Samoa   NaN
# 276        262                                            Tokelau   NaN
# 277        263                                              Tonga   NaN
# 278        264                                             Tuvalu   NaN
# 279        265                          Wallis and Futuna Islands   NaN
#
#     Country code Type of data (a) both_sexs1990 both_sexs1995 both_sexs2000  \
# 275          882                B          3357          4694          5998
# 276          772                B           270           266           262
# 277          776                B          2911          3274          3684
# 278          798                C           318           263           217
# 279          876                B          1402          1680          2015
#
#     both_sexs2005  both_sexs2010  ...  male2000 male2005 male2010 male2015  \
# 275          5746         5122.0  ...      3101     2940   2594.0   2469.0
# 276           258          429.0  ...       144      133    206.0    233.0
# 277          4301         5022.0  ...      1981     2328   2727.0   3127.0
# 278           183          154.0  ...       121      101     85.0     78.0
# 279          2365         2776.0  ...      1018     1194   1401.0   1438.0
#
#     female1990  female1995  female2000 female2005 female2010 female2015
# 275       1586        2243        2897       2806     2528.0     2460.0
# 276        120         119         118        125      223.0      254.0
# 277       1423        1556        1703       1973     2295.0     2604.0
# 278        138         115          96         82       69.0       63.0
# 279        676         821         997       1171     1375.0     1411.0
#
# [5 rows x 23 columns]

# %%
tb_1=tb_1.melt(id_vars=["Sort order","Major area, region, country or area of destination","Notes","Country code","Type of data (a)"],var_name=["Genderandyear"],value_name="International migrant stock at mid-year")
tb_1.head(5)
# Out:
#   Sort order Major area, region, country or area of destination Notes  \
# 0          1                                              WORLD   NaN
# 1          2                                  Developed regions   (b)
# 2          3                                 Developing regions   (c)
# 3          4                          Least developed countries   (d)
# 4          5  Less developed regions excluding least develop...   NaN
#
#   Country code Type of data (a)  Genderandyear  \
# 0          900              NaN  both_sexs1990
# 1          901              NaN  both_sexs1990
# 2          902              NaN  both_sexs1990
# 3          941              NaN  both_sexs1990
# 4          934              NaN  both_sexs1990
#
#   International migrant stock at mid-year
# 0                               152563212
# 1                                82378628
# 2                                70184584
# 3                                11075966
# 4                                59105261

# %%
tb_1 = tb_1.assign(Gender = lambda x: x.Genderandyear.str[0].astype(str), Year = lambda x: x.Genderandyear.str[-4:].astype(str))
tb_1 = tb_1.drop("Genderandyear", axis = 1)
tb_1.head(5)
# Out:
#   Sort order Major area, region, country or area of destination Notes  \
# 0          1                                              WORLD   NaN
# 1          2                                  Developed regions   (b)
# 2          3                                 Developing regions   (c)
# 3          4                          Least developed countries   (d)
# 4          5  Less developed regions excluding least develop...   NaN
#
#   Country code Type of data (a) International migrant stock at mid-year  \
# 0          900              NaN                               152563212
# 1          901              NaN                                82378628
# 2          902              NaN                                70184584
# 3          941              NaN                                11075966
# 4          934              NaN                                59105261
#
#   Gender  Year
# 0      b  1990
# 1      b  1990
# 2      b  1990
# 3      b  1990
# 4      b  1990

# %%
tb_1 = tb_1.replace(to_replace=["f", "b", "m"], value=["female", "both sexes", "male"])
tb_1.head(4770)
# Out:
#       Sort order Major area, region, country or area of destination Notes  \
# 0              1                                              WORLD   NaN
# 1              2                                  Developed regions   (b)
# 2              3                                 Developing regions   (c)
# 3              4                          Least developed countries   (d)
# 4              5  Less developed regions excluding least develop...   NaN
# ...          ...                                                ...   ...
# 4765         261                                              Samoa   NaN
# 4766         262                                            Tokelau   NaN
# 4767         263                                              Tonga   NaN
# 4768         264                                             Tuvalu   NaN
# 4769         265                          Wallis and Futuna Islands   NaN
#
#       Country code Type of data (a) International migrant stock at mid-year  \
# 0              900              NaN                               152563212
# 1              901              NaN                                82378628
# 2              902              NaN                                70184584
# 3              941              NaN                                11075966
# 4              934              NaN                                59105261
# ...            ...              ...                                     ...
# 4765           882                B                                  2460.0
# 4766           772                B                                   254.0
# 4767           776                B                                  2604.0
# 4768           798                C                                    63.0
# 4769           876                B                                  1411.0
#
#           Gender  Year
# 0     both sexes  1990
# 1     both sexes  1990
# 2     both sexes  1990
# 3     both sexes  1990
# 4     both sexes  1990
# ...          ...   ...
# 4765      female  2015
# 4766      female  2015
# 4767      female  2015
# 4768      female  2015
# 4769      female  2015
#
# [4770 rows x 8 columns]

# %%
cols_tb_1 = tb_1.columns.tolist()
cols_tb_1.insert(7,cols_tb_1.pop(cols_tb_1.index('International migrant stock at mid-year')))   # I change the column position
tb_1 = tb_1[cols_tb_1]       
tb_1 = tb_1.set_index('Sort order') #reset index

# %%
tb_1
# Out:
#            Major area, region, country or area of destination Notes  \
# Sort order
# 1                                                       WORLD   NaN
# 2                                           Developed regions   (b)
# 3                                          Developing regions   (c)
# 4                                   Least developed countries   (d)
# 5           Less developed regions excluding least develop...   NaN
# ...                                                       ...   ...
# 261                                                     Samoa   NaN
# 262                                                   Tokelau   NaN
# 263                                                     Tonga   NaN
# 264                                                    Tuvalu   NaN
# 265                                 Wallis and Futuna Islands   NaN
#
#             Country code Type of data (a)      Gender  Year  \
# Sort order
# 1                    900              NaN  both sexes  1990
# 2                    901              NaN  both sexes  1990
# 3                    902              NaN  both sexes  1990
# 4                    941              NaN  both sexes  1990
# 5                    934              NaN  both sexes  1990
# ...                  ...              ...         ...   ...
# 261                  882                B      female  2015
# 262                  772                B      female  2015
# 263                  776                B      female  2015
# 264                  798                C      female  2015
# 265                  876                B      female  2015
#
#            International migrant stock at mid-year
# Sort order
# 1                                        152563212
# 2                                         82378628
# 3                                         70184584
# 4                                         11075966
# 5                                         59105261
# ...                                            ...
# 261                                         2460.0
# 262                                          254.0
# 263                                         2604.0
# 264                                           63.0
# 265                                         1411.0
#
# [4770 rows x 7 columns]

# %%
#@title Table 2 Cleaning

# %%
import pandas as pd
import numpy as np
from google.colab import drive
tb_2 = pd.read_excel("/content/UN_MigrantStockTotal_2015.xlsx", sheet_name ="Table 2")
tb_2.drop(tb_2.index[0:15], inplace=True)
tb_2.columns = ["Sort order", "Major area, region, country or area of destination", "Notes",
               "Country code", "both_sexs1990", "both_sexs1995", "both_sexs2000", "both_sexs2005", "both_sexs2010",
               "both_sexs2015", "male1990", "male1995", "male2000", "male2005", "male2010", "male2015", "female1990", "female1995", "female2000",
               "female2005", "female2010", "female2015"]

# %%
tb_2=tb_2.melt(id_vars=["Sort order","Major area, region, country or area of destination","Notes","Country code"],var_name=["Genderandyear"],value_name="Total population of both sexes at mid-year (thousands)")

# %%
tb_2 = tb_2.assign(Gender = lambda x: x.Genderandyear.str[0].astype(str), Year = lambda x: x.Genderandyear.str[-4:].astype(str))
tb_2 = tb_2.drop("Genderandyear", axis = 1)

# %%
tb_2 = tb_2.replace(to_replace=["f", "b", "m"], value=["female", "both sexes", "male"])
tb_2.head(4770)
# Out:
#       Sort order Major area, region, country or area of destination Notes  \
# 0              1                                              WORLD   NaN
# 1              2                                  Developed regions   (b)
# 2              3                                 Developing regions   (c)
# 3              4                          Least developed countries   (d)
# 4              5  Less developed regions excluding least develop...   NaN
# ...          ...                                                ...   ...
# 4765         261                                              Samoa   NaN
# 4766         262                                            Tokelau   NaN
# 4767         263                                              Tonga   NaN
# 4768         264                                             Tuvalu   NaN
# 4769         265                          Wallis and Futuna Islands   NaN
#
#       Country code Total population of both sexes at mid-year (thousands)  \
# 0              900                                        5309667.699
# 1              901                                        1144463.062
# 2              902                                        4165204.637
# 3              941                                         510057.629
# 4              934                                        3655147.008
# ...            ...                                                ...
# 4765           882                                             93.584
# 4766           772                                                 ..
# 4767           776                                             52.931
# 4768           798                                                 ..
# 4769           876                                                 ..
#
#           Gender  Year
# 0     both sexes  1990
# 1     both sexes  1990
# 2     both sexes  1990
# 3     both sexes  1990
# 4     both sexes  1990
# ...          ...   ...
# 4765      female  2015
# 4766      female  2015
# 4767      female  2015
# 4768      female  2015
# 4769      female  2015
#
# [4770 rows x 7 columns]

# %%
cols_tb_2 = tb_2.columns.tolist()
cols_tb_2.insert(7,cols_tb_2.pop(cols_tb_2.index('Total population of both sexes at mid-year (thousands)')))   # I change the column position
tb_2 = tb_2[cols_tb_2]

# %%
tb_2 = tb_2.set_index('Sort order')
tb_2
# Out:
#            Major area, region, country or area of destination Notes  \
# Sort order
# 1                                                       WORLD   NaN
# 2                                           Developed regions   (b)
# 3                                          Developing regions   (c)
# 4                                   Least developed countries   (d)
# 5           Less developed regions excluding least develop...   NaN
# ...                                                       ...   ...
# 261                                                     Samoa   NaN
# 262                                                   Tokelau   NaN
# 263                                                     Tonga   NaN
# 264                                                    Tuvalu   NaN
# 265                                 Wallis and Futuna Islands   NaN
#
#             Country code      Gender  Year  \
# Sort order
# 1                    900  both sexes  1990
# 2                    901  both sexes  1990
# 3                    902  both sexes  1990
# 4                    941  both sexes  1990
# 5                    934  both sexes  1990
# ...                  ...         ...   ...
# 261                  882      female  2015
# 262                  772      female  2015
# 263                  776      female  2015
# 264                  798      female  2015
# 265                  876      female  2015
#
#            Total population of both sexes at mid-year (thousands)
# Sort order
# 1                                                 5309667.699
# 2                                                 1144463.062
# 3                                                 4165204.637
# 4                                                  510057.629
# 5                                                 3655147.008
# ...                                                       ...
# 261                                                    93.584
# 262                                                        ..
# 263                                                    52.931
# 264                                                        ..
# 265                                                        ..
#
# [4770 rows x 6 columns]

# %%
#@title Table 3 Cleaning

# %%
import pandas as pd
import numpy as np
from google.colab import drive
tb_3 = pd.read_excel("/content/UN_MigrantStockTotal_2015.xlsx", sheet_name ="Table 3")
tb_3.drop(tb_3.index[0:15], inplace=True)
tb_3.columns = ["Sort order", "Major area, region, country or area of destination", "Notes",
               "Country code", "Type of data (a)", "both_sexs1990", "both_sexs1995", "both_sexs2000", "both_sexs2005", "both_sexs2010",
               "both_sexs2015", "male1990", "male1995", "male2000", "male2005", "male2010", "male2015", "female1990", "female1995", "female2000",
               "female2005", "female2010", "female2015"]

# %%
tb_3=tb_3.melt(id_vars=["Sort order","Major area, region, country or area of destination","Notes","Country code","Type of data (a)"],var_name=["Genderandyear"],value_name="International migrant stock as a percentage of the total population")
tb_3.head(5)
# Out:
#   Sort order Major area, region, country or area of destination Notes  \
# 0          1                                              WORLD   NaN
# 1          2                                  Developed regions   (b)
# 2          3                                 Developing regions   (c)
# 3          4                          Least developed countries   (d)
# 4          5  Less developed regions excluding least develop...   NaN
#
#   Country code Type of data (a)  Genderandyear  \
# 0          900              NaN  both_sexs1990
# 1          901              NaN  both_sexs1990
# 2          902              NaN  both_sexs1990
# 3          941              NaN  both_sexs1990
# 4          934              NaN  both_sexs1990
#
#   International migrant stock as a percentage of the total population
# 0                                            2.87331
# 1                                           7.198015
# 2                                           1.685021
# 3                                           2.171513
# 4                                           1.617042

# %%
tb_3 = tb_3.assign(Gender = lambda x: x.Genderandyear.str[0].astype(str), Year = lambda x: x.Genderandyear.str[-4:].astype(str))
tb_3 = tb_3.drop("Genderandyear", axis = 1)

# %%
tb_3 = tb_3.replace(to_replace=["f", "b", "m"], value=["female", "both sexes", "male"])
tb_3.head(4770)
# Out:
#       Sort order Major area, region, country or area of destination Notes  \
# 0              1                                              WORLD   NaN
# 1              2                                  Developed regions   (b)
# 2              3                                 Developing regions   (c)
# 3              4                          Least developed countries   (d)
# 4              5  Less developed regions excluding least develop...   NaN
# ...          ...                                                ...   ...
# 4765         261                                              Samoa   NaN
# 4766         262                                            Tokelau   NaN
# 4767         263                                              Tonga   NaN
# 4768         264                                             Tuvalu   NaN
# 4769         265                          Wallis and Futuna Islands   NaN
#
#       Country code Type of data (a)  \
# 0              900              NaN
# 1              901              NaN
# 2              902              NaN
# 3              941              NaN
# 4              934              NaN
# ...            ...              ...
# 4765           882                B
# 4766           772                B
# 4767           776                B
# 4768           798                C
# 4769           876                B
#
#      International migrant stock as a percentage of the total population  \
# 0                                               2.87331
# 1                                              7.198015
# 2                                              1.685021
# 3                                              2.171513
# 4                                              1.617042
# ...                                                 ...
# 4765                                           2.628654
# 4766                                                 ..
# 4767                                           4.919612
# 4768                                                 ..
# 4769                                                 ..
#
#           Gender  Year
# 0     both sexes  1990
# 1     both sexes  1990
# 2     both sexes  1990
# 3     both sexes  1990
# 4     both sexes  1990
# ...          ...   ...
# 4765      female  2015
# 4766      female  2015
# 4767      female  2015
# 4768      female  2015
# 4769      female  2015
#
# [4770 rows x 8 columns]

# %%
cols_tb_3 = tb_3.columns.tolist()
cols_tb_3.insert(7,cols_tb_3.pop(cols_tb_3.index('International migrant stock as a percentage of the total population')))   # I change the column position
tb_3 = tb_3[cols_tb_3]

# %%
tb_3 = tb_3.set_index('Sort order')
tb_3
# Out:
#            Major area, region, country or area of destination Notes  \
# Sort order
# 1                                                       WORLD   NaN
# 2                                           Developed regions   (b)
# 3                                          Developing regions   (c)
# 4                                   Least developed countries   (d)
# 5           Less developed regions excluding least develop...   NaN
# ...                                                       ...   ...
# 261                                                     Samoa   NaN
# 262                                                   Tokelau   NaN
# 263                                                     Tonga   NaN
# 264                                                    Tuvalu   NaN
# 265                                 Wallis and Futuna Islands   NaN
#
#             Country code Type of data (a)      Gender  Year  \
# Sort order
# 1                    900              NaN  both sexes  1990
# 2                    901              NaN  both sexes  1990
# 3                    902              NaN  both sexes  1990
# 4                    941              NaN  both sexes  1990
# 5                    934              NaN  both sexes  1990
# ...                  ...              ...         ...   ...
# 261                  882                B      female  2015
# 262                  772                B      female  2015
# 263                  776                B      female  2015
# 264                  798                C      female  2015
# 265                  876                B      female  2015
#
#            International migrant stock as a percentage of the total population
# Sort order
# 1                                                     2.87331
# 2                                                    7.198015
# 3                                                    1.685021
# 4                                                    2.171513
# 5                                                    1.617042
# ...                                                       ...
# 261                                                  2.628654
# 262                                                        ..
# 263                                                  4.919612
# 264                                                        ..
# 265                                                        ..
#
# [4770 rows x 7 columns]

# %%
#@title Table 4 Cleaning

# %%
import pandas as pd
import numpy as np
from google.colab import drive
tb_4 = pd.read_excel("/content/UN_MigrantStockTotal_2015.xlsx", sheet_name ="Table 4")
tb_4.drop(tb_4.index[0:15], inplace=True)
tb_4.columns = ["Sort order", "Major area, region, country or area of destination", "Notes",
               "Country code", "Type of data (a)", "female1990", "female1995", "female2000",
               "female2005", "female2010", "female2015"]

# %%
tb_4=tb_4.melt(id_vars=["Sort order","Major area, region, country or area of destination","Notes","Country code","Type of data (a)"],var_name=["Genderandyear"],value_name="Female migrants as a percentage of the international migrant stock")

# %%
tb_4 = tb_4.assign( Year = lambda x: x.Genderandyear.str[-4:].astype(str))
tb_4 = tb_4.drop("Genderandyear", axis = 1)
tb_4.head(5)
# Out:
#   Sort order Major area, region, country or area of destination Notes  \
# 0          1                                              WORLD   NaN
# 1          2                                  Developed regions   (b)
# 2          3                                 Developing regions   (c)
# 3          4                          Least developed countries   (d)
# 4          5  Less developed regions excluding least develop...   NaN
#
#   Country code Type of data (a)  \
# 0          900              NaN
# 1          901              NaN
# 2          902              NaN
# 3          941              NaN
# 4          934              NaN
#
#   Female migrants as a percentage of the international migrant stock  Year
# 0                                           49.03915                  1990
# 1                                          51.123977                  1990
# 2                                          46.592099                  1990
# 3                                          47.261155                  1990
# 4                                          46.466684                  1990

# %%
cols_tb_4 = tb_4.columns.tolist()
cols_tb_4.insert(6,cols_tb_4.pop(cols_tb_4.index('Female migrants as a percentage of the international migrant stock')))   # I change the column position
tb_4 = tb_4[cols_tb_4]

# %%
tb_4 = tb_4.set_index('Sort order')
tb_4
# Out:
#            Major area, region, country or area of destination Notes  \
# Sort order
# 1                                                       WORLD   NaN
# 2                                           Developed regions   (b)
# 3                                          Developing regions   (c)
# 4                                   Least developed countries   (d)
# 5           Less developed regions excluding least develop...   NaN
# ...                                                       ...   ...
# 261                                                     Samoa   NaN
# 262                                                   Tokelau   NaN
# 263                                                     Tonga   NaN
# 264                                                    Tuvalu   NaN
# 265                                 Wallis and Futuna Islands   NaN
#
#            Country code Type of data (a)  Year  \
# Sort order
# 1                   900              NaN  1990
# 2                   901              NaN  1990
# 3                   902              NaN  1990
# 4                   941              NaN  1990
# 5                   934              NaN  1990
# ...                 ...              ...   ...
# 261                 882                B  2015
# 262                 772                B  2015
# 263                 776                B  2015
# 264                 798                C  2015
# 265                 876                B  2015
#
#            Female migrants as a percentage of the international migrant stock
# Sort order
# 1                                                    49.03915
# 2                                                   51.123977
# 3                                                   46.592099
# 4                                                   47.261155
# 5                                                   46.466684
# ...                                                       ...
# 261                                                 49.908704
# 262                                                 52.156057
# 263                                                 45.437096
# 264                                                 44.680851
# 265                                                  49.52615
#
# [1590 rows x 6 columns]

# %%
#@title Table 5 Cleaning

# %%
import pandas as pd
import numpy as np
from google.colab import drive
tb_5 = pd.read_excel("/content/UN_MigrantStockTotal_2015.xlsx", sheet_name ="Table 5")
tb_5.drop(tb_5.index[0:15], inplace=True)
tb_5.columns = ["Sort order", "Major area, region, country or area of destination", "Notes",
               "Country code", "Type of data (a)", "both_sexs1990-1995", "both_sexs1995-2000", "both_sexs2000-2005", "both_sexs2005-2010", "both_sexs2010-2015","male1990-1995","male1995-2000",
                "male2000-2005", "male2005-2010", "male2010-2015","female1990-1995","female1995-2000","female2000-2005","female2005-2010","female2010-2015"]
tb_5
# Out:
#     Sort order Major area, region, country or area of destination Notes  \
# 15           1                                              WORLD   NaN
# 16           2                                  Developed regions   (b)
# 17           3                                 Developing regions   (c)
# 18           4                          Least developed countries   (d)
# 19           5  Less developed regions excluding least develop...   NaN
# ..         ...                                                ...   ...
# 275        261                                              Samoa   NaN
# 276        262                                            Tokelau   NaN
# 277        263                                              Tonga   NaN
# 278        264                                             Tuvalu   NaN
# 279        265                          Wallis and Futuna Islands   NaN
#
#     Country code Type of data (a) both_sexs1990-1995 both_sexs1995-2000  \
# 15           900              NaN           1.051865           1.428058
# 16           901              NaN           2.275847           2.264965
# 17           902              NaN          -0.487389           0.241777
# 18           941              NaN           1.118175          -3.001139
# 19           934              NaN          -0.803244           0.850177
# ..           ...              ...                ...                ...
# 275          882                B           6.704748            4.90282
# 276          772                B          -0.298513          -0.303036
# 277          776                B           2.350316           2.359733
# 278          798                C          -3.797947          -3.845134
# 279          876                B            3.61788           3.636508
#
#     both_sexs2000-2005 both_sexs2005-2010 both_sexs2010-2015 male1990-1995  \
# 15            2.042124            2.95416           1.890991      1.000922
# 16             2.50708           2.466343           1.160824      2.265595
# 17            1.328107           3.702217           2.929634      -0.45298
# 18           -0.539636           0.419137           3.526927      1.000073
# 19             1.62934           4.159339           2.852687     -0.733256
# ..                 ...                ...                ...           ...
# 275          -0.858442          -2.299179          -0.768177      6.499035
# 276          -0.307698          10.169947           2.536144     -0.404054
# 277           3.096969           3.099614           2.641235      2.874558
# 278          -3.408224          -3.450671          -1.763854     -3.914892
# 279           3.203177            3.20466            0.51914      3.364378
#
#     male1995-2000 male2000-2005 male2005-2010 male2010-2015 female1990-1995  \
# 15       1.450294      2.151575      3.159228      1.912603        1.104667
# 16       2.279583      2.483259      2.265689      1.074685        2.285643
# 17       0.380246      1.693824      4.352954      2.927058       -0.526904
# 18      -2.718952      0.078575      0.293964      3.363629        1.249146
# 19       0.950231      1.952269       4.90598       2.87349        -0.88418
# ..            ...           ...           ...           ...             ...
# 275      4.704571     -1.066301      -2.50417     -0.987758        6.931983
# 276     -0.412386     -1.589283      8.750541      2.463246       -0.167365
# 277      2.848819      3.228155      3.163851      2.737439        1.787022
# 278     -4.028435     -3.613401     -3.449385     -1.718849       -3.646431
# 279      3.396526      3.189382      3.197545       0.52134        3.886601
#
#     female1995-2000 female2000-2005 female2005-2010 female2010-2015
# 15         1.405044         1.92808        2.737012        1.867837
# 16         2.250995        2.529838         2.65595        1.241097
# 17         0.081268         0.89236        2.881555        2.933003
# 18        -3.316818       -1.265617         0.57011         3.72079
# 19         0.733402        1.243624        3.212358        2.825127
# ..              ...             ...             ...             ...
# 275        5.117229       -0.638315        -2.08663       -0.545343
# 276       -0.168777        1.152582       11.577161         2.60325
# 277         1.80546        2.943277        3.023552        2.526318
# 278       -3.611679       -3.152579       -3.452255       -1.819436
# 279        3.884553        3.217252        3.211913        0.516899
#
# [265 rows x 20 columns]

# %%
tb_5=tb_5.melt(id_vars=["Sort order","Major area, region, country or area of destination","Notes","Country code","Type of data (a)"],var_name=["Genderandyear"],value_name="Annual rate of change of the migrant stock")
tb_5.head(5)
# Out:
#   Sort order Major area, region, country or area of destination Notes  \
# 0          1                                              WORLD   NaN
# 1          2                                  Developed regions   (b)
# 2          3                                 Developing regions   (c)
# 3          4                          Least developed countries   (d)
# 4          5  Less developed regions excluding least develop...   NaN
#
#   Country code Type of data (a)       Genderandyear  \
# 0          900              NaN  both_sexs1990-1995
# 1          901              NaN  both_sexs1990-1995
# 2          902              NaN  both_sexs1990-1995
# 3          941              NaN  both_sexs1990-1995
# 4          934              NaN  both_sexs1990-1995
#
#   Annual rate of change of the migrant stock
# 0                                   1.051865
# 1                                   2.275847
# 2                                  -0.487389
# 3                                   1.118175
# 4                                  -0.803244

# %%
tb_5 = tb_5.assign(Gender = lambda x: x.Genderandyear.str[0].astype(str), TimePeiord = lambda x: x.Genderandyear.str[-9:].astype(str))
tb_5 = tb_5.drop("Genderandyear", axis = 1)

# %%
tb_5 = tb_5.replace(to_replace=["f", "b", "m"], value=["female", "both sexes", "male"])

# %%
cols_tb_5 = tb_5.columns.tolist()
cols_tb_5.insert(7,cols_tb_5.pop(cols_tb_5.index('Annual rate of change of the migrant stock')))   # I change the column position
tb_5 = tb_5[cols_tb_5]

# %%
tb_5 = tb_5.set_index('Sort order')
tb_5
# Out:
#            Major area, region, country or area of destination Notes  \
# Sort order
# 1                                                       WORLD   NaN
# 2                                           Developed regions   (b)
# 3                                          Developing regions   (c)
# 4                                   Least developed countries   (d)
# 5           Less developed regions excluding least develop...   NaN
# ...                                                       ...   ...
# 261                                                     Samoa   NaN
# 262                                                   Tokelau   NaN
# 263                                                     Tonga   NaN
# 264                                                    Tuvalu   NaN
# 265                                 Wallis and Futuna Islands   NaN
#
#             Country code Type of data (a)      Gender TimePeiord  \
# Sort order
# 1                    900              NaN  both sexes  1990-1995
# 2                    901              NaN  both sexes  1990-1995
# 3                    902              NaN  both sexes  1990-1995
# 4                    941              NaN  both sexes  1990-1995
# 5                    934              NaN  both sexes  1990-1995
# ...                  ...              ...         ...        ...
# 261                  882                B      female  2010-2015
# 262                  772                B      female  2010-2015
# 263                  776                B      female  2010-2015
# 264                  798                C      female  2010-2015
# 265                  876                B      female  2010-2015
#
#            Annual rate of change of the migrant stock
# Sort order
# 1                                            1.051865
# 2                                            2.275847
# 3                                           -0.487389
# 4                                            1.118175
# 5                                           -0.803244
# ...                                               ...
# 261                                         -0.545343
# 262                                           2.60325
# 263                                          2.526318
# 264                                         -1.819436
# 265                                          0.516899
#
# [3975 rows x 7 columns]

# %%
#@title Table 6 Cleaning

# %%
import pandas as pd
import numpy as np
from google.colab import drive
tb_6 = pd.read_excel("/content/UN_MigrantStockTotal_2015.xlsx", sheet_name ="Table 6")
tb_6.drop(tb_6.index[0:15], inplace=True)
tb_6.columns = ["Sort order", "Major area, region, country or area of destination", "Notes",
               "Country code", "Type of data (a)", "both_sexes1990", "both_sexes1995", "both_sexes2000", "both_sexes2005", "both_sexes2010","both_sexes2015","1990", "1995","2000","2005","2010"
               ,"2015", "1990-1995","1995-2000","2000-2005","2005-2010","2010-2015"]
tb_6
# Out:
#     Sort order Major area, region, country or area of destination Notes  \
# 15           1                                              WORLD   NaN
# 16           2                                  Developed regions   (b)
# 17           3                                 Developing regions   (c)
# 18           4                          Least developed countries   (d)
# 19           5  Less developed regions excluding least develop...   NaN
# ..         ...                                                ...   ...
# 275        261                                              Samoa   NaN
# 276        262                                            Tokelau   NaN
# 277        263                                              Tonga   NaN
# 278        264                                             Tuvalu   NaN
# 279        265                          Wallis and Futuna Islands   NaN
#
#     Country code Type of data (a) both_sexes1990 both_sexes1995  \
# 15           900              NaN       18836571       17853840
# 16           901              NaN        2014564        3609670
# 17           902              NaN       16822007       14244170
# 18           941              NaN        5048391        5160131
# 19           934              NaN       11773616        9084039
# ..           ...              ...            ...            ...
# 275          882                B              0              0
# 276          772                B              0              0
# 277          776                B              0              0
# 278          798                C              0              0
# 279          876                B              0              0
#
#     both_sexes2000 both_sexes2005  both_sexes2010  ...       1995       2000  \
# 15        15827803       13276733      15370755.0  ...  11.103013   9.164736
# 16         2997256        2361229       2046917.0  ...   3.910511   2.899391
# 17        12830547       10915504      13323838.0  ...  20.795958  18.507035
# 18         3047488        2363782       1957884.0  ...  44.041961  30.221557
# 19         9783059        8551722      11365954.0  ...  15.999082   16.51313
# ..             ...            ...             ...  ...        ...        ...
# 275              0              0             0.0  ...          0          0
# 276              0              0             0.0  ...          0          0
# 277              0              0             0.0  ...          0          0
# 278              0              0             0.0  ...          0          0
# 279              0              0             0.0  ...          0          0
#
#           2005       2010       2015  1990-1995  1995-2000 2000-2005  \
# 15    6.941389   6.932687   8.033424  -2.123497  -3.837069 -5.557223
# 16    2.015025   1.544140   1.391085   9.388424  -5.983348 -7.277379
# 17   14.733162  14.944759  17.073768  -2.839417  -2.332154    -4.561
# 18    24.08243  19.533425  28.801534  -0.680327  -7.531747 -4.541459
# 19   13.305391  14.363526  15.537313    -4.3836   0.632489 -4.319731
# ..         ...        ...        ...        ...        ...       ...
# 275          0   0.000000   0.000000         ..         ..        ..
# 276          0   0.000000   0.000000         ..         ..        ..
# 277          0   0.000000   0.000000         ..         ..        ..
# 278          0   0.000000   0.000000         ..         ..        ..
# 279          0   0.000000   0.000000         ..         ..        ..
#
#     2005-2010 2010-2015
# 15  -0.025089  2.947267
# 16  -5.323293 -2.087656
# 17   0.285195  2.663652
# 18  -4.187109  7.766031
# 19   1.530456  1.571047
# ..        ...       ...
# 275        ..        ..
# 276        ..        ..
# 277        ..        ..
# 278        ..        ..
# 279        ..        ..
#
# [265 rows x 22 columns]

# %%
#@title tb_6_E1
#this table contains different variables, so I need to split it into three different sub-tables

# %%
tb_6_E1 = tb_6
tb_6_E1.columns
# Out:
# Index(['Sort order', 'Major area, region, country or area of destination',
#        'Notes', 'Country code', 'Type of data (a)', 'both_sexes1990',
#        'both_sexes1995', 'both_sexes2000', 'both_sexes2005', 'both_sexes2010',
#        'both_sexes2015', '1990', '1995', '2000', '2005', '2010', '2015',
#        '1990-1995', '1995-2000', '2000-2005', '2005-2010', '2010-2015'],
#       dtype='object')

# %%
tb_6_E1_drop=tb_6_E1.drop(['1990', '1995', '2000', '2005', '2010', '2015',
       '1990-1995', '1995-2000', '2000-2005', '2005-2010', '2010-2015'],axis=1) #leave Estimated refugee stock at mid-year (both sexes)
tb_6_E1_drop
# Out:
#     Sort order Major area, region, country or area of destination Notes  \
# 15           1                                              WORLD   NaN
# 16           2                                  Developed regions   (b)
# 17           3                                 Developing regions   (c)
# 18           4                          Least developed countries   (d)
# 19           5  Less developed regions excluding least develop...   NaN
# ..         ...                                                ...   ...
# 275        261                                              Samoa   NaN
# 276        262                                            Tokelau   NaN
# 277        263                                              Tonga   NaN
# 278        264                                             Tuvalu   NaN
# 279        265                          Wallis and Futuna Islands   NaN
#
#     Country code Type of data (a) both_sexes1990 both_sexes1995  \
# 15           900              NaN       18836571       17853840
# 16           901              NaN        2014564        3609670
# 17           902              NaN       16822007       14244170
# 18           941              NaN        5048391        5160131
# 19           934              NaN       11773616        9084039
# ..           ...              ...            ...            ...
# 275          882                B              0              0
# 276          772                B              0              0
# 277          776                B              0              0
# 278          798                C              0              0
# 279          876                B              0              0
#
#     both_sexes2000 both_sexes2005  both_sexes2010  both_sexes2015
# 15        15827803       13276733      15370755.0      19577474.0
# 16         2997256        2361229       2046917.0       1954224.0
# 17        12830547       10915504      13323838.0      17623250.0
# 18         3047488        2363782       1957884.0       3443582.0
# 19         9783059        8551722      11365954.0      14179668.0
# ..             ...            ...             ...             ...
# 275              0              0             0.0             0.0
# 276              0              0             0.0             0.0
# 277              0              0             0.0             0.0
# 278              0              0             0.0             0.0
# 279              0              0             0.0             0.0
#
# [265 rows x 11 columns]

# %%
tb_6_E1_drop=tb_6_E1_drop.melt(id_vars=["Sort order","Major area, region, country or area of destination",
                        "Notes","Country code","Type of data (a)"],var_name=["Genderandyear"],value_name="Estimated refugee stock at mid-year (both sexes)")
tb_6_E1_drop
# Out:
#      Sort order Major area, region, country or area of destination Notes  \
# 0             1                                              WORLD   NaN
# 1             2                                  Developed regions   (b)
# 2             3                                 Developing regions   (c)
# 3             4                          Least developed countries   (d)
# 4             5  Less developed regions excluding least develop...   NaN
# ...         ...                                                ...   ...
# 1585        261                                              Samoa   NaN
# 1586        262                                            Tokelau   NaN
# 1587        263                                              Tonga   NaN
# 1588        264                                             Tuvalu   NaN
# 1589        265                          Wallis and Futuna Islands   NaN
#
#      Country code Type of data (a)   Genderandyear  \
# 0             900              NaN  both_sexes1990
# 1             901              NaN  both_sexes1990
# 2             902              NaN  both_sexes1990
# 3             941              NaN  both_sexes1990
# 4             934              NaN  both_sexes1990
# ...           ...              ...             ...
# 1585          882                B  both_sexes2015
# 1586          772                B  both_sexes2015
# 1587          776                B  both_sexes2015
# 1588          798                C  both_sexes2015
# 1589          876                B  both_sexes2015
#
#      Estimated refugee stock at mid-year (both sexes)
# 0                                            18836571
# 1                                             2014564
# 2                                            16822007
# 3                                             5048391
# 4                                            11773616
# ...                                               ...
# 1585                                              0.0
# 1586                                              0.0
# 1587                                              0.0
# 1588                                              0.0
# 1589                                              0.0
#
# [1590 rows x 7 columns]

# %%
tb_6_E1_drop = tb_6_E1_drop.assign(Gender = lambda x: x.Genderandyear.str[0].astype(str), Year = lambda x: x.Genderandyear.str[-4:].astype(str))
tb_6_E1_drop = tb_6_E1_drop.drop("Genderandyear", axis = 1)
tb_6_E1_drop
# Out:
#      Sort order Major area, region, country or area of destination Notes  \
# 0             1                                              WORLD   NaN
# 1             2                                  Developed regions   (b)
# 2             3                                 Developing regions   (c)
# 3             4                          Least developed countries   (d)
# 4             5  Less developed regions excluding least develop...   NaN
# ...         ...                                                ...   ...
# 1585        261                                              Samoa   NaN
# 1586        262                                            Tokelau   NaN
# 1587        263                                              Tonga   NaN
# 1588        264                                             Tuvalu   NaN
# 1589        265                          Wallis and Futuna Islands   NaN
#
#      Country code Type of data (a)  \
# 0             900              NaN
# 1             901              NaN
# 2             902              NaN
# 3             941              NaN
# 4             934              NaN
# ...           ...              ...
# 1585          882                B
# 1586          772                B
# 1587          776                B
# 1588          798                C
# 1589          876                B
#
#      Estimated refugee stock at mid-year (both sexes) Gender  Year
# 0                                            18836571      b  1990
# 1                                             2014564      b  1990
# 2                                            16822007      b  1990
# 3                                             5048391      b  1990
# 4                                            11773616      b  1990
# ...                                               ...    ...   ...
# 1585                                              0.0      b  2015
# 1586                                              0.0      b  2015
# 1587                                              0.0      b  2015
# 1588                                              0.0      b  2015
# 1589                                              0.0      b  2015
#
# [1590 rows x 8 columns]

# %%
tb_6_E1_drop = tb_6_E1_drop.replace(to_replace=["b"], value=["both sexes"])

# %%
cols_tb_6_E1_drop = tb_6_E1_drop.columns.tolist()
cols_tb_6_E1_drop.insert(7,cols_tb_6_E1_drop.pop(cols_tb_6_E1_drop.index('Estimated refugee stock at mid-year (both sexes)')))   # I change the column position
tb_6_E1_drop = tb_6_E1_drop[cols_tb_6_E1_drop]

# %%
tb_6_E1_drop = tb_6_E1_drop.set_index('Sort order')
tb_6_E1_drop
# Out:
#            Major area, region, country or area of destination Notes  \
# Sort order
# 1                                                       WORLD   NaN
# 2                                           Developed regions   (b)
# 3                                          Developing regions   (c)
# 4                                   Least developed countries   (d)
# 5           Less developed regions excluding least develop...   NaN
# ...                                                       ...   ...
# 261                                                     Samoa   NaN
# 262                                                   Tokelau   NaN
# 263                                                     Tonga   NaN
# 264                                                    Tuvalu   NaN
# 265                                 Wallis and Futuna Islands   NaN
#
#             Country code Type of data (a)      Gender  Year  \
# Sort order
# 1                    900              NaN  both sexes  1990
# 2                    901              NaN  both sexes  1990
# 3                    902              NaN  both sexes  1990
# 4                    941              NaN  both sexes  1990
# 5                    934              NaN  both sexes  1990
# ...                  ...              ...         ...   ...
# 261                  882                B  both sexes  2015
# 262                  772                B  both sexes  2015
# 263                  776                B  both sexes  2015
# 264                  798                C  both sexes  2015
# 265                  876                B  both sexes  2015
#
#            Estimated refugee stock at mid-year (both sexes)
# Sort order
# 1                                                  18836571
# 2                                                   2014564
# 3                                                  16822007
# 4                                                   5048391
# 5                                                  11773616
# ...                                                     ...
# 261                                                     0.0
# 262                                                     0.0
# 263                                                     0.0
# 264                                                     0.0
# 265                                                     0.0
#
# [1590 rows x 7 columns]

# %%
#@title tb_6_E2

# %%
tb_6_E2 = tb_6
tb_6_E2.columns
# Out:
# Index(['Sort order', 'Major area, region, country or area of destination',
#        'Notes', 'Country code', 'Type of data (a)', 'both_sexes1990',
#        'both_sexes1995', 'both_sexes2000', 'both_sexes2005', 'both_sexes2010',
#        'both_sexes2015', '1990', '1995', '2000', '2005', '2010', '2015',
#        '1990-1995', '1995-2000', '2000-2005', '2005-2010', '2010-2015'],
#       dtype='object')

# %%
tb_6_E2_drop=tb_6_E2.drop([ 'both_sexes1990',
       'both_sexes1995', 'both_sexes2000', 'both_sexes2005', 'both_sexes2010',
       'both_sexes2015','1990-1995', '1995-2000', '2000-2005', '2005-2010', '2010-2015'],axis=1) #leave Refugees as a percentage of the international migrant stock
tb_6_E2_drop
# Out:
#     Sort order Major area, region, country or area of destination Notes  \
# 15           1                                              WORLD   NaN
# 16           2                                  Developed regions   (b)
# 17           3                                 Developing regions   (c)
# 18           4                          Least developed countries   (d)
# 19           5  Less developed regions excluding least develop...   NaN
# ..         ...                                                ...   ...
# 275        261                                              Samoa   NaN
# 276        262                                            Tokelau   NaN
# 277        263                                              Tonga   NaN
# 278        264                                             Tuvalu   NaN
# 279        265                          Wallis and Futuna Islands   NaN
#
#     Country code Type of data (a)       1990       1995       2000       2005  \
# 15           900              NaN  12.346732  11.103013   9.164736   6.941389
# 16           901              NaN   2.445494   3.910511   2.899391   2.015025
# 17           902              NaN  23.968236  20.795958  18.507035  14.733162
# 18           941              NaN   45.56588  44.041961  30.221557   24.08243
# 19           934              NaN  19.919743  15.999082   16.51313  13.305391
# ..           ...              ...        ...        ...        ...        ...
# 275          882                B          0          0          0          0
# 276          772                B          0          0          0          0
# 277          776                B          0          0          0          0
# 278          798                C          0          0          0          0
# 279          876                B          0          0          0          0
#
#           2010       2015
# 15    6.932687   8.033424
# 16    1.544140   1.391085
# 17   14.944759  17.073768
# 18   19.533425  28.801534
# 19   14.363526  15.537313
# ..         ...        ...
# 275   0.000000   0.000000
# 276   0.000000   0.000000
# 277   0.000000   0.000000
# 278   0.000000   0.000000
# 279   0.000000   0.000000
#
# [265 rows x 11 columns]

# %%
tb_6_E2_drop=tb_6_E2_drop.melt(id_vars=["Sort order","Major area, region, country or area of destination",
                        "Notes","Country code","Type of data (a)"],var_name=["Year"],value_name="Refugees as a percentage of the international migrant stock")
tb_6_E2_drop
# Out:
#      Sort order Major area, region, country or area of destination Notes  \
# 0             1                                              WORLD   NaN
# 1             2                                  Developed regions   (b)
# 2             3                                 Developing regions   (c)
# 3             4                          Least developed countries   (d)
# 4             5  Less developed regions excluding least develop...   NaN
# ...         ...                                                ...   ...
# 1585        261                                              Samoa   NaN
# 1586        262                                            Tokelau   NaN
# 1587        263                                              Tonga   NaN
# 1588        264                                             Tuvalu   NaN
# 1589        265                          Wallis and Futuna Islands   NaN
#
#      Country code Type of data (a)  Year  \
# 0             900              NaN  1990
# 1             901              NaN  1990
# 2             902              NaN  1990
# 3             941              NaN  1990
# 4             934              NaN  1990
# ...           ...              ...   ...
# 1585          882                B  2015
# 1586          772                B  2015
# 1587          776                B  2015
# 1588          798                C  2015
# 1589          876                B  2015
#
#      Refugees as a percentage of the international migrant stock
# 0                                             12.346732
# 1                                              2.445494
# 2                                             23.968236
# 3                                              45.56588
# 4                                             19.919743
# ...                                                 ...
# 1585                                                0.0
# 1586                                                0.0
# 1587                                                0.0
# 1588                                                0.0
# 1589                                                0.0
#
# [1590 rows x 7 columns]

# %%
cols_tb_6_E2_drop = tb_6_E2_drop.columns.tolist()
cols_tb_6_E2_drop.insert(6,cols_tb_6_E2_drop.pop(cols_tb_6_E2_drop.index('Refugees as a percentage of the international migrant stock')))   # I change the column position
tb_6_E2_drop = tb_6_E2_drop[cols_tb_6_E2_drop]

# %%
tb_6_E2_drop = tb_6_E2_drop.set_index('Sort order')
tb_6_E2_drop
# Out:
#            Major area, region, country or area of destination Notes  \
# Sort order
# 1                                                       WORLD   NaN
# 2                                           Developed regions   (b)
# 3                                          Developing regions   (c)
# 4                                   Least developed countries   (d)
# 5           Less developed regions excluding least develop...   NaN
# ...                                                       ...   ...
# 261                                                     Samoa   NaN
# 262                                                   Tokelau   NaN
# 263                                                     Tonga   NaN
# 264                                                    Tuvalu   NaN
# 265                                 Wallis and Futuna Islands   NaN
#
#            Country code Type of data (a)  Year  \
# Sort order
# 1                   900              NaN  1990
# 2                   901              NaN  1990
# 3                   902              NaN  1990
# 4                   941              NaN  1990
# 5                   934              NaN  1990
# ...                 ...              ...   ...
# 261                 882                B  2015
# 262                 772                B  2015
# 263                 776                B  2015
# 264                 798                C  2015
# 265                 876                B  2015
#
#            Refugees as a percentage of the international migrant stock
# Sort order
# 1                                                   12.346732
# 2                                                    2.445494
# 3                                                   23.968236
# 4                                                    45.56588
# 5                                                   19.919743
# ...                                                       ...
# 261                                                       0.0
# 262                                                       0.0
# 263                                                       0.0
# 264                                                       0.0
# 265                                                       0.0
#
# [1590 rows x 6 columns]

# %%
#@title tb_6_E3

# %%
tb_6_E3 = tb_6
tb_6_E3.columns
# Out:
# Index(['Sort order', 'Major area, region, country or area of destination',
#        'Notes', 'Country code', 'Type of data (a)', 'both_sexes1990',
#        'both_sexes1995', 'both_sexes2000', 'both_sexes2005', 'both_sexes2010',
#        'both_sexes2015', '1990', '1995', '2000', '2005', '2010', '2015',
#        '1990-1995', '1995-2000', '2000-2005', '2005-2010', '2010-2015'],
#       dtype='object')

# %%
tb_6_E3_drop=tb_6_E3.drop([ 'both_sexes1990',
       'both_sexes1995', 'both_sexes2000', 'both_sexes2005', 'both_sexes2010',
       'both_sexes2015','1990', '1995', '2000', '2005', '2010', '2015'],axis=1) #leave Annual rate of change of the refugee stock alone
tb_6_E3_drop
# Out:
#     Sort order Major area, region, country or area of destination Notes  \
# 15           1                                              WORLD   NaN
# 16           2                                  Developed regions   (b)
# 17           3                                 Developing regions   (c)
# 18           4                          Least developed countries   (d)
# 19           5  Less developed regions excluding least develop...   NaN
# ..         ...                                                ...   ...
# 275        261                                              Samoa   NaN
# 276        262                                            Tokelau   NaN
# 277        263                                              Tonga   NaN
# 278        264                                             Tuvalu   NaN
# 279        265                          Wallis and Futuna Islands   NaN
#
#     Country code Type of data (a) 1990-1995 1995-2000 2000-2005 2005-2010  \
# 15           900              NaN -2.123497 -3.837069 -5.557223 -0.025089
# 16           901              NaN  9.388424 -5.983348 -7.277379 -5.323293
# 17           902              NaN -2.839417 -2.332154    -4.561  0.285195
# 18           941              NaN -0.680327 -7.531747 -4.541459 -4.187109
# 19           934              NaN   -4.3836  0.632489 -4.319731  1.530456
# ..           ...              ...       ...       ...       ...       ...
# 275          882                B        ..        ..        ..        ..
# 276          772                B        ..        ..        ..        ..
# 277          776                B        ..        ..        ..        ..
# 278          798                C        ..        ..        ..        ..
# 279          876                B        ..        ..        ..        ..
#
#     2010-2015
# 15   2.947267
# 16  -2.087656
# 17   2.663652
# 18   7.766031
# 19   1.571047
# ..        ...
# 275        ..
# 276        ..
# 277        ..
# 278        ..
# 279        ..
#
# [265 rows x 10 columns]

# %%
tb_6_E3_drop=tb_6_E3_drop.melt(id_vars=["Sort order","Major area, region, country or area of destination",
                        "Notes","Country code","Type of data (a)"],var_name=["TimePeriod"],value_name="Annual rate of change of the refugee stock")
tb_6_E3_drop
# Out:
#      Sort order Major area, region, country or area of destination Notes  \
# 0             1                                              WORLD   NaN
# 1             2                                  Developed regions   (b)
# 2             3                                 Developing regions   (c)
# 3             4                          Least developed countries   (d)
# 4             5  Less developed regions excluding least develop...   NaN
# ...         ...                                                ...   ...
# 1320        261                                              Samoa   NaN
# 1321        262                                            Tokelau   NaN
# 1322        263                                              Tonga   NaN
# 1323        264                                             Tuvalu   NaN
# 1324        265                          Wallis and Futuna Islands   NaN
#
#      Country code Type of data (a) TimePeriod  \
# 0             900              NaN  1990-1995
# 1             901              NaN  1990-1995
# 2             902              NaN  1990-1995
# 3             941              NaN  1990-1995
# 4             934              NaN  1990-1995
# ...           ...              ...        ...
# 1320          882                B  2010-2015
# 1321          772                B  2010-2015
# 1322          776                B  2010-2015
# 1323          798                C  2010-2015
# 1324          876                B  2010-2015
#
#      Annual rate of change of the refugee stock
# 0                                     -2.123497
# 1                                      9.388424
# 2                                     -2.839417
# 3                                     -0.680327
# 4                                       -4.3836
# ...                                         ...
# 1320                                         ..
# 1321                                         ..
# 1322                                         ..
# 1323                                         ..
# 1324                                         ..
#
# [1325 rows x 7 columns]

# %%
cols_tb_6_E3_drop = tb_6_E3_drop.columns.tolist()
cols_tb_6_E3_drop.insert(6,cols_tb_6_E3_drop.pop(cols_tb_6_E3_drop.index('Annual rate of change of the refugee stock')))   # I change the column position
tb_6_E3_drop = tb_6_E3_drop[cols_tb_6_E3_drop]

# %%
tb_6_E3_drop = tb_6_E3_drop.set_index('Sort order')
tb_6_E3_drop
# Out:
#            Major area, region, country or area of destination Notes  \
# Sort order
# 1                                                       WORLD   NaN
# 2                                           Developed regions   (b)
# 3                                          Developing regions   (c)
# 4                                   Least developed countries   (d)
# 5           Less developed regions excluding least develop...   NaN
# ...                                                       ...   ...
# 261                                                     Samoa   NaN
# 262                                                   Tokelau   NaN
# 263                                                     Tonga   NaN
# 264                                                    Tuvalu   NaN
# 265                                 Wallis and Futuna Islands   NaN
#
#            Country code Type of data (a) TimePeriod  \
# Sort order
# 1                   900              NaN  1990-1995
# 2                   901              NaN  1990-1995
# 3                   902              NaN  1990-1995
# 4                   941              NaN  1990-1995
# 5                   934              NaN  1990-1995
# ...                 ...              ...        ...
# 261                 882                B  2010-2015
# 262                 772                B  2010-2015
# 263                 776                B  2010-2015
# 264                 798                C  2010-2015
# 265                 876                B  2010-2015
#
#            Annual rate of change of the refugee stock
# Sort order
# 1                                           -2.123497
# 2                                            9.388424
# 3                                           -2.839417
# 4                                           -0.680327
# 5                                             -4.3836
# ...                                               ...
# 261                                                ..
# 262                                                ..
# 263                                                ..
# 264                                                ..
# 265                                                ..
#
# [1325 rows x 6 columns]

# %%
#@title Merge tables

# %%
final_1 = tb_1.merge(tb_3, how='left', on =['Sort order','Major area, region, country or area of destination',
                        'Notes','Country code','Type of data (a)','Year','Gender'])
final_1
# Out:
#            Major area, region, country or area of destination Notes  \
# Sort order
# 1                                                       WORLD   NaN
# 2                                           Developed regions   (b)
# 3                                          Developing regions   (c)
# 4                                   Least developed countries   (d)
# 5           Less developed regions excluding least develop...   NaN
# ...                                                       ...   ...
# 261                                                     Samoa   NaN
# 262                                                   Tokelau   NaN
# 263                                                     Tonga   NaN
# 264                                                    Tuvalu   NaN
# 265                                 Wallis and Futuna Islands   NaN
#
#             Country code Type of data (a)      Gender  Year  \
# Sort order
# 1                    900              NaN  both sexes  1990
# 2                    901              NaN  both sexes  1990
# 3                    902              NaN  both sexes  1990
# 4                    941              NaN  both sexes  1990
# 5                    934              NaN  both sexes  1990
# ...                  ...              ...         ...   ...
# 261                  882                B      female  2015
# 262                  772                B      female  2015
# 263                  776                B      female  2015
# 264                  798                C      female  2015
# 265                  876                B      female  2015
#
#            International migrant stock at mid-year  \
# Sort order
# 1                                        152563212
# 2                                         82378628
# 3                                         70184584
# 4                                         11075966
# 5                                         59105261
# ...                                            ...
# 261                                         2460.0
# 262                                          254.0
# 263                                         2604.0
# 264                                           63.0
# 265                                         1411.0
#
#            International migrant stock as a percentage of the total population
# Sort order
# 1                                                     2.87331
# 2                                                    7.198015
# 3                                                    1.685021
# 4                                                    2.171513
# 5                                                    1.617042
# ...                                                       ...
# 261                                                  2.628654
# 262                                                        ..
# 263                                                  4.919612
# 264                                                        ..
# 265                                                        ..
#
# [4770 rows x 8 columns]
