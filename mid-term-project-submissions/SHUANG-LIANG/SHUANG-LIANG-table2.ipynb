# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
table2 = pd.read_excel(r'/Users/liangshuang/Desktop/table2.xlsx')

table2.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3           Unnamed: 4  \
# 0        NaN        NaN        NaN        NaN                  NaN
# 1        NaN        NaN        NaN        NaN                  NaN
# 2        NaN        NaN        NaN        NaN                  NaN
# 3        NaN        NaN        NaN        NaN       United Nations
# 4        NaN        NaN        NaN        NaN  Population Division
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# 2         NaN         NaN         NaN         NaN         NaN  ...
# 3         NaN         NaN         NaN         NaN         NaN  ...
# 4         NaN         NaN         NaN         NaN         NaN  ...
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
table2 = table2.drop(labels = range(0, 15), axis=0)
table2
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 15           1                                              WORLD        NaN
# 16           2                                  Developed regions        (b)
# 17           3                                 Developing regions        (c)
# 18           4                          Least developed countries        (d)
# 19           5  Less developed regions excluding least develop...        NaN
# ..         ...                                                ...        ...
# 275        261                                              Samoa        NaN
# 276        262                                            Tokelau        NaN
# 277        263                                              Tonga        NaN
# 278        264                                             Tuvalu        NaN
# 279        265                          Wallis and Futuna Islands        NaN
#
# ...

# %%
table2 = table2.reset_index(drop = True)
table2
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0            1                                              WORLD        NaN
# 1            2                                  Developed regions        (b)
# 2            3                                 Developing regions        (c)
# 3            4                          Least developed countries        (d)
# 4            5  Less developed regions excluding least develop...        NaN
# ..         ...                                                ...        ...
# 260        261                                              Samoa        NaN
# 261        262                                            Tokelau        NaN
# 262        263                                              Tonga        NaN
# 263        264                                             Tuvalu        NaN
# 264        265                          Wallis and Futuna Islands        NaN
#
# ...

# %%
table2.columns = ["Sort order", "Major area, region, country or area of destination", "Notes", "Country code", "1990B","1995B","2000B","2005B","2010B","2015B","1990M","1995M","2000M","2005M","2010M","2015M","1990F","1995F","2000F","2005F","2010F","2015F"]
table2
# Out:
#     Sort order Major area, region, country or area of destination Notes  \
# 0            1                                              WORLD   NaN
# 1            2                                  Developed regions   (b)
# 2            3                                 Developing regions   (c)
# 3            4                          Least developed countries   (d)
# 4            5  Less developed regions excluding least develop...   NaN
# ..         ...                                                ...   ...
# 260        261                                              Samoa   NaN
# 261        262                                            Tokelau   NaN
# 262        263                                              Tonga   NaN
# 263        264                                             Tuvalu   NaN
# 264        265                          Wallis and Futuna Islands   NaN
#
#     Country code        1990B        1995B        2000B        2005B  \
# ...

# %%
# "Notes" in the third column is just symbols represent for comments and it should not include in the dataframe, we have an information sheet called "NOTES" that would explain those symbols
table2 = table2.drop(["Notes"], axis = 1)
table2
# Out:
#     Sort order Major area, region, country or area of destination  \
# 0            1                                              WORLD
# 1            2                                  Developed regions
# 2            3                                 Developing regions
# 3            4                          Least developed countries
# 4            5  Less developed regions excluding least develop...
# ..         ...                                                ...
# 260        261                                              Samoa
# 261        262                                            Tokelau
# 262        263                                              Tonga
# 263        264                                             Tuvalu
# 264        265                          Wallis and Futuna Islands
#
#     Country code        1990B        1995B        2000B        2005B  \
# 0            900  5309667.699  5735123.084  6126622.121  6519635.850
# ...

# %%
#problem: there are multiple variables stored in 1 column
#tidy data principle #2: each column needs to consist of one and only one variable
table2.columns
# Out:
# Index(['Sort order', 'Major area, region, country or area of destination',
#        'Country code', '1990B', '1995B', '2000B', '2005B', '2010B', '2015B',
#        '1990M', '1995M', '2000M', '2005M', '2010M', '2015M', '1990F', '1995F',
#        '2000F', '2005F', '2010F', '2015F'],
#       dtype='object')

# %%
#problem: variables are stored in both rows and columns
#tidy data principle #3: variables need to be in cells, not rows and columns
table2.head()
# Out:
#   Sort order Major area, region, country or area of destination Country code  \
# 0          1                                              WORLD          900
# 1          2                                  Developed regions          901
# 2          3                                 Developing regions          902
# 3          4                          Least developed countries          941
# 4          5  Less developed regions excluding least develop...          934
#
#          1990B        1995B        2000B        2005B        2010B  \
# 0  5309667.699  5735123.084  6126622.121  6519635.850  6929725.043
# 1  1144463.062  1169761.211  1188811.731  1208919.509  1233375.711
# 2  4165204.637  4565361.873  4937810.390  5310716.341  5696349.332
# 3   510057.629   585189.354   664386.087   752804.951   847254.847
# 4  3655147.008  3980172.519  4273424.303  4557911.390  4849094.485
#
#          2015B        1990M  ...        2000M        2005M        2010M  \
# ...

# %%
table2.tail()
# Out:
#     Sort order Major area, region, country or area of destination  \
# 260        261                                              Samoa
# 261        262                                            Tokelau
# 262        263                                              Tonga
# 263        264                                             Tuvalu
# 264        265                          Wallis and Futuna Islands
#
#     Country code    1990B    1995B    2000B    2005B    2010B    2015B  \
# 260          882  162.865  170.158  174.614  179.928  186.029  193.228
# 261          772    1.609    1.520    1.552    1.210    1.135    1.250
# 262          776   95.152   95.889   97.898  100.858  103.947  106.170
# 263          798    9.004    9.227    9.419    9.694    9.827    9.916
# 264          876    13.88   14.143   14.497   14.246   13.565   13.151
#
#       1990M  ...   2000M   2005M   2010M   2015M   1990F   1995F   2000F  \
# ...

# %%
table2 = table2.melt(id_vars = ["Sort order", "Major area, region, country or area of destination", "Country code"], value_vars = ["1990B","1995B","2000B","2005B", "2010B","2015B","1990M","1995M", "2000M","2005M","2010M","2015M","1990F","1995F", "2000F","2005F","2010F","2015F"])
table2
# Out:
#      Sort order Major area, region, country or area of destination  \
# 0             1                                              WORLD
# 1             2                                  Developed regions
# 2             3                                 Developing regions
# 3             4                          Least developed countries
# 4             5  Less developed regions excluding least develop...
# ...         ...                                                ...
# 4765        261                                              Samoa
# 4766        262                                            Tokelau
# 4767        263                                              Tonga
# 4768        264                                             Tuvalu
# 4769        265                          Wallis and Futuna Islands
#
#      Country code variable        value
# 0             900    1990B  5309667.699
# 1             901    1990B  1144463.062
# ...

# %%
table2 = (table2.assign(Year = lambda x: x.variable.str[0:4].astype(int), Gender = lambda x: x.variable.str[4].astype(str)).drop("variable",axis = 1))
table2.head(10)
# Out:
#   Sort order Major area, region, country or area of destination Country code  \
# 0          1                                              WORLD          900
# 1          2                                  Developed regions          901
# 2          3                                 Developing regions          902
# 3          4                          Least developed countries          941
# 4          5  Less developed regions excluding least develop...          934
# 5          6                                 Sub-Saharan Africa          947
# 6          7                                             Africa          903
# 7          8                                     Eastern Africa          910
# 8          9                                            Burundi          108
# 9         10                                            Comoros          174
#
#          value  Year Gender
# 0  5309667.699  1990      B
# 1  1144463.062  1990      B
# 2  4165204.637  1990      B
# ...

# %%
# Styling the dataset
table2 = table2.replace({"Gender": {"B": "Both sexes", "F": "Female", "M": "Male"}})
table2.sample(10)
# Out:
#      Sort order Major area, region, country or area of destination  \
# 422         158                                          Gibraltar
# 557          28                                           Zimbabwe
# 1216        157                                            Croatia
# 2430         46                                     Western Sahara
# 3239         60                                             Guinea
# 3288        109                                            Armenia
# 3092        178                                        Netherlands
# 1585        261                                              Samoa
# 2294        175                                      Liechtenstein
# 1903         49                                            Lesotho
#
#      Country code      value  Year      Gender
# 422           292     27.285  1995  Both sexes
# 557           716  12499.981  2000  Both sexes
# 1216          191   4316.425  2010  Both sexes
# ...

# %%
table2 = table2.rename({"value": "Total population at mid-year (thousands)"}, axis = 1)
table2
# Out:
#      Sort order Major area, region, country or area of destination  \
# 0             1                                              WORLD
# 1             2                                  Developed regions
# 2             3                                 Developing regions
# 3             4                          Least developed countries
# 4             5  Less developed regions excluding least develop...
# ...         ...                                                ...
# 4765        261                                              Samoa
# 4766        262                                            Tokelau
# 4767        263                                              Tonga
# 4768        264                                             Tuvalu
# 4769        265                          Wallis and Futuna Islands
#
#      Country code Total population at mid-year (thousands)  Year      Gender
# 0             900                              5309667.699  1990  Both sexes
# ...

# %%
#change position of columns
table2 = table2.iloc[:, [0,1,2,4,5,3]]
table2
# Out:
#      Sort order Major area, region, country or area of destination  \
# 0             1                                              WORLD
# 1             2                                  Developed regions
# 2             3                                 Developing regions
# 3             4                          Least developed countries
# 4             5  Less developed regions excluding least develop...
# ...         ...                                                ...
# 4765        261                                              Samoa
# 4766        262                                            Tokelau
# 4767        263                                              Tonga
# 4768        264                                             Tuvalu
# 4769        265                          Wallis and Futuna Islands
#
#      Country code  Year      Gender Total population at mid-year (thousands)
# 0             900  1990  Both sexes                              5309667.699
# ...

# %%
table2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4770 entries, 0 to 4769
# Data columns (total 6 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Sort order                                          4770 non-null   object
#  1   Major area, region, country or area of destination  4770 non-null   object
#  2   Country code                                        4770 non-null   object
#  3   Year                                                4770 non-null   int64
#  4   Gender                                              4770 non-null   object
#  5   Total population at mid-year (thousands)            4770 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 223.7+ KB

# %%
table2.tail()
# Out:
#      Sort order Major area, region, country or area of destination  \
# 4765        261                                              Samoa
# 4766        262                                            Tokelau
# 4767        263                                              Tonga
# 4768        264                                             Tuvalu
# 4769        265                          Wallis and Futuna Islands
#
#      Country code  Year  Gender Total population at mid-year (thousands)
# 4765          882  2015  Female                                   93.584
# 4766          772  2015  Female                                       ..
# 4767          776  2015  Female                                   52.931
# 4768          798  2015  Female                                       ..
# 4769          876  2015  Female                                       ..

# %%
# There are some missing value but shows by "..", so we change to 0 that we can drop those in the next step
table2 = table2.replace("..", "NaN")

# The missing values are meaningless, so we drop those rows include missing values
table2 = table2.drop(table2[table2["Total population at mid-year (thousands)"] == "NaN"].index)

# Check whether the missing values deleted
table2.tail()
# Out:
#       Sort order Major area, region, country or area of destination  \
# 4756         252                   Micronesia (Federated States of)
# 4760         256                                          Polynesia
# 4763         259                                   French Polynesia
# 4765         261                                              Samoa
# 4767         263                                              Tonga
#
#       Country code  Year  Gender Total population at mid-year (thousands)
# 4756           583  2015  Female                                    50.95
# 4760           957  2015  Female                                  336.115
# 4763           258  2015  Female                                  138.468
# 4765           882  2015  Female                                   93.584
# 4767           776  2015  Female                                   52.931

# %%
table2.dtypes
# Out:
# Sort order                                             int64
# Major area, region, country or area of destination    object
# Country code                                           int64
# Year                                                   int64
# Gender                                                object
# Total population at mid-year (thousands)              object
# dtype: object

# %%
table2 = table2.astype({"Total population at mid-year (thousands)": "float"})

# %%
table2.dtypes # The types are all correct now
# Out:
# Sort order                                              int64
# Major area, region, country or area of destination     object
# Country code                                            int64
# Year                                                    int64
# Gender                                                 object
# Total population at mid-year (thousands)              float64
# dtype: object

# %%
table2
# Out:
#       Sort order Major area, region, country or area of destination  \
# 0              1                                              WORLD
# 1              2                                  Developed regions
# 2              3                                 Developing regions
# 3              4                          Least developed countries
# 4              5  Less developed regions excluding least develop...
# ...          ...                                                ...
# 4756         252                   Micronesia (Federated States of)
# 4760         256                                          Polynesia
# 4763         259                                   French Polynesia
# 4765         261                                              Samoa
# 4767         263                                              Tonga
#
#       Country code  Year      Gender  Total population at mid-year (thousands)
# ...

# %%
table2 = table2.reset_index(drop=True)
table2
# Out:
#       Sort order Major area, region, country or area of destination  \
# 0              1                                              WORLD
# 1              2                                  Developed regions
# 2              3                                 Developing regions
# 3              4                          Least developed countries
# 4              5  Less developed regions excluding least develop...
# ...          ...                                                ...
# 4381         252                   Micronesia (Federated States of)
# 4382         256                                          Polynesia
# 4383         259                                   French Polynesia
# 4384         261                                              Samoa
# 4385         263                                              Tonga
#
#       Country code  Year      Gender  Total population at mid-year (thousands)
# ...

# %%
#problem: there are multiple types of data stored in 1 table
#tidy data principle #4: each table column needs to have a singular data type

# %%
t2 = table2.set_index(["Sort order", "Major area, region, country or area of destination", "Country code"])
t2 = t2.sort_values("Sort order")
t2
# Out:
#                                                                             Year  \
# Sort order Major area, region, country or area of destination Country code
# 1          WORLD                                              900           1990
#                                                               900           2000
#                                                               900           2010
#                                                               900           2005
#                                                               900           2005
# ...                                                                          ...
# 265        Wallis and Futuna Islands                          876           2000
#                                                               876           2005
#                                                               876           1995
#                                                               876           1990
# ...

# %%
order2 = pd.DataFrame.from_records(
    columns = ["id", "Sort order", "Major area, region, country or area of destination", "Country code"],
    data = [
        (a+1,b,c,d)
        for (a,(b,c,d)) in enumerate(t2.index.unique())
    ],
)

# %%
order2
# Out:
#       id  Sort order Major area, region, country or area of destination  \
# 0      1           1                                              WORLD
# 1      2           2                                  Developed regions
# 2      3           3                                 Developing regions
# 3      4           4                          Least developed countries
# 4      5           5  Less developed regions excluding least develop...
# ..   ...         ...                                                ...
# 260  261         261                                              Samoa
# 261  262         262                                            Tokelau
# 262  263         263                                              Tonga
# 263  264         264                                             Tuvalu
# 264  265         265                          Wallis and Futuna Islands
#
#      Country code
# 0             900
# 1             901
# 2             902
# 3             941
# ...

# %%
order2 = order2.sort_values("Sort order")

# %%
order2
# Out:
#       id  Sort order Major area, region, country or area of destination  \
# 0      1           1                                              WORLD
# 1      2           2                                  Developed regions
# 2      3           3                                 Developing regions
# 3      4           4                          Least developed countries
# 4      5           5  Less developed regions excluding least develop...
# ..   ...         ...                                                ...
# 260  261         261                                              Samoa
# 261  262         262                                            Tokelau
# 262  263         263                                              Tonga
# 263  264         264                                             Tuvalu
# 264  265         265                          Wallis and Futuna Islands
#
#      Country code
# 0             900
# 1             901
# 2             902
# 3             941
# ...

# %%
pop2 = t2[["Year", "Gender", "Total population at mid-year (thousands)"]].copy()
pop2["id"] = order2.set_index(["Sort order", "Major area, region, country or area of destination", "Country code"])
pop2.head(20)
# Out:
#                                                                             Year  \
# Sort order Major area, region, country or area of destination Country code
# 1          WORLD                                              900           1990
#                                                               900           2000
#                                                               900           2010
#                                                               900           2005
#                                                               900           2005
#                                                               900           2010
#                                                               900           2000
#                                                               900           2015
#                                                               900           2015
#                                                               900           1990
# ...

# %%
pop2_tidy = pop2.reset_index(drop = True).set_index("id")
pop2_tidy
# Out:
#      Year      Gender  Total population at mid-year (thousands)
# id
# 1    1990  Both sexes                               5309667.699
# 1    2000  Both sexes                               6126622.121
# 1    2010      Female                               3435768.139
# 1    2005  Both sexes                               6519635.850
# 1    2005      Female                               3234553.601
# ..    ...         ...                                       ...
# 265  2000  Both sexes                                    14.497
# 265  2005  Both sexes                                    14.246
# 265  1995  Both sexes                                    14.143
# 265  1990  Both sexes                                    13.880
# 265  2015  Both sexes                                    13.151
#
# [4386 rows x 3 columns]

# %%
order2_tidy = order2.set_index("id")
order2_tidy
# Out:
#      Sort order Major area, region, country or area of destination  \
# id
# 1             1                                              WORLD
# 2             2                                  Developed regions
# 3             3                                 Developing regions
# 4             4                          Least developed countries
# 5             5  Less developed regions excluding least develop...
# ..          ...                                                ...
# 261         261                                              Samoa
# 262         262                                            Tokelau
# 263         263                                              Tonga
# 264         264                                             Tuvalu
# 265         265                          Wallis and Futuna Islands
#
#      Country code
# id
# 1             900
# 2             901
# 3             902
# 4             941
# 5             934
# ..            ...
# ...

# %%
# order2_tidy.to_csv("order2_table2.csv")

# %%
# pop2_tidy.to_csv("population_table2.csv")
