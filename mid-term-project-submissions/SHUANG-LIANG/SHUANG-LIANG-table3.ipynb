# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
table3 = pd.read_excel(r'/Users/liangshuang/Desktop/table3.xlsx')

table3.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3           Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN                  NaN        NaN
# 1        NaN        NaN        NaN        NaN                  NaN        NaN
# 2        NaN        NaN        NaN        NaN                  NaN        NaN
# 3        NaN        NaN        NaN        NaN       United Nations        NaN
# 4        NaN        NaN        NaN        NaN  Population Division        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  Unnamed: 13 Unnamed: 14  \
# 0        NaN        NaN        NaN         NaN  ...          NaN         NaN
# 1        NaN        NaN        NaN         NaN  ...          NaN         NaN
# 2        NaN        NaN        NaN         NaN  ...          NaN         NaN
# 3        NaN        NaN        NaN         NaN  ...          NaN         NaN
# 4        NaN        NaN        NaN         NaN  ...          NaN         NaN
#
# ...

# %%
table3 = table3.drop(labels=range(0, 15), axis=0)
table3
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 15           1                                              WORLD        NaN
# 16           2                                  Developed regions        (b)
# 17           3                                 Developing regions        (c)
# 18           4                          Least developed countries        (d)
# 19           5  Less developed regions excluding least develop...        NaN
# ..         ...                                                ...        ...
# 275        261                                              Samoa        NaN
# 276        262                                            Tokelau        NaN
# 277        263                                              Tonga        NaN
# 278        264                                             Tuvalu        NaN
# 279        265                          Wallis and Futuna Islands        NaN
#
# ...

# %%
table3 = table3.reset_index(drop = True)
table3
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0            1                                              WORLD        NaN
# 1            2                                  Developed regions        (b)
# 2            3                                 Developing regions        (c)
# 3            4                          Least developed countries        (d)
# 4            5  Less developed regions excluding least develop...        NaN
# ..         ...                                                ...        ...
# 260        261                                              Samoa        NaN
# 261        262                                            Tokelau        NaN
# 262        263                                              Tonga        NaN
# 263        264                                             Tuvalu        NaN
# 264        265                          Wallis and Futuna Islands        NaN
#
# ...

# %%
table3.columns = ["Sort order", "Major area, region, country or area of destination", "Notes", "Country code", "Type of data (a)", "1990B","1995B","2000B","2005B","2010B","2015B","1990M","1995M","2000M","2005M","2010M","2015M","1990F","1995F","2000F","2005F","2010F","2015F"]
table3
# Out:
#     Sort order Major area, region, country or area of destination Notes  \
# 0            1                                              WORLD   NaN
# 1            2                                  Developed regions   (b)
# 2            3                                 Developing regions   (c)
# 3            4                          Least developed countries   (d)
# 4            5  Less developed regions excluding least develop...   NaN
# ..         ...                                                ...   ...
# 260        261                                              Samoa   NaN
# 261        262                                            Tokelau   NaN
# 262        263                                              Tonga   NaN
# 263        264                                             Tuvalu   NaN
# 264        265                          Wallis and Futuna Islands   NaN
#
#     Country code Type of data (a)      1990B      1995B      2000B      2005B  \
# ...

# %%
# "Notes" in the third column is just symbols represent for comments and it should not include in the dataframe, we have an information sheet called "NOTES" that would explain those symbols
table3 = table3.drop(["Notes"], axis = 1)
table3
# Out:
#     Sort order Major area, region, country or area of destination  \
# 0            1                                              WORLD
# 1            2                                  Developed regions
# 2            3                                 Developing regions
# 3            4                          Least developed countries
# 4            5  Less developed regions excluding least develop...
# ..         ...                                                ...
# 260        261                                              Samoa
# 261        262                                            Tokelau
# 262        263                                              Tonga
# 263        264                                             Tuvalu
# 264        265                          Wallis and Futuna Islands
#
#     Country code Type of data (a)      1990B      1995B      2000B      2005B  \
# 0            900              NaN    2.87331   2.803806   2.818899   2.933739
# ...

# %%
#problem: there are multiple variables stored in 1 column
#tidy data principle #2: each column needs to consist of one and only one variable
table3.columns
# Out:
# Index(['Sort order', 'Major area, region, country or area of destination',
#        'Country code', 'Type of data (a)', '1990B', '1995B', '2000B', '2005B',
#        '2010B', '2015B', '1990M', '1995M', '2000M', '2005M', '2010M', '2015M',
#        '1990F', '1995F', '2000F', '2005F', '2010F', '2015F'],
#       dtype='object')

# %%
#problem: variables are stored in both rows and columns
#tidy data principle #3: variables need to be in cells, not rows and columns
table3.head()
# Out:
#   Sort order Major area, region, country or area of destination Country code  \
# 0          1                                              WORLD          900
# 1          2                                  Developed regions          901
# 2          3                                 Developing regions          902
# 3          4                          Least developed countries          941
# 4          5  Less developed regions excluding least develop...          934
#
#   Type of data (a)     1990B     1995B     2000B     2005B      2010B  \
# 0              NaN   2.87331  2.803806  2.818899  2.933739   3.199467
# 1              NaN  7.198015  7.891085  8.695688  9.693045  10.747765
# 2              NaN  1.685021  1.500317  1.404022  1.395066   1.565106
# 3              NaN  2.171513  2.001353  1.516863  1.303078   1.182422
# 4              NaN  1.617042  1.426534  1.386338  1.410133   1.631865
#
#        2015B  ...     2000M     2005M      2010M      2015M     1990F  \
# ...

# %%
table3.tail()
# Out:
#     Sort order Major area, region, country or area of destination  \
# 260        261                                              Samoa
# 261        262                                            Tokelau
# 262        263                                              Tonga
# 263        264                                             Tuvalu
# 264        265                          Wallis and Futuna Islands
#
#     Country code Type of data (a)      1990B      1995B      2000B      2005B  \
# 260          882                B   2.061216   2.758613   3.435005     3.1935
# 261          772                B  16.780609       17.5  16.881443  21.322314
# 262          776                B   3.059316   3.414365     3.7631   4.264411
# 263          798                C   3.531764   2.850331   2.303854   1.887766
# 264          876                B  10.100865  11.878668  13.899427  16.601151
#
#          2010B      2015B  ...     2000M     2005M     2010M     2015M  \
# ...

# %%
table3 = table3.melt(id_vars = ["Sort order","Major area, region, country or area of destination","Country code","Type of data (a)"], value_vars = ["1990B","1995B","2000B","2005B", "2010B","2015B","1990M","1995M", "2000M","2005M","2010M","2015M","1990F","1995F", "2000F","2005F","2010F","2015F"])
table3
# Out:
#      Sort order Major area, region, country or area of destination  \
# 0             1                                              WORLD
# 1             2                                  Developed regions
# 2             3                                 Developing regions
# 3             4                          Least developed countries
# 4             5  Less developed regions excluding least develop...
# ...         ...                                                ...
# 4765        261                                              Samoa
# 4766        262                                            Tokelau
# 4767        263                                              Tonga
# 4768        264                                             Tuvalu
# 4769        265                          Wallis and Futuna Islands
#
#      Country code Type of data (a) variable     value
# 0             900              NaN    1990B   2.87331
# ...

# %%
table3 = (table3.assign(Year = lambda x: x.variable.str[0:4].astype(int), Gender = lambda x: x.variable.str[4].astype(str)).drop("variable", axis = 1))
table3.head(10)
# Out:
#   Sort order Major area, region, country or area of destination Country code  \
# 0          1                                              WORLD          900
# 1          2                                  Developed regions          901
# 2          3                                 Developing regions          902
# 3          4                          Least developed countries          941
# 4          5  Less developed regions excluding least develop...          934
# 5          6                                 Sub-Saharan Africa          947
# 6          7                                             Africa          903
# 7          8                                     Eastern Africa          910
# 8          9                                            Burundi          108
# 9         10                                            Comoros          174
#
#   Type of data (a)     value  Year Gender
# 0              NaN   2.87331  1990      B
# ...

# %%
# Styling the dataset
table3 = table3.replace({"Gender": {"B": "Both sexes", "F": "Female", "M": "Male"}})
table3.sample(10)
# Out:
#      Sort order Major area, region, country or area of destination  \
# 171         172                                            Belgium
# 4372        133                                             Poland
# 592          63                                               Mali
# 1708        119                                               Oman
# 1436        112                                             Cyprus
# 4673        169          The former Yugoslav Republic of Macedonia
# 3931        222                                           Colombia
# 3535         91                                           Malaysia
# 2423         39                                    Northern Africa
# 4319         80     China, Hong Kong Special Administrative Region
#
#      Country code Type of data (a)      value  Year      Gender
# 171            56                C   8.934811  1990  Both sexes
# 4372          616                B    1.90992  2010      Female
# ...

# %%
table3 = table3.rename({"value": "International migrant stock as a percentage of the total population"}, axis = 1)
table3
# Out:
#      Sort order Major area, region, country or area of destination  \
# 0             1                                              WORLD
# 1             2                                  Developed regions
# 2             3                                 Developing regions
# 3             4                          Least developed countries
# 4             5  Less developed regions excluding least develop...
# ...         ...                                                ...
# 4765        261                                              Samoa
# 4766        262                                            Tokelau
# 4767        263                                              Tonga
# 4768        264                                             Tuvalu
# 4769        265                          Wallis and Futuna Islands
#
#      Country code Type of data (a)  \
# 0             900              NaN
# 1             901              NaN
# 2             902              NaN
# ...

# %%
#change position of columns
table3 = table3.iloc[:, [0,1,2,3,5,6,4]]
table3
# Out:
#      Sort order Major area, region, country or area of destination  \
# 0             1                                              WORLD
# 1             2                                  Developed regions
# 2             3                                 Developing regions
# 3             4                          Least developed countries
# 4             5  Less developed regions excluding least develop...
# ...         ...                                                ...
# 4765        261                                              Samoa
# 4766        262                                            Tokelau
# 4767        263                                              Tonga
# 4768        264                                             Tuvalu
# 4769        265                          Wallis and Futuna Islands
#
#      Country code Type of data (a)  Year      Gender  \
# 0             900              NaN  1990  Both sexes
# ...

# %%
table3.info() # The type of columns is wrong since there are some missing values in table1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4770 entries, 0 to 4769
# Data columns (total 7 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Sort order                                                           4770 non-null   object
#  1   Major area, region, country or area of destination                   4770 non-null   object
#  2   Country code                                                         4770 non-null   object
#  3   Type of data (a)                                                     4176 non-null   object
#  4   Year                                                                 4770 non-null   int64
#  5   Gender                                                               4770 non-null   object
#  6   International migrant stock as a percentage of the total population  4770 non-null   object
# ...

# %%
# There are some missing value but shows by "..", so we change to NaN to make it more clear
table3 = table3.replace("..", "NaN")
table3 = table3.drop(table3[table3["International migrant stock as a percentage of the total population"] == "NaN"].index)

# %%
table3.dtypes
# Out:
# Sort order                                                              int64
# Major area, region, country or area of destination                     object
# Country code                                                            int64
# Type of data (a)                                                       object
# Year                                                                    int64
# Gender                                                                 object
# International migrant stock as a percentage of the total population    object
# dtype: object

# %%
table3 = table3.astype({"International migrant stock as a percentage of the total population": "float"})

# %%
table3.dtypes # The types are all correct now
# Out:
# Sort order                                                               int64
# Major area, region, country or area of destination                      object
# Country code                                                             int64
# Type of data (a)                                                        object
# Year                                                                     int64
# Gender                                                                  object
# International migrant stock as a percentage of the total population    float64
# dtype: object

# %%
table3 # The values in the last column need to round to 1 decimal place
# Out:
#       Sort order Major area, region, country or area of destination  \
# 0              1                                              WORLD
# 1              2                                  Developed regions
# 2              3                                 Developing regions
# 3              4                          Least developed countries
# 4              5  Less developed regions excluding least develop...
# ...          ...                                                ...
# 4756         252                   Micronesia (Federated States of)
# 4760         256                                          Polynesia
# 4763         259                                   French Polynesia
# 4765         261                                              Samoa
# 4767         263                                              Tonga
#
#       Country code Type of data (a)  Year      Gender  \
# 0              900              NaN  1990  Both sexes
# ...

# %%
# We can round the values now under the "International migrant stock as a percentage of the total population" column since the types are all correct.
table3["International migrant stock as a percentage of the total population"] = table3["International migrant stock as a percentage of the total population"].round(decimals = 1)
table3
# Out:
#       Sort order Major area, region, country or area of destination  \
# 0              1                                              WORLD
# 1              2                                  Developed regions
# 2              3                                 Developing regions
# 3              4                          Least developed countries
# 4              5  Less developed regions excluding least develop...
# ...          ...                                                ...
# 4756         252                   Micronesia (Federated States of)
# 4760         256                                          Polynesia
# 4763         259                                   French Polynesia
# 4765         261                                              Samoa
# 4767         263                                              Tonga
#
#       Country code Type of data (a)  Year      Gender  \
# 0              900              NaN  1990  Both sexes
# ...

# %%
table3 = table3.reset_index(drop=True)
table3
# Out:
#       Sort order Major area, region, country or area of destination  \
# 0              1                                              WORLD
# 1              2                                  Developed regions
# 2              3                                 Developing regions
# 3              4                          Least developed countries
# 4              5  Less developed regions excluding least develop...
# ...          ...                                                ...
# 4338         252                   Micronesia (Federated States of)
# 4339         256                                          Polynesia
# 4340         259                                   French Polynesia
# 4341         261                                              Samoa
# 4342         263                                              Tonga
#
#       Country code Type of data (a)  Year      Gender  \
# 0              900              NaN  1990  Both sexes
# ...

# %%
#problem: there are multiple types of data stored in 1 table
#tidy data principle #4: each table column needs to have a singular data type

# %%
t3 = table3.set_index(["Sort order", "Major area, region, country or area of destination", "Country code", "Type of data (a)"])
t3 = t3.sort_values("Sort order")
t3
# Out:
#                                                                                              Year  \
# Sort order Major area, region, country or area of destination Country code Type of data (a)
# 1          WORLD                                              900          NaN               1990
#                                                                            NaN               2015
#                                                                            NaN               2000
#                                                                            NaN               2010
#                                                                            NaN               2005
# ...                                                                                           ...
# 265        Wallis and Futuna Islands                          876          B                 2015
#                                                                            B                 1990
# ...

# %%
order3 = pd.DataFrame.from_records(
    columns = ["id", "Sort order", "Major area, region, country or area of destination", "Country code", "Type of data (a)"],
    data = [
        (a+1,b,c,d,e)
        for (a,(b,c,d,e)) in enumerate(t3.index.unique())
    ],
)

# %%
order3
# Out:
#       id  Sort order Major area, region, country or area of destination  \
# 0      1           1                                              WORLD
# 1      2           2                                  Developed regions
# 2      3           3                                 Developing regions
# 3      4           4                          Least developed countries
# 4      5           5  Less developed regions excluding least develop...
# ..   ...         ...                                                ...
# 260  261         261                                              Samoa
# 261  262         262                                            Tokelau
# 262  263         263                                              Tonga
# 263  264         264                                             Tuvalu
# 264  265         265                          Wallis and Futuna Islands
#
#      Country code Type of data (a)
# 0             900              NaN
# ...

# %%
stock3 = t3[["Year", "Gender", "International migrant stock as a percentage of the total population"]].copy()
stock3["id"] = order3.set_index(["Sort order", "Major area, region, country or area of destination", "Country code", "Type of data (a)"])
stock3.head(20)
# Out:
#                                                                                              Year  \
# Sort order Major area, region, country or area of destination Country code Type of data (a)
# 1          WORLD                                              900          NaN               1990
#                                                                            NaN               2015
#                                                                            NaN               2000
#                                                                            NaN               2010
#                                                                            NaN               2005
#                                                                            NaN               2005
#                                                                            NaN               2010
#                                                                            NaN               2000
# ...

# %%
stock3_tidy = stock3.reset_index(drop = True).set_index("id")
stock3_tidy
# Out:
#      Year      Gender  \
# id
# 1    1990  Both sexes
# 1    2015      Female
# 1    2000  Both sexes
# 1    2010      Female
# 1    2005  Both sexes
# ..    ...         ...
# 265  2015  Both sexes
# 265  1990  Both sexes
# 265  2005  Both sexes
# 265  2010  Both sexes
# 265  2000  Both sexes
#
#      International migrant stock as a percentage of the total population
# id
# 1                                                  2.9
# 1                                                  3.2
# 1                                                  2.8
# 1                                                  3.1
# 1                                                  2.9
# ..                                                 ...
# 265                                               21.7
# 265                                               10.1
# 265                                               16.6
# 265                                               20.5
# ...

# %%
order3_tidy = order3.set_index("id")
order3_tidy
# Out:
#      Sort order Major area, region, country or area of destination  \
# id
# 1             1                                              WORLD
# 2             2                                  Developed regions
# 3             3                                 Developing regions
# 4             4                          Least developed countries
# 5             5  Less developed regions excluding least develop...
# ..          ...                                                ...
# 261         261                                              Samoa
# 262         262                                            Tokelau
# 263         263                                              Tonga
# 264         264                                             Tuvalu
# 265         265                          Wallis and Futuna Islands
#
#      Country code Type of data (a)
# id
# 1             900              NaN
# 2             901              NaN
# 3             902              NaN
# ...

# %%
# order3_tidy.to_csv("order3_table3.csv")

# %%
# stock3_tidy.to_csv("stock_percen_table3.csv")
