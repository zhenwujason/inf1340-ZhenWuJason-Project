# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
table1 = pd.read_excel(r'/Users/liangshuang/Desktop/table1.xlsx')

table1.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3           Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN                  NaN        NaN
# 1        NaN        NaN        NaN        NaN                  NaN        NaN
# 2        NaN        NaN        NaN        NaN                  NaN        NaN
# 3        NaN        NaN        NaN        NaN       United Nations        NaN
# 4        NaN        NaN        NaN        NaN  Population Division        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  Unnamed: 13 Unnamed: 14  \
# 0        NaN        NaN        NaN         NaN  ...          NaN         NaN
# 1        NaN        NaN        NaN         NaN  ...          NaN         NaN
# 2        NaN        NaN        NaN         NaN  ...          NaN         NaN
# 3        NaN        NaN        NaN         NaN  ...          NaN         NaN
# 4        NaN        NaN        NaN         NaN  ...          NaN         NaN
#
# ...

# %%
table1 = table1.drop(labels = range(0, 15), axis=0)
table1
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 15           1                                              WORLD        NaN
# 16           2                                  Developed regions        (b)
# 17           3                                 Developing regions        (c)
# 18           4                          Least developed countries        (d)
# 19           5  Less developed regions excluding least develop...        NaN
# ..         ...                                                ...        ...
# 275        261                                              Samoa        NaN
# 276        262                                            Tokelau        NaN
# 277        263                                              Tonga        NaN
# 278        264                                             Tuvalu        NaN
# 279        265                          Wallis and Futuna Islands        NaN
#
# ...

# %%
table1 = table1.reset_index(drop = True)
table1
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0            1                                              WORLD        NaN
# 1            2                                  Developed regions        (b)
# 2            3                                 Developing regions        (c)
# 3            4                          Least developed countries        (d)
# 4            5  Less developed regions excluding least develop...        NaN
# ..         ...                                                ...        ...
# 260        261                                              Samoa        NaN
# 261        262                                            Tokelau        NaN
# 262        263                                              Tonga        NaN
# 263        264                                             Tuvalu        NaN
# 264        265                          Wallis and Futuna Islands        NaN
#
# ...

# %%
table1.columns = ["Sort order", "Major area, region, country or area of destination", "Notes", "Country code", "Type of data (a)", "1990B","1995B","2000B","2005B","2010B","2015B","1990M","1995M","2000M","2005M","2010M","2015M","1990F","1995F", "2000F","2005F","2010F","2015F"]
table1
# Out:
#     Sort order Major area, region, country or area of destination Notes  \
# 0            1                                              WORLD   NaN
# 1            2                                  Developed regions   (b)
# 2            3                                 Developing regions   (c)
# 3            4                          Least developed countries   (d)
# 4            5  Less developed regions excluding least develop...   NaN
# ..         ...                                                ...   ...
# 260        261                                              Samoa   NaN
# 261        262                                            Tokelau   NaN
# 262        263                                              Tonga   NaN
# 263        264                                             Tuvalu   NaN
# 264        265                          Wallis and Futuna Islands   NaN
#
#     Country code Type of data (a)      1990B      1995B      2000B      2005B  \
# ...

# %%
# "Notes" in the third column is just symbols represent for comments and it should not include in the dataframe, we have an information sheet called "NOTES" that would explain those symbols
table1 = table1.drop(["Notes"], axis = 1)
table1
# Out:
#     Sort order Major area, region, country or area of destination  \
# 0            1                                              WORLD
# 1            2                                  Developed regions
# 2            3                                 Developing regions
# 3            4                          Least developed countries
# 4            5  Less developed regions excluding least develop...
# ..         ...                                                ...
# 260        261                                              Samoa
# 261        262                                            Tokelau
# 262        263                                              Tonga
# 263        264                                             Tuvalu
# 264        265                          Wallis and Futuna Islands
#
#     Country code Type of data (a)      1990B      1995B      2000B      2005B  \
# 0            900              NaN  152563212  160801752  172703309  191269100
# ...

# %%
#problem: there are multiple variables stored in 1 column
#tidy data principle #2: each column needs to consist of one and only one variable
table1.columns
# Out:
# Index(['Sort order', 'Major area, region, country or area of destination',
#        'Country code', 'Type of data (a)', '1990B', '1995B', '2000B', '2005B',
#        '2010B', '2015B', '1990M', '1995M', '2000M', '2005M', '2010M', '2015M',
#        '1990F', '1995F', '2000F', '2005F', '2010F', '2015F'],
#       dtype='object')

# %%
#problem: variables are stored in both rows and columns
#tidy data principle #3: variables need to be in cells, not rows and columns
table1.head()
# Out:
#   Sort order Major area, region, country or area of destination Country code  \
# 0          1                                              WORLD          900
# 1          2                                  Developed regions          901
# 2          3                                 Developing regions          902
# 3          4                          Least developed countries          941
# 4          5  Less developed regions excluding least develop...          934
#
#   Type of data (a)      1990B      1995B      2000B      2005B        2010B  \
# 0              NaN  152563212  160801752  172703309  191269100  221714243.0
# 1              NaN   82378628   92306854  103375363  117181109  132560325.0
# 2              NaN   70184584   68494898   69327946   74087991   89153918.0
# 3              NaN   11075966   11711703   10077824    9809634   10018128.0
# 4              NaN   59105261   56778501   59244124   64272611   79130668.0
#
# ...

# %%
table1.tail()
# Out:
#     Sort order Major area, region, country or area of destination  \
# 260        261                                              Samoa
# 261        262                                            Tokelau
# 262        263                                              Tonga
# 263        264                                             Tuvalu
# 264        265                          Wallis and Futuna Islands
#
#     Country code Type of data (a) 1990B 1995B 2000B 2005B   2010B   2015B  \
# 260          882                B  3357  4694  5998  5746  5122.0  4929.0
# 261          772                B   270   266   262   258   429.0   487.0
# 262          776                B  2911  3274  3684  4301  5022.0  5731.0
# 263          798                C   318   263   217   183   154.0   141.0
# 264          876                B  1402  1680  2015  2365  2776.0  2849.0
#
#      ... 2000M 2005M   2010M   2015M  1990F  1995F 2000F 2005F   2010F   2015F
# ...

# %%
table1 = table1.melt(id_vars = ["Sort order", "Major area, region, country or area of destination", "Country code", "Type of data (a)"], value_vars = ["1990B","1995B","2000B","2005B", "2010B","2015B","1990M","1995M", "2000M","2005M","2010M","2015M","1990F","1995F", "2000F","2005F","2010F","2015F"])
table1
# Out:
#      Sort order Major area, region, country or area of destination  \
# 0             1                                              WORLD
# 1             2                                  Developed regions
# 2             3                                 Developing regions
# 3             4                          Least developed countries
# 4             5  Less developed regions excluding least develop...
# ...         ...                                                ...
# 4765        261                                              Samoa
# 4766        262                                            Tokelau
# 4767        263                                              Tonga
# 4768        264                                             Tuvalu
# 4769        265                          Wallis and Futuna Islands
#
#      Country code Type of data (a) variable      value
# 0             900              NaN    1990B  152563212
# ...

# %%
table1 = (table1.assign(Year = lambda x: x.variable.str[0:4].astype(int), Gender = lambda x: x.variable.str[4].astype(str)).drop("variable", axis = 1))
table1.head(10)
# Out:
#   Sort order Major area, region, country or area of destination Country code  \
# 0          1                                              WORLD          900
# 1          2                                  Developed regions          901
# 2          3                                 Developing regions          902
# 3          4                          Least developed countries          941
# 4          5  Less developed regions excluding least develop...          934
# 5          6                                 Sub-Saharan Africa          947
# 6          7                                             Africa          903
# 7          8                                     Eastern Africa          910
# 8          9                                            Burundi          108
# 9         10                                            Comoros          174
#
#   Type of data (a)      value  Year Gender
# 0              NaN  152563212  1990      B
# ...

# %%
# Styling the dataset
table1 = table1.replace({"Gender": {"B": "Both sexes", "F": "Female", "M": "Male"}})
table1.sample(10)
# Out:
#      Sort order Major area, region, country or area of destination  \
# 1611         22                                         Seychelles
# 2799        150                                             Norway
# 2361        242                                          Melanesia
# 1568        244                                      New Caledonia
# 3179        265                          Wallis and Futuna Islands
# 3008         94                                          Singapore
# 492         228                                               Peru
# 3309        130                                           Bulgaria
# 2897        248                                         Micronesia
# 1198        139                                    Northern Europe
#
#      Country code Type of data (a)       value  Year      Gender
# 1611          690                B        2204  1990        Male
# 2799          578                B    268505.0  2010        Male
# ...

# %%
table1 = table1.rename({"value": "International migrant stock at mid-year"}, axis = 1)
table1
# Out:
#      Sort order Major area, region, country or area of destination  \
# 0             1                                              WORLD
# 1             2                                  Developed regions
# 2             3                                 Developing regions
# 3             4                          Least developed countries
# 4             5  Less developed regions excluding least develop...
# ...         ...                                                ...
# 4765        261                                              Samoa
# 4766        262                                            Tokelau
# 4767        263                                              Tonga
# 4768        264                                             Tuvalu
# 4769        265                          Wallis and Futuna Islands
#
#      Country code Type of data (a) International migrant stock at mid-year  \
# 0             900              NaN                               152563212
# ...

# %%
#change position of columns
table1 = table1.iloc[:, [0,1,2,3,5,6,4]]
table1
# Out:
#      Sort order Major area, region, country or area of destination  \
# 0             1                                              WORLD
# 1             2                                  Developed regions
# 2             3                                 Developing regions
# 3             4                          Least developed countries
# 4             5  Less developed regions excluding least develop...
# ...         ...                                                ...
# 4765        261                                              Samoa
# 4766        262                                            Tokelau
# 4767        263                                              Tonga
# 4768        264                                             Tuvalu
# 4769        265                          Wallis and Futuna Islands
#
#      Country code Type of data (a)  Year      Gender  \
# 0             900              NaN  1990  Both sexes
# ...

# %%
table1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4770 entries, 0 to 4769
# Data columns (total 7 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Sort order                                          4770 non-null   object
#  1   Major area, region, country or area of destination  4770 non-null   object
#  2   Country code                                        4770 non-null   object
#  3   Type of data (a)                                    4176 non-null   object
#  4   Year                                                4770 non-null   int64
#  5   Gender                                              4770 non-null   object
#  6   International migrant stock at mid-year             4770 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 261.0+ KB

# %%
# There are some missing value but shows by "..", so we change to "NaN" that we can drop those in the next step
table1 = table1.replace("..", "NaN")

# The missing values are meaningless, so we drop those rows include missing values
table1 = table1.drop(table1[table1["International migrant stock at mid-year"] == "NaN"].index)

# %%
table1.dtypes
# Out:
# Sort order                                             int64
# Major area, region, country or area of destination    object
# Country code                                           int64
# Type of data (a)                                      object
# Year                                                   int64
# Gender                                                object
# International migrant stock at mid-year               object
# dtype: object

# %%
table1 = table1.astype({"International migrant stock at mid-year": "float"})
table1.dtypes # The types are all correct now
# Out:
# Sort order                                              int64
# Major area, region, country or area of destination     object
# Country code                                            int64
# Type of data (a)                                       object
# Year                                                    int64
# Gender                                                 object
# International migrant stock at mid-year               float64
# dtype: object

# %%
table1
# Out:
#       Sort order Major area, region, country or area of destination  \
# 0              1                                              WORLD
# 1              2                                  Developed regions
# 2              3                                 Developing regions
# 3              4                          Least developed countries
# 4              5  Less developed regions excluding least develop...
# ...          ...                                                ...
# 4765         261                                              Samoa
# 4766         262                                            Tokelau
# 4767         263                                              Tonga
# 4768         264                                             Tuvalu
# 4769         265                          Wallis and Futuna Islands
#
#       Country code Type of data (a)  Year      Gender  \
# 0              900              NaN  1990  Both sexes
# ...

# %%
table1 = table1.reset_index(drop=True)
table1
# Out:
#       Sort order Major area, region, country or area of destination  \
# 0              1                                              WORLD
# 1              2                                  Developed regions
# 2              3                                 Developing regions
# 3              4                          Least developed countries
# 4              5  Less developed regions excluding least develop...
# ...          ...                                                ...
# 4720         261                                              Samoa
# 4721         262                                            Tokelau
# 4722         263                                              Tonga
# 4723         264                                             Tuvalu
# 4724         265                          Wallis and Futuna Islands
#
#       Country code Type of data (a)  Year      Gender  \
# 0              900              NaN  1990  Both sexes
# ...

# %%
#problem: there are multiple types of data stored in 1 table
#tidy data principle #4: each table column needs to have a singular data type

# %%
t1 = table1.set_index(["Sort order", "Major area, region, country or area of destination", "Country code", "Type of data (a)"])
t1 = t1.sort_values("Sort order")
t1
# Out:
#                                                                                              Year  \
# Sort order Major area, region, country or area of destination Country code Type of data (a)
# 1          WORLD                                              900          NaN               1990
#                                                                            NaN               2000
#                                                                            NaN               2005
#                                                                            NaN               2010
#                                                                            NaN               2015
# ...                                                                                           ...
# 265        Wallis and Futuna Islands                          876          B                 2015
#                                                                            B                 1995
# ...

# %%
order1 = pd.DataFrame.from_records(
    columns = ["id", "Sort order", "Major area, region, country or area of destination", "Country code", "Type of data (a)"],
    data = [
        (a+1,b,c,d,e)
        for (a,(b,c,d,e)) in enumerate(t1.index.unique())
    ],
)

# %%
order1
# Out:
#       id  Sort order Major area, region, country or area of destination  \
# 0      1           1                                              WORLD
# 1      2           2                                  Developed regions
# 2      3           3                                 Developing regions
# 3      4           4                          Least developed countries
# 4      5           5  Less developed regions excluding least develop...
# ..   ...         ...                                                ...
# 260  261         261                                              Samoa
# 261  262         262                                            Tokelau
# 262  263         263                                              Tonga
# 263  264         264                                             Tuvalu
# 264  265         265                          Wallis and Futuna Islands
#
#      Country code Type of data (a)
# 0             900              NaN
# ...

# %%
stock1 = t1[["Year", "Gender", "International migrant stock at mid-year"]].copy()
stock1["id"] = order1.set_index(["Sort order", "Major area, region, country or area of destination", "Country code", "Type of data (a)"])
stock1.head(20)
# Out:
#                                                                                              Year  \
# Sort order Major area, region, country or area of destination Country code Type of data (a)
# 1          WORLD                                              900          NaN               1990
#                                                                            NaN               2000
#                                                                            NaN               2005
#                                                                            NaN               2010
#                                                                            NaN               2015
#                                                                            NaN               1990
#                                                                            NaN               1995
#                                                                            NaN               2000
# ...

# %%
stock1_tidy = stock1.reset_index(drop = True).set_index("id")
stock1_tidy
# Out:
#      Year      Gender  International migrant stock at mid-year
# id
# 1    1990  Both sexes                              152563212.0
# 1    2000  Both sexes                              172703309.0
# 1    2005  Both sexes                              191269100.0
# 1    2010  Both sexes                              221714243.0
# 1    2015  Both sexes                              243700236.0
# ..    ...         ...                                      ...
# 265  2015  Both sexes                                   2849.0
# 265  1995  Both sexes                                   1680.0
# 265  2010        Male                                   1401.0
# 265  2015        Male                                   1438.0
# 265  2015      Female                                   1411.0
#
# [4725 rows x 3 columns]

# %%
order1_tidy = order1.set_index("id")
order1_tidy
# Out:
#      Sort order Major area, region, country or area of destination  \
# id
# 1             1                                              WORLD
# 2             2                                  Developed regions
# 3             3                                 Developing regions
# 4             4                          Least developed countries
# 5             5  Less developed regions excluding least develop...
# ..          ...                                                ...
# 261         261                                              Samoa
# 262         262                                            Tokelau
# 263         263                                              Tonga
# 264         264                                             Tuvalu
# 265         265                          Wallis and Futuna Islands
#
#      Country code Type of data (a)
# id
# 1             900              NaN
# 2             901              NaN
# 3             902              NaN
# ...

# %%
# order1_tidy.to_csv("order1_table1.csv")

# %%
# stock1_tidy.to_csv("stock1_table1.csv")
