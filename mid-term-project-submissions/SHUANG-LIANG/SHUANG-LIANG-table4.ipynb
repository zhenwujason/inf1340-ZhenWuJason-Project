# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
table4 = pd.read_excel(r'/Users/liangshuang/Desktop/table4.xlsx')

table4.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3           Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN                  NaN        NaN
# 1        NaN        NaN        NaN        NaN                  NaN        NaN
# 2        NaN        NaN        NaN        NaN                  NaN        NaN
# 3        NaN        NaN        NaN        NaN       United Nations        NaN
# 4        NaN        NaN        NaN        NaN  Population Division        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  Unnamed: 10
# 0        NaN        NaN        NaN         NaN          NaN
# 1        NaN        NaN        NaN         NaN          NaN
# 2        NaN        NaN        NaN         NaN          NaN
# 3        NaN        NaN        NaN         NaN          NaN
# 4        NaN        NaN        NaN         NaN          NaN

# %%
table4 = table4.drop(labels = range(0, 15), axis=0)
table4
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 15           1                                              WORLD        NaN
# 16           2                                  Developed regions        (b)
# 17           3                                 Developing regions        (c)
# 18           4                          Least developed countries        (d)
# 19           5  Less developed regions excluding least develop...        NaN
# ..         ...                                                ...        ...
# 275        261                                              Samoa        NaN
# 276        262                                            Tokelau        NaN
# 277        263                                              Tonga        NaN
# 278        264                                             Tuvalu        NaN
# 279        265                          Wallis and Futuna Islands        NaN
#
# ...

# %%
table4 = table4.reset_index(drop = True)
table4
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0            1                                              WORLD        NaN
# 1            2                                  Developed regions        (b)
# 2            3                                 Developing regions        (c)
# 3            4                          Least developed countries        (d)
# 4            5  Less developed regions excluding least develop...        NaN
# ..         ...                                                ...        ...
# 260        261                                              Samoa        NaN
# 261        262                                            Tokelau        NaN
# 262        263                                              Tonga        NaN
# 263        264                                             Tuvalu        NaN
# 264        265                          Wallis and Futuna Islands        NaN
#
# ...

# %%
table4.columns = ["Sort order", "Major area, region, country or area of destination", "Notes", "Country code", "Type of data (a)", "1990","1995","2000","2005","2010","2015"]
table4
# Out:
#     Sort order Major area, region, country or area of destination Notes  \
# 0            1                                              WORLD   NaN
# 1            2                                  Developed regions   (b)
# 2            3                                 Developing regions   (c)
# 3            4                          Least developed countries   (d)
# 4            5  Less developed regions excluding least develop...   NaN
# ..         ...                                                ...   ...
# 260        261                                              Samoa   NaN
# 261        262                                            Tokelau   NaN
# 262        263                                              Tonga   NaN
# 263        264                                             Tuvalu   NaN
# 264        265                          Wallis and Futuna Islands   NaN
#
#     Country code Type of data (a)       1990       1995       2000       2005  \
# ...

# %%
# "Notes" in the third column is just symbols represent for comments and it should not include in the dataframe, we have an information sheet called "NOTES" that would explain those symbols
table4 = table4.drop(["Notes"], axis = 1)
table4
# Out:
#     Sort order Major area, region, country or area of destination  \
# 0            1                                              WORLD
# 1            2                                  Developed regions
# 2            3                                 Developing regions
# 3            4                          Least developed countries
# 4            5  Less developed regions excluding least develop...
# ..         ...                                                ...
# 260        261                                              Samoa
# 261        262                                            Tokelau
# 262        263                                              Tonga
# 263        264                                             Tuvalu
# 264        265                          Wallis and Futuna Islands
#
#     Country code Type of data (a)       1990       1995       2000       2005  \
# 0            900              NaN   49.03915   49.16879  49.112244  48.832993
# ...

# %%
#problem: there are multiple variables stored in 1 column
#tidy data principle #2: each column needs to consist of one and only one variable
table4.columns
# Out:
# Index(['Sort order', 'Major area, region, country or area of destination',
#        'Country code', 'Type of data (a)', '1990', '1995', '2000', '2005',
#        '2010', '2015'],
#       dtype='object')

# %%
#problem: variables are stored in both rows and columns
#tidy data principle #3: variables need to be in cells, not rows and columns
table4.head()
# Out:
#   Sort order Major area, region, country or area of destination Country code  \
# 0          1                                              WORLD          900
# 1          2                                  Developed regions          901
# 2          3                                 Developing regions          902
# 3          4                          Least developed countries          941
# 4          5  Less developed regions excluding least develop...          934
#
#   Type of data (a)       1990       1995       2000       2005       2010  \
# 0              NaN   49.03915   49.16879  49.112244  48.832993  48.305660
# 1              NaN  51.123977  51.149024  51.113307  51.171501  51.658932
# 2              NaN  46.592099  46.500135  46.128444  45.134297  43.319780
# 3              NaN  47.261155  47.571664  46.826689  45.157406  45.499573
# 4              NaN  46.466684  46.279022  46.009598  45.130768  43.043672
#
#         2015
# 0  48.249769
# 1  51.866687
# 2  43.327078
# ...

# %%
table4.tail()
# Out:
#     Sort order Major area, region, country or area of destination  \
# 260        261                                              Samoa
# 261        262                                            Tokelau
# 262        263                                              Tonga
# 263        264                                             Tuvalu
# 264        265                          Wallis and Futuna Islands
#
#     Country code Type of data (a)       1990       1995       2000       2005  \
# 260          882                B  47.244564  47.784406  48.299433  48.833971
# 261          772                B  44.444444  44.736842  45.038168  48.449612
# 262          776                B  48.883545  47.525962  46.226927  45.873053
# 263          798                C  43.396226  43.726236  44.239631  44.808743
# 264          876                B  48.216833  48.869048  49.478908  49.513742
#
#           2010       2015
# 260  49.355720  49.908704
# 261  51.981352  52.156057
# ...

# %%
table4 = table4.melt(id_vars = ["Sort order", "Major area, region, country or area of destination", "Country code", "Type of data (a)"], value_vars = ["1990","1995","2000","2005", "2010","2015"])
table4
# Out:
#      Sort order Major area, region, country or area of destination  \
# 0             1                                              WORLD
# 1             2                                  Developed regions
# 2             3                                 Developing regions
# 3             4                          Least developed countries
# 4             5  Less developed regions excluding least develop...
# ...         ...                                                ...
# 1585        261                                              Samoa
# 1586        262                                            Tokelau
# 1587        263                                              Tonga
# 1588        264                                             Tuvalu
# 1589        265                          Wallis and Futuna Islands
#
#      Country code Type of data (a) variable      value
# 0             900              NaN     1990   49.03915
# ...

# %%
table4 = table4.rename({"variable": "Year", "value": "Female migrants as a percentage of the international migrant stock"}, axis = 1)
table4
# Out:
#      Sort order Major area, region, country or area of destination  \
# 0             1                                              WORLD
# 1             2                                  Developed regions
# 2             3                                 Developing regions
# 3             4                          Least developed countries
# 4             5  Less developed regions excluding least develop...
# ...         ...                                                ...
# 1585        261                                              Samoa
# 1586        262                                            Tokelau
# 1587        263                                              Tonga
# 1588        264                                             Tuvalu
# 1589        265                          Wallis and Futuna Islands
#
#      Country code Type of data (a)  Year  \
# 0             900              NaN  1990
# 1             901              NaN  1990
# ...

# %%
table4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1590 entries, 0 to 1589
# Data columns (total 6 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Sort order                                                          1590 non-null   object
#  1   Major area, region, country or area of destination                  1590 non-null   object
#  2   Country code                                                        1590 non-null   object
#  3   Type of data (a)                                                    1392 non-null   object
#  4   Year                                                                1590 non-null   object
#  5   Female migrants as a percentage of the international migrant stock  1590 non-null   object
# dtypes: object(6)
# memory usage: 74.7+ KB

# %%
# There are some missing value but shows by "..", so we change to NaN to make it more clear
table4 = table4.replace("..", "NaN")

# The missing values are meaningless, so we drop those rows include missing values
table4 = table4.drop(table4[table4["Female migrants as a percentage of the international migrant stock"] == "NaN"].index)

# %%
table4.dtypes
# Out:
# Sort order                                                             int64
# Major area, region, country or area of destination                    object
# Country code                                                           int64
# Type of data (a)                                                      object
# Year                                                                  object
# Female migrants as a percentage of the international migrant stock    object
# dtype: object

# %%
table4 = table4.astype({"Female migrants as a percentage of the international migrant stock": "float", "Year": "int"})

# %%
table4.dtypes # The types are all correct now
# Out:
# Sort order                                                              int64
# Major area, region, country or area of destination                     object
# Country code                                                            int64
# Type of data (a)                                                       object
# Year                                                                    int64
# Female migrants as a percentage of the international migrant stock    float64
# dtype: object

# %%
table4 # The values in the last column need to round to 1 decimal place
# Out:
#       Sort order Major area, region, country or area of destination  \
# 0              1                                              WORLD
# 1              2                                  Developed regions
# 2              3                                 Developing regions
# 3              4                          Least developed countries
# 4              5  Less developed regions excluding least develop...
# ...          ...                                                ...
# 1585         261                                              Samoa
# 1586         262                                            Tokelau
# 1587         263                                              Tonga
# 1588         264                                             Tuvalu
# 1589         265                          Wallis and Futuna Islands
#
#       Country code Type of data (a)  Year  \
# 0              900              NaN  1990
# 1              901              NaN  1990
# ...

# %%
# We can round the values now under the "Female migrants as a percentage of the international migrant stock" column since the types are all correct
table4["Female migrants as a percentage of the international migrant stock"] = table4["Female migrants as a percentage of the international migrant stock"].round(decimals = 1)
table4
# Out:
#       Sort order Major area, region, country or area of destination  \
# 0              1                                              WORLD
# 1              2                                  Developed regions
# 2              3                                 Developing regions
# 3              4                          Least developed countries
# 4              5  Less developed regions excluding least develop...
# ...          ...                                                ...
# 1585         261                                              Samoa
# 1586         262                                            Tokelau
# 1587         263                                              Tonga
# 1588         264                                             Tuvalu
# 1589         265                          Wallis and Futuna Islands
#
#       Country code Type of data (a)  Year  \
# 0              900              NaN  1990
# 1              901              NaN  1990
# ...

# %%
table4 = table4.reset_index(drop=True)
table4
# Out:
#       Sort order Major area, region, country or area of destination  \
# 0              1                                              WORLD
# 1              2                                  Developed regions
# 2              3                                 Developing regions
# 3              4                          Least developed countries
# 4              5  Less developed regions excluding least develop...
# ...          ...                                                ...
# 1570         261                                              Samoa
# 1571         262                                            Tokelau
# 1572         263                                              Tonga
# 1573         264                                             Tuvalu
# 1574         265                          Wallis and Futuna Islands
#
#       Country code Type of data (a)  Year  \
# 0              900              NaN  1990
# 1              901              NaN  1990
# ...

# %%
#problem: there are multiple types of data stored in 1 table
#tidy data principle #4: each table column needs to have a singular data type

# %%
t4 = table4.set_index(["Sort order", "Major area, region, country or area of destination", "Country code", "Type of data (a)"])
t4 = t4.sort_values("Sort order")
t4
# Out:
#                                                                                              Year  \
# Sort order Major area, region, country or area of destination Country code Type of data (a)
# 1          WORLD                                              900          NaN               1990
#                                                                            NaN               2000
#                                                                            NaN               2005
#                                                                            NaN               2015
#                                                                            NaN               2010
# ...                                                                                           ...
# 265        Wallis and Futuna Islands                          876          B                 1995
#                                                                            B                 2005
# ...

# %%
order4 = pd.DataFrame.from_records(
    columns = ["id", "Sort order", "Major area, region, country or area of destination", "Country code", "Type of data (a)"],
    data = [
        (a+1,b,c,d,e)
        for (a,(b,c,d,e)) in enumerate(t4.index.unique())
    ],
)

# %%
order4
# Out:
#       id  Sort order Major area, region, country or area of destination  \
# 0      1           1                                              WORLD
# 1      2           2                                  Developed regions
# 2      3           3                                 Developing regions
# 3      4           4                          Least developed countries
# 4      5           5  Less developed regions excluding least develop...
# ..   ...         ...                                                ...
# 260  261         261                                              Samoa
# 261  262         262                                            Tokelau
# 262  263         263                                              Tonga
# 263  264         264                                             Tuvalu
# 264  265         265                          Wallis and Futuna Islands
#
#      Country code Type of data (a)
# 0             900              NaN
# ...

# %%
stock4 = t4[["Year", "Female migrants as a percentage of the international migrant stock"]].copy()
stock4["id"] = order4.set_index(["Sort order", "Major area, region, country or area of destination", "Country code", "Type of data (a)"])
stock4.head(20)
# Out:
#                                                                                              Year  \
# Sort order Major area, region, country or area of destination Country code Type of data (a)
# 1          WORLD                                              900          NaN               1990
#                                                                            NaN               2000
#                                                                            NaN               2005
#                                                                            NaN               2015
#                                                                            NaN               2010
#                                                                            NaN               1995
# 2          Developed regions                                  901          NaN               1990
#                                                                            NaN               2000
# ...

# %%
stock4_tidy = stock4.reset_index(drop = True).set_index("id")
stock4_tidy
# Out:
#      Year  Female migrants as a percentage of the international migrant stock
# id
# 1    1990                                               49.0
# 1    2000                                               49.1
# 1    2005                                               48.8
# 1    2015                                               48.2
# 1    2010                                               48.3
# ..    ...                                                ...
# 265  1995                                               48.9
# 265  2005                                               49.5
# 265  2010                                               49.5
# 265  2000                                               49.5
# 265  2015                                               49.5
#
# [1575 rows x 2 columns]

# %%
order4_tidy = order4.set_index("id")
order4_tidy
# Out:
#      Sort order Major area, region, country or area of destination  \
# id
# 1             1                                              WORLD
# 2             2                                  Developed regions
# 3             3                                 Developing regions
# 4             4                          Least developed countries
# 5             5  Less developed regions excluding least develop...
# ..          ...                                                ...
# 261         261                                              Samoa
# 262         262                                            Tokelau
# 263         263                                              Tonga
# 264         264                                             Tuvalu
# 265         265                          Wallis and Futuna Islands
#
#      Country code Type of data (a)
# id
# 1             900              NaN
# 2             901              NaN
# 3             902              NaN
# ...

# %%
# order4_tidy.to_csv("order4_table4.csv")

# %%
# stock4_tidy.to_csv("female_percen_table4.csv")
